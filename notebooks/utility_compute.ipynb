# %%
import json
import numpy as np
from pathlib import Path

# %% [markdown]
# Simple linear equation
#
# $\alpha*P + \beta*S + \gamma*R$

# %%
bwt_results = {
    "W/O CL": {
        "Random": -0.32,
        "B2W":    -0.31,
        "W2B":    -0.38,
        "Toggle": -0.35,
    },
    "EWC": {
        "Random": -0.15,
        "B2W":    -0.28,
        "W2B":    -0.17,
        "Toggle": -0.17,
    },
    "SI": {
        "Random": -0.06,
        "B2W":    -0.08,
        "W2B":    -0.09,
        "Toggle": -0.09,
    },
    "LwF": {
        "Random": -0.22,
        "B2W":    -0.26,
        "W2B":    -0.10,
        "Toggle": -0.16,
    },
    "Replay": {
        "Random": -0.11,
        "B2W":    -0.11,
        "W2B":    -0.11,
        "Toggle": -0.11,
    },
    "Generative Replay": {
        "Random": -0.28,
        "B2W":    -0.29,
        "W2B":    -0.35,
        "Toggle": -0.32,
    },
}

plasticity_results = {
    "W/O CL": {
        "Random": 0.25,
        "B2W":    0.13,
        "W2B":    0.40,
        "Toggle": 0.31,
    },
    "EWC": {
        "Random": 0.08,
        "B2W":    0.19,
        "W2B":    0.16,
        "Toggle": 0.14,
    },
    "SI": {
        "Random": 0.03,
        "B2W":    0.03,
        "W2B":    0.06,
        "Toggle": 0.05,
    },
    "LwF": {
        "Random": 0.07,
        "B2W":    0.08,
        "W2B":    0.14,
        "Toggle": 0.13,
    },
    "Replay": {
        "Random": 0.31,
        "B2W":    0.32,
        "W2B":    0.31,
        "Toggle": 0.31,
    },
    "Generative Replay": {
        "Random": 0.24,
        "B2W":    0.13,
        "W2B":    0.38,
        "Toggle": 0.29,
    },
}

cost_efficiency_results = {
    "W/O CL": {
        "Random": 0.94,
        "B2W":    0.96,
        "W2B":    0.85,
        "Toggle": 0.96,
    },
    "EWC": {
        "Random": 0.18,
        "B2W":    0.22,
        "W2B":    0.20,
        "Toggle": 0.18,
    },
    "SI": {
        "Random": 0.83,
        "B2W":    0.80,
        "W2B":    0.92,
        "Toggle": 0.78,
    },
    "LwF": {
        "Random": 0.64,
        "B2W":    0.61,
        "W2B":    0.76,
        "Toggle": 0.64,
    },
    "Replay": {
        "Random": 0.54,
        "B2W":    0.52,
        "W2B":    0.66,
        "Toggle": 0.57,
    },
    "Generative Replay": {
        "Random": 0.42,
        "B2W":    0.40,
        "W2B":    0.51,
        "Toggle": 0.42,
    },
}

# %%
import numpy as np

# Your input dicts
bwt_results = {
    "W/O CL": {"Random": -0.32, "B2W": -0.31, "W2B": -0.38, "Toggle": -0.35},
    "EWC": {"Random": -0.15, "B2W": -0.28, "W2B": -0.17, "Toggle": -0.17},
    "SI": {"Random": -0.06, "B2W": -0.08, "W2B": -0.09, "Toggle": -0.09},
    "LwF": {"Random": -0.22, "B2W": -0.26, "W2B": -0.10, "Toggle": -0.16},
    "Replay": {"Random": -0.11, "B2W": -0.11, "W2B": -0.11, "Toggle": -0.11},
    "Generative Replay": {"Random": -0.28, "B2W": -0.29, "W2B": -0.35, "Toggle": -0.32},
}

plasticity_results = {
    "W/O CL": {"Random": 0.25, "B2W": 0.13, "W2B": 0.40, "Toggle": 0.31},
    "EWC": {"Random": 0.08, "B2W": 0.19, "W2B": 0.16, "Toggle": 0.14},
    "SI": {"Random": 0.03, "B2W": 0.03, "W2B": 0.06, "Toggle": 0.05},
    "LwF": {"Random": 0.07, "B2W": 0.08, "W2B": 0.14, "Toggle": 0.13},
    "Replay": {"Random": 0.31, "B2W": 0.32, "W2B": 0.31, "Toggle": 0.31},
    "Generative Replay": {"Random": 0.24, "B2W": 0.13, "W2B": 0.38, "Toggle": 0.29},
}

cost_efficiency_results = {
    "W/O CL": {"Random": 0.94, "B2W": 0.96, "W2B": 0.85, "Toggle": 0.96},
    "EWC": {"Random": 0.18, "B2W": 0.22, "W2B": 0.20, "Toggle": 0.18},
    "SI": {"Random": 0.83, "B2W": 0.80, "W2B": 0.92, "Toggle": 0.78},
    "LwF": {"Random": 0.64, "B2W": 0.61, "W2B": 0.76, "Toggle": 0.64},
    "Replay": {"Random": 0.54, "B2W": 0.52, "W2B": 0.66, "Toggle": 0.57},
    "Generative Replay": {"Random": 0.42, "B2W": 0.40, "W2B": 0.51, "Toggle": 0.42},
}

# --- Step 1: Scale BWT into [0,1] ---
scaled_bwt = {
    method: {scenario: (val + 1) / 2 for scenario, val in scores.items()}
    for method, scores in bwt_results.items()
}

# --- Step 2: Set weights ---
alpha, beta, gamma = 0.1, 0.8, 0.1   # change if needed

# --- Step 3: Compute final results ---
final_results = {}
for method in bwt_results.keys():
    final_results[method] = {}
    for scenario in bwt_results[method].keys():
        p = plasticity_results[method][scenario]
        b = scaled_bwt[method][scenario]
        c = cost_efficiency_results[method][scenario]
        final_results[method][scenario] = (
            alpha * p + beta * b + gamma * c
        )

# --- Print nicely ---

# print("Scaled BWT:")
# print(scaled_bwt)

print("\nFinal Results:")
print(final_results)
# Out:
# Final Results:
# {'W/O CL': {'Random': 0.391, 'B2W': 0.385, 'W2B': 0.37300000000000005, 'Toggle': 0.387}, 'EWC': {'Random': 0.36600000000000005, 'B2W': 0.329, 'W2B': 0.36800000000000005, 'Toggle': 0.36400000000000005}, 'SI': {'Random': 0.462, 'B2W': 0.45100000000000007, 'W2B': 0.4620000000000001, 'Toggle': 0.44700000000000006}, 'LwF': {'Random': 0.38300000000000006, 'B2W': 0.365, 'W2B': 0.45000000000000007, 'Toggle': 0.41300000000000003}, 'Replay': {'Random': 0.441, 'B2W': 0.44, 'W2B': 0.453, 'Toggle': 0.444}, 'Generative Replay': {'Random': 0.354, 'B2W': 0.33699999999999997, 'W2B': 0.34900000000000003, 'Toggle': 0.3429999999999999}}

# %%
import pandas as pd

# Convert nested dict to DataFrame
df = pd.DataFrame(final_results).T  # methods as rows, scenarios as columns

# Round for nicer display
df = df.round(3)

print("\n=== Final Results Table ===")
print(df.to_string())

# If you want LaTeX table (for paper)
print("\n=== LaTeX Table ===")
print(df.to_latex(float_format="%.3f"))
# Out:
# === Final Results Table ===
#                    Random    B2W    W2B  Toggle
# W/O CL              0.391  0.385  0.373   0.387
# EWC                 0.366  0.329  0.368   0.364
# SI                  0.462  0.451  0.462   0.447
# LwF                 0.383  0.365  0.450   0.413
# Replay              0.441  0.440  0.453   0.444
# Generative Replay   0.354  0.337  0.349   0.343
#
# === LaTeX Table ===
# \begin{tabular}{lrrrr}
# \toprule
# {} &  Random &   B2W &   W2B &  Toggle \\
# \midrule
# W/O CL            &   0.391 & 0.385 & 0.373 &   0.387 \\
# EWC               &   0.366 & 0.329 & 0.368 &   0.364 \\
# SI                &   0.462 & 0.451 & 0.462 &   0.447 \\
# LwF               &   0.383 & 0.365 & 0.450 &   0.413 \\
# Replay            &   0.441 & 0.440 & 0.453 &   0.444 \\
# Generative Replay &   0.354 & 0.337 & 0.349 &   0.343 \\
# \bottomrule
# \end{tabular}
# ...

# %% [markdown]
# Plot the utility for 4 scenarios
#
# A. Random
#
# B. W2B
#
# C. B2W
#
# D. Toggle
