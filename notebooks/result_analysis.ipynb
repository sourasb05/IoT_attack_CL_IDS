# %% [markdown]
# ## 1. BWT across 48 domains (Random, B2W, W2B, Toggle)

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_random.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_random_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_random.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Attention_EWC_random.json', 'r') as f:
    data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_random.json', 'r') as f:
    data5 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_SI_random.json', 'r') as f:
    data6 = json.load(f)
# Color-blind friendly palette (Okabe-Ito)
COLORS = {
    "W/O CL": "#0072B2",   # blue
    "LwF":    "#E69F00",   # orange
    "GR":     "#D55E00",   # vermilion
    "EWC":    "#CC79A7",   # reddish-purple
    "REPLAY": "#56B4E9",   # sky blue
    "SI":     "#009E73"    # bluish-green
}

plt.figure(figsize=(8,6), dpi=150)

# Plot with distinct styles
plt.plot(data1["BWT_values"], label="W/O CL", color=COLORS["W/O CL"], 
         linewidth=2.5, linestyle="-", marker="o", markersize=5)
plt.plot(data2["BWT_values"], label="LwF", color=COLORS["LwF"], 
         linewidth=2.5, linestyle="--", marker="^", markersize=5)
plt.plot(data3["BWT_values"], label="GR", color=COLORS["GR"], 
         linewidth=2.5, linestyle="-.", marker="s", markersize=5)
plt.plot(data4["BWT_values"], label="EWC", color=COLORS["EWC"], 
         linewidth=2.5, linestyle=":", marker="D", markersize=5)
plt.plot(data5["BWT_values"], label="REPLAY", color=COLORS["REPLAY"],
            linewidth=2.5, linestyle="--", marker="v", markersize=5)
plt.plot(data6["BWT_values"], label="SI", color=COLORS["SI"],
            linewidth=2.5, linestyle="-.", marker="*", markersize=5)

# Labels
plt.xlabel("Domain Index", fontsize=22)
plt.ylabel("BWT", fontsize=22)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True, alpha=0.3)

plt.legend(
     fontsize=20,
    frameon=True, edgecolor="black", 
    loc="upper center", bbox_to_anchor=(0.5, 1.27), ncol=3
)
# Save + show
plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/BWT_random.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_b2w.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_b2w_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_b2w.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Attention_EWC_b2w.json', 'r') as f:
    data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_b2w.json', 'r') as f:
    data5 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_SI_b2w.json', 'r') as f:
    data6 = json.load(f)

# Color-blind friendly palette (Okabe-Ito)
COLORS = {
    "W/O CL": "#0072B2",   # blue
    "LwF":    "#E69F00",   # orange
    "GR":     "#D55E00",   # vermilion
    "EWC":    "#CC79A7",   # reddish-purple
    "REPLAY": "#56B4E9",   # sky blue
    "SI":     "#009E73"    # bluish-green
}

plt.figure(figsize=(8,6), dpi=150)

# Plot with distinct styles
plt.plot(data1["BWT_values"], label="W/O CL", color=COLORS["W/O CL"], 
         linewidth=2.5, linestyle="-", marker="o", markersize=5)
plt.plot(data2["BWT_values"], label="LwF", color=COLORS["LwF"], 
         linewidth=2.5, linestyle="--", marker="^", markersize=5)
plt.plot(data3["BWT_values"], label="GR", color=COLORS["GR"], 
         linewidth=2.5, linestyle="-.", marker="s", markersize=5)
plt.plot(data4["BWT_values"], label="EWC", color=COLORS["EWC"], 
         linewidth=2.5, linestyle=":", marker="D", markersize=5)
plt.plot(data5["BWT_values"], label="REPLAY", color=COLORS["REPLAY"],
            linewidth=2.5, linestyle="--", marker="v", markersize=5)
plt.plot(data6["BWT_values"], label="SI", color=COLORS["SI"],
            linewidth=2.5, linestyle="-.", marker="*", markersize=5)

# Labels
plt.xlabel("Domain Index", fontsize=22)
plt.ylabel("BWT", fontsize=22)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True, alpha=0.3)


plt.legend(
     fontsize=20,
    frameon=True, edgecolor="black", 
    loc="upper center", bbox_to_anchor=(0.5, 1.27), ncol=3
)
# Save + show
plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/BWT_b2w.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_w2b.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_w2b_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_w2b.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_w2b.json', 'r') as f:
    data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_w2b.json', 'r') as f:
    data5 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_SI_w2b.json', 'r') as f:
    data6 = json.load(f)

# Color-blind friendly palette (Okabe-Ito)
COLORS = {
    "W/O CL": "#0072B2",   # blue
    "LwF":    "#E69F00",   # orange
    "GR":     "#D55E00",   # vermilion
    "EWC":    "#CC79A7",   # reddish-purple
    "REPLAY": "#56B4E9",   # sky blue
    "SI":     "#009E73"    # bluish-green
}

plt.figure(figsize=(8,6), dpi=150)

# Plot with distinct styles
plt.plot(data1["BWT_values"], label="W/O CL", color=COLORS["W/O CL"], 
         linewidth=2.5, linestyle="-", marker="o", markersize=5)
plt.plot(data2["BWT_values"], label="LwF", color=COLORS["LwF"], 
         linewidth=2.5, linestyle="--", marker="^", markersize=5)
plt.plot(data3["BWT_values"], label="GR", color=COLORS["GR"], 
         linewidth=2.5, linestyle="-.", marker="s", markersize=5)
plt.plot(data4["BWT_values"], label="EWC", color=COLORS["EWC"], 
         linewidth=2.5, linestyle=":", marker="D", markersize=5)
plt.plot(data5["BWT_values"], label="REPLAY", color=COLORS["REPLAY"],
            linewidth=2.5, linestyle="--", marker="v", markersize=5)
plt.plot(data6["BWT_values"], label="SI", color=COLORS["SI"],
            linewidth=2.5, linestyle="-.", marker="*", markersize=5)

# Labels
plt.xlabel("Domain Index", fontsize=22)
plt.ylabel("BWT", fontsize=22)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True, alpha=0.3)
plt.legend(
     fontsize=20,
    frameon=True, edgecolor="black", 
    loc="upper center", bbox_to_anchor=(0.5, 1.27), ncol=3
)
# Save + show
plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/BWT_w2b.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_toggle.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_toggle_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_toggle.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_toggle.json', 'r') as f:
    data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_toggle.json', 'r') as f:
    data5 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_SI_toggle.json', 'r') as f:
    data6 = json.load(f)


COLORS = {
    "W/O CL": "#0072B2",   # blue
    "LwF":    "#E69F00",   # orange
    "GR":     "#D55E00",   # vermilion
    "EWC":    "#CC79A7",   # reddish-purple
    "REPLAY": "#56B4E9",   # sky blue
    "SI":     "#009E73"    # bluish-green
}

plt.figure(figsize=(8,6), dpi=150)

# Plot with distinct styles
plt.plot(data1["BWT_values"], label="W/O CL", color=COLORS["W/O CL"], 
         linewidth=2.5, linestyle="-", marker="o", markersize=5)
plt.plot(data2["BWT_values"], label="LwF", color=COLORS["LwF"], 
         linewidth=2.5, linestyle="--", marker="^", markersize=5)
plt.plot(data3["BWT_values"], label="GR", color=COLORS["GR"], 
         linewidth=2.5, linestyle="-.", marker="s", markersize=5)
plt.plot(data4["BWT_values"], label="EWC", color=COLORS["EWC"], 
         linewidth=2.5, linestyle=":", marker="D", markersize=5)
plt.plot(data5["BWT_values"], label="REPLAY", color=COLORS["REPLAY"],
            linewidth=2.5, linestyle="--", marker="v", markersize=5)
plt.plot(data6["BWT_values"], label="SI", color=COLORS["SI"],
            linewidth=2.5, linestyle="-.", marker="*", markersize=5)

# Labels
plt.xlabel("Domain Index", fontsize=22)
plt.ylabel("BWT", fontsize=22)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True, alpha=0.3)

# Legend (fixed bug)
plt.legend(
     fontsize=20,
    frameon=True, edgecolor="black", 
    loc="upper center", bbox_to_anchor=(0.5, 1.27), ncol=3
)
# Save + show
plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/BWT_toggle.png")
plt.show()

# %% [markdown]
# Box Plot of Different Continual Learning method

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Load results
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_random.json') as f: data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_random_alpha_1.0_T_4.0.json') as f: data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_random.json') as f: data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/3_experiment_results_LSTM_EWC_random.json') as f: data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_random.json') as f: data5 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_SI_random.json') as f: data6 = json.load(f)

# Sub-dicts
d1, d2, d3, d4, d5, d6 = (data1["domain_training_cost"],
                          data2["domain_training_cost"],
                          data3["domain_training_cost"],
                          data4["domain_training_cost"],
                          data5["domain_training_cost"],
                          data6["domain_training_cost"])

# Common keys
print(d1)
keys = sorted(set(d1) & set(d2) & set(d3) & set(d4) & set(d5) & set(d6))
print(keys)
# Values per method
vals1 = [d1[k][0] for k in keys]
vals2 = [d2[k][0] for k in keys]
vals3 = [d3[k][0] for k in keys]
vals4 = [d4[k][0] for k in keys]
vals5 = [d5[k][0] for k in keys]
vals6 = [d6[k][0] for k in keys]

# Okabe–Ito colorblind safe palette
colors = [
    "#E69F00",  # orange
    "#56B4E9",  # sky blue
    "#009E73",  # green
    "#F0E442",  # yellow
    "#0072B2",  # blue
    "#D55E00"   # vermillion
]

labels = ["W/O CL", "LwF", "GR", "EWC", "Replay", "SI"]

plt.figure(figsize=(12, 6))
boxplots = plt.boxplot([vals1, vals2, vals3, vals4, vals5, vals6],
                       labels=labels,
                       patch_artist=True,
                       showmeans=True)

# Apply colors
for patch, color in zip(boxplots["boxes"], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

for median in boxplots["medians"]:
    median.set(color="black", linewidth=2)

for mean in boxplots["means"]:
    mean.set(marker="o", markerfacecolor="black", markeredgecolor="black", markersize=5)

plt.ylabel("Domain Training Cost", fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
# plt.title("Domain Training Cost — Boxplot Across Methods (toggle)")
plt.grid(axis="y", linestyle="--", alpha=0.6)

plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/Domain_Training_Cost_random_boxplot.png", dpi=200)
plt.show()
# Out:
# {'blackhole_var10_base': [8.85408162791282], 'blackhole_var10_dec': [10.474850629922003], 'blackhole_var10_oo': [9.754400193924084], 'blackhole_var15_base': [13.566432684892789], 'blackhole_var15_dec': [14.147411733865738], 'blackhole_var15_oo': [9.813761702971533], 'blackhole_var20_base': [13.900195207912475], 'blackhole_var20_dec': [11.102222746936604], 'blackhole_var20_oo': [7.413909231079742], 'blackhole_var5_base': [13.960775636136532], 'blackhole_var5_dec': [14.196546755963936], 'blackhole_var5_oo': [8.503290647873655], 'disflooding_var10_base': [13.422360466094688], 'disflooding_var10_dec': [14.443807400995865], 'disflooding_var10_oo': [22.01545278611593], 'disflooding_var15_base': [14.894838456995785], 'disflooding_var15_dec': [22.276544528082013], 'disflooding_var15_oo': [21.907497504958883], 'disflooding_var20_base': [15.906014155130833], 'disflooding_var20_dec': [15.402086907997727], 'disflooding_var20_oo': [20.747895932057872], 'disflooding_var5_base': [20.95931567181833]
# ...

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Load results
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_b2w.json') as f: data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_b2w_alpha_1.0_T_4.0.json') as f: data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_b2w.json') as f: data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/3_experiment_results_LSTM_EWC_b2w.json') as f: data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_b2w.json') as f: data5 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_SI_b2w.json') as f: data6 = json.load(f)

# Sub-dicts
d1, d2, d3, d4, d5, d6 = (data1["domain_training_cost"],
                          data2["domain_training_cost"],
                          data3["domain_training_cost"],
                          data4["domain_training_cost"],
                          data5["domain_training_cost"],
                          data6["domain_training_cost"])

# Common keys
keys = sorted(set(d1) & set(d2) & set(d3) & set(d4) & set(d5) & set(d6))

# Values per method
vals1 = [d1[k][0] for k in keys]
vals2 = [d2[k][0] for k in keys]
vals3 = [d3[k][0] for k in keys]
vals4 = [d4[k][0] for k in keys]
vals5 = [d5[k][0] for k in keys]
vals6 = [d6[k][0] for k in keys]

# Okabe–Ito colorblind safe palette
colors = [
    "#E69F00",  # orange
    "#56B4E9",  # sky blue
    "#009E73",  # green
    "#F0E442",  # yellow
    "#0072B2",  # blue
    "#D55E00"   # vermillion
]

labels = ["W/O CL", "LwF", "GR", "EWC", "Replay", "SI"]

plt.figure(figsize=(12, 6))
boxplots = plt.boxplot([vals1, vals2, vals3, vals4, vals5, vals6],
                       labels=labels,
                       patch_artist=True,
                       showmeans=True)

# Apply colors
for patch, color in zip(boxplots["boxes"], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

for median in boxplots["medians"]:
    median.set(color="black", linewidth=2)

for mean in boxplots["means"]:
    mean.set(marker="o", markerfacecolor="black", markeredgecolor="black", markersize=5)

plt.ylabel("Domain Training Cost", fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
# plt.title("Domain Training Cost — Boxplot Across Methods (toggle)")
plt.grid(axis="y", linestyle="--", alpha=0.6)

plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/Domain_Training_Cost_b2w_boxplot.png", dpi=200)
plt.show()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Load results
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_w2b.json') as f: data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_w2b_alpha_1.0_T_4.0.json') as f: data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_w2b.json') as f: data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/3_experiment_results_LSTM_EWC_w2b.json') as f: data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_w2b.json') as f: data5 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_SI_w2b.json') as f: data6 = json.load(f)

# Sub-dicts
d1, d2, d3, d4, d5, d6 = (data1["domain_training_cost"],
                          data2["domain_training_cost"],
                          data3["domain_training_cost"],
                          data4["domain_training_cost"],
                          data5["domain_training_cost"],
                          data6["domain_training_cost"])

# Common keys
keys = sorted(set(d1) & set(d2) & set(d3) & set(d4) & set(d5) & set(d6))

# Values per method
vals1 = [d1[k][0] for k in keys]
vals2 = [d2[k][0] for k in keys]
vals3 = [d3[k][0] for k in keys]
vals4 = [d4[k][0] for k in keys]
vals5 = [d5[k][0] for k in keys]
vals6 = [d6[k][0] for k in keys]

# Okabe–Ito colorblind safe palette
colors = [
    "#E69F00",  # orange
    "#56B4E9",  # sky blue
    "#009E73",  # green
    "#F0E442",  # yellow
    "#0072B2",  # blue
    "#D55E00"   # vermillion
]

labels = ["W/O CL", "LwF", "GR", "EWC", "Replay", "SI"]

plt.figure(figsize=(12, 6))
boxplots = plt.boxplot([vals1, vals2, vals3, vals4, vals5, vals6],
                       labels=labels,
                       patch_artist=True,
                       showmeans=True)

# Apply colors
for patch, color in zip(boxplots["boxes"], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

for median in boxplots["medians"]:
    median.set(color="black", linewidth=2)

for mean in boxplots["means"]:
    mean.set(marker="o", markerfacecolor="black", markeredgecolor="black", markersize=5)

plt.ylabel("Domain Training Cost", fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
# plt.title("Domain Training Cost — Boxplot Across Methods (toggle)")
plt.grid(axis="y", linestyle="--", alpha=0.6)

plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/Domain_Training_Cost_w2b_boxplot.png", dpi=200)
plt.show()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Load results
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_toggle.json') as f: data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_toggle_alpha_1.0_T_4.0.json') as f: data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_toggle.json') as f: data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_toggle.json') as f: data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_toggle.json') as f: data5 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_SI_toggle.json') as f: data6 = json.load(f)

# Sub-dicts
d1, d2, d3, d4, d5, d6 = (data1["domain_training_cost"],
                          data2["domain_training_cost"],
                          data3["domain_training_cost"],
                          data4["domain_training_cost"],
                          data5["domain_training_cost"],
                          data6["domain_training_cost"])

# Common keys
keys = sorted(set(d1) & set(d2) & set(d3) & set(d4) & set(d5) & set(d6))

# Values per method
vals1 = [d1[k][0] for k in keys]
vals2 = [d2[k][0] for k in keys]
vals3 = [d3[k][0] for k in keys]
vals4 = [d4[k][0] for k in keys]
vals5 = [d5[k][0] for k in keys]
vals6 = [d6[k][0] for k in keys]

# Okabe–Ito colorblind safe palette
colors = [
    "#E69F00",  # orange
    "#56B4E9",  # sky blue
    "#009E73",  # green
    "#F0E442",  # yellow
    "#0072B2",  # blue
    "#D55E00"   # vermillion
]

labels = ["W/O CL", "LwF", "GR", "EWC", "Replay", "SI"]

plt.figure(figsize=(12, 6))
boxplots = plt.boxplot([vals1, vals2, vals3, vals4, vals5, vals6],
                       labels=labels,
                       patch_artist=True,
                       showmeans=True)

# Apply colors
for patch, color in zip(boxplots["boxes"], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

for median in boxplots["medians"]:
    median.set(color="black", linewidth=2)

for mean in boxplots["means"]:
    mean.set(marker="o", markerfacecolor="black", markeredgecolor="black", markersize=5)

plt.ylabel("Domain Training Cost", fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
# plt.title("Domain Training Cost — Boxplot Across Methods (toggle)")
plt.grid(axis="y", linestyle="--", alpha=0.6)

plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/Domain_Training_Cost_toggle_boxplot.png", dpi=200)
plt.show()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_toggle.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_toggle_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_toggle.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_toggle.json', 'r') as f:
    data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_toggle.json', 'r') as f:
    data5 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_SI_toggle.json', 'r') as f:
    data6 = json.load(f)

# Pull the sub-dicts
d1 = data1["domain_training_cost"]
d2 = data2["domain_training_cost"]
d3 = data3["domain_training_cost"]
d4 = data4["domain_training_cost"]
d5 = data5["domain_training_cost"]
d6 = data6["domain_training_cost"]
# Use the intersection of keys (and sort for stable order)
keys = sorted(set(d1) & set(d2) & set(d3) & set(d4))

# Extract scalar values (each list has one number)
vals1 = [d1[k][0] for k in keys]
vals2 = [d2[k][0] for k in keys]
vals3 = [d3[k][0] for k in keys]
vals4 = [d4[k][0] for k in keys]
vals5 = [d5[k][0] for k in keys]

x = np.arange(len(keys))
width = 0.2

plt.figure(figsize=(20, 8))
plt.bar(x - 1.5*width, vals1, width, label="W/O CL", color="blue")
plt.bar(x - 0.5*width, vals2, width, label="LwF",   color="orange")
plt.bar(x + 0.5*width,  vals3, width, label="GR",    color="purple")
plt.bar(x + 1.5*width,  vals4, width, label="EWC",   color="brown")
plt.bar(x + 2.5*width,  vals5, width, label="REPLAY",   color="skyblue")

plt.xticks(x, keys, rotation=75, ha="right")
plt.ylabel("Training Cost")
plt.title("Domain Training Cost — Comparison Across Methods (toggle)")
plt.legend()
plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/Domain_Training_Cost_toggle_comparison.png")
plt.show()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_b2w.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_b2w_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_b2w.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Attention_EWC_b2w.json', 'r') as f:
    data4 = json.load(f)


# Pull the sub-dicts
d1 = data1["domain_training_cost"]
d2 = data2["domain_training_cost"]
d3 = data3["domain_training_cost"]
d4 = data4["domain_training_cost"]

# Use the intersection of keys (and sort for stable order)
keys = sorted(set(d1) & set(d2) & set(d3) & set(d4))

# Extract scalar values (each list has one number)
vals1 = [d1[k][0] for k in keys]
vals2 = [d2[k][0] for k in keys]
vals3 = [d3[k][0] for k in keys]
vals4 = [d4[k][0] for k in keys]

x = np.arange(len(keys))
width = 0.2

plt.figure(figsize=(20, 8))
plt.bar(x - 1.5*width, vals1, width, label="W/O CL", color="blue")
plt.bar(x - 0.5*width, vals2, width, label="LwF",   color="orange")
plt.bar(x + 0.5*width,  vals3, width, label="GR",    color="purple")
plt.bar(x + 1.5*width,  vals4, width, label="EWC",   color="brown")

plt.xticks(x, keys, rotation=75, ha="right")
plt.ylabel("Training Cost")
plt.title("Domain Training Cost — Comparison Across Methods (b2w)")
plt.legend()
plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/Domain_Training_Cost_b2w_comparison.png")
plt.show()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_w2b.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_w2b_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_w2b.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Attention_EWC_w2b.json', 'r') as f:
    data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_w2b.json', 'r') as f:
    data5 = json.load(f)

# Pull the sub-dicts
d1 = data1["domain_training_cost"]
d2 = data2["domain_training_cost"]
d3 = data3["domain_training_cost"]
d4 = data4["domain_training_cost"]
d5 = data5["domain_training_cost"]

# Use the intersection of keys (and sort for stable order)
keys = sorted(set(d1) & set(d2) & set(d3) & set(d4))

# Extract scalar values (each list has one number)
vals1 = [d1[k][0] for k in keys]
vals2 = [d2[k][0] for k in keys]
vals3 = [d3[k][0] for k in keys]
vals4 = [d4[k][0] for k in keys]
vals5 = [d5[k][0] for k in keys]

x = np.arange(len(keys))
width = 0.2

plt.figure(figsize=(20, 8))
plt.bar(x - 1.5*width, vals1, width, label="W/O CL", color="blue")
plt.bar(x - 0.5*width, vals2, width, label="LwF",   color="orange")
plt.bar(x + 0.5*width,  vals3, width, label="GR",    color="purple")
plt.bar(x + 1.5*width,  vals4, width, label="EWC",   color="brown")
plt.bar(x + 2.5*width,  vals5, width, label="REPLAY",   color="skyblue")

plt.xticks(x, keys, rotation=75, ha="right")
plt.ylabel("Training Cost")
plt.title("Domain Training Cost — Comparison Across Methods (w2b)")
plt.legend()
plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/Domain_Training_Cost_w2b_comparison.png")
plt.show()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_random.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_random_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_random.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_random.json', 'r') as f:
    data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_random.json', 'r') as f:
    data5 = json.load(f)


# Pull the sub-dicts
d1 = data1["domain_training_cost"]
d2 = data2["domain_training_cost"]
d3 = data3["domain_training_cost"]
d4 = data4["domain_training_cost"]
d5 = data5["domain_training_cost"]

# Use the intersection of keys (and sort for stable order)
keys = sorted(set(d1) & set(d2) & set(d3) & set(d4))

# Extract scalar values (each list has one number)
vals1 = [d1[k][0] for k in keys]
vals2 = [d2[k][0] for k in keys]
vals3 = [d3[k][0] for k in keys]
vals4 = [d4[k][0] for k in keys]
vals5 = [d5[k][0] for k in keys]

x = np.arange(len(keys))
width = 0.2

plt.figure(figsize=(20, 8))
plt.bar(x - 1.5*width, vals1, width, label="W/O CL", color="blue")
plt.bar(x - 0.5*width, vals2, width, label="LwF",   color="orange")
plt.bar(x + 0.5*width,  vals3, width, label="GR",    color="purple")
plt.bar(x + 1.5*width,  vals4, width, label="EWC",   color="brown")
plt.bar(x + 2.5*width,  vals5, width, label="REPLAY",   color="skyblue")

plt.xticks(x, keys, rotation=75, ha="right")
plt.ylabel("Training Cost")
plt.title("Domain Training Cost — Comparison Across Methods (random)")
plt.legend()
plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/Domain_Training_Cost_random_comparison.png")
plt.show()

# %% [markdown]
# ## Utility based measuremnt

# %%
import json
import matplotlib.pyplot as plt

# Load data
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_toggle.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_toggle_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_toggle.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_toggle.json', 'r') as f:
    data4 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Replay_REPLAY_toggle.json', 'r') as f:
    data5 = json.load(f)

# Okabe–Ito color-blind–friendly palette
COLORS = {
    "W/O CL": "#0072B2",   # blue
    "LwF":    "#E69F00",   # orange
    "GR":     "#D55E00",   # vermilion
    "EWC":    "#CC79A7",   # reddish-purple
    "Replay": "#009E73",   # bluish-green
}

plt.figure(figsize=(8,6), dpi=150)

plt.plot(data1["Utility"], label="W/O CL", color=COLORS["W/O CL"],
         lw=2.5, ls="-", marker="o", markersize=5)
plt.plot(data2["Utility"], label="LwF", color=COLORS["LwF"],
         lw=2.5, ls="--", marker="^", markersize=5)
plt.plot(data3["Utility"], label="GR", color=COLORS["GR"],
         lw=2.5, ls="-.", marker="s", markersize=5)
plt.plot(data4["Utility"], label="EWC", color=COLORS["EWC"],
         lw=2.5, ls=":", marker="D", markersize=5)
plt.plot(data5["Utility_WP_2"], label="Replay", color=COLORS["Replay"],
         lw=2.5, ls="-", marker="*", markersize=6)

plt.xlabel("Domain Index", fontsize=16)
plt.ylabel("Utility", fontsize=16)
plt.title("Utility Values Comparison (Toggle)", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True, alpha=0.3)

plt.legend(title="Method", fontsize=12, title_fontsize=12,
           frameon=True, edgecolor="black", loc="upper right")

plt.tight_layout()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_toggle_comparison_cb.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_random.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_random_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_random.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Attention_EWC_random.json', 'r') as f:
    data4 = json.load(f)


plt.plot(data1["Utility"], label="W/O CL", color="blue")
plt.plot(data2["Utility"], label="LwF", color="orange")
plt.plot(data3["Utility"], label="GR", color="purple")
plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (random)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_random_comparison.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_b2w.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_b2w_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_b2w.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Attention_EWC_b2w.json', 'r') as f:
    data4 = json.load(f)


plt.plot(data1["Utility"], label="W/O CL", color="blue")
plt.plot(data2["Utility"], label="LwF", color="orange")
plt.plot(data3["Utility"], label="GR", color="purple")
plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (b2w)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_b2w_comparison.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_WCL_w2b.json', 'r') as f:
    data1 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_w2b_alpha_1.0_T_4.0.json', 'r') as f:
    data2 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_GR_w2b.json', 'r') as f:
    data3 = json.load(f)
with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_Attention_EWC_w2b.json', 'r') as f:
    data4 = json.load(f)


plt.plot(data1["Utility"], label="W/O CL", color="blue")
plt.plot(data2["Utility"], label="LwF", color="orange")
plt.plot(data3["Utility"], label="GR", color="purple")
plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (w2b)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_w2b_comparison.png")
plt.show()

# %% [markdown]
# ## Compare between P heavy, S heavy, and E heavy Utility values

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_w2b.json', 'r') as f:
    data1 = json.load(f)


plt.plot(data1["Utility_WP_2"], label="wP=2,wS=0,wE=0", color="blue")
plt.plot(data1["Utility_WS_2"], label="wP=,wS=2,wE=0", color="orange")
plt.plot(data1["Utility_WE_2"], label="wP=0,wS=0,wE=2", color="purple")
# plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (w2b): How much each componet explain Utility)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_w2b_comparison_eachcomponent_EWC.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_b2w.json', 'r') as f:
    data1 = json.load(f)


plt.plot(data1["Utility_WP_2"], label="wP=2,wS=0,wE=0", color="blue")
plt.plot(data1["Utility_WS_2"], label="wP=,wS=2,wE=0", color="orange")
plt.plot(data1["Utility_WE_2"], label="wP=0,wS=0,wE=2", color="purple")
# plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (b2w): How much each componet explain Utility)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_b2w_comparison_eachcomponent_EWC.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_random.json', 'r') as f:
    data1 = json.load(f)


plt.plot(data1["Utility_WP_2"], label="wP=2,wS=0,wE=0", color="blue")
plt.plot(data1["Utility_WS_2"], label="wP=,wS=2,wE=0", color="orange")
plt.plot(data1["Utility_WE_2"], label="wP=0,wS=0,wE=2", color="purple")
# plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (random): How much each componet explain Utility)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_random_comparison_eachcomponent_EWC.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_EWC_toggle.json', 'r') as f:
    data1 = json.load(f)


plt.plot(data1["Utility_WP_2"], label="wP=2,wS=0,wE=0", color="blue")
plt.plot(data1["Utility_WS_2"], label="wP=,wS=2,wE=0", color="orange")
plt.plot(data1["Utility_WE_2"], label="wP=0,wS=0,wE=2", color="purple")
# plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (toggle): How much each componet explain Utility)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_toggle_comparison_eachcomponent_EWC.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_random_alpha_1.0_T_4.0.json', 'r') as f:
    data1 = json.load(f)


plt.plot(data1["Utility_WP_2"], label="wP=2,wS=0,wE=0", color="blue")
plt.plot(data1["Utility_WS_2"], label="wP=0,wS=2,wE=0", color="orange")
plt.plot(data1["Utility_WE_2"], label="wP=0,wS=0,wE=2", color="purple")
# plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (random): How much each componet explain Utility)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_random_comparison_eachcomponent_LwF.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_b2w_alpha_1.0_T_4.0.json', 'r') as f:
    data1 = json.load(f)


plt.plot(data1["Utility_WP_2"], label="wP=2,wS=0,wE=0", color="blue")
plt.plot(data1["Utility_WS_2"], label="wP=0,wS=2,wE=0", color="orange")
plt.plot(data1["Utility_WE_2"], label="wP=0,wS=0,wE=2", color="purple")
# plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (b2w): How much each componet explain Utility)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_b2w_comparison_eachcomponent_LwF.png")
plt.show()

# %%
import json
import matplotlib.pyplot as plt


with open('/proj/sourasb-220503/IoT_attack_CL_IDS/results/1_experiment_results_LSTM_LwF_b2w_alpha_1.0_T_4.0.json', 'r') as f:
    data1 = json.load(f)


plt.plot(data1["Utility_WP_2"], label="wP=2,wS=0,wE=0", color="blue")
plt.plot(data1["Utility_WS_2"], label="wP=0,wS=2,wE=0", color="orange")
plt.plot(data1["Utility_WE_2"], label="wP=0,wS=0,wE=2", color="purple")
# plt.plot(data4["Utility"], label="EWC", color="brown")
plt.xlabel("Domain Index")
plt.ylabel("Utility")
plt.title("Utility Values Comparison (b2w): How much each componet explain Utility)")
plt.legend()
plt.savefig("/proj/sourasb-220503/IoT_attack_CL_IDS/results/plots/utility_b2w_comparison_eachcomponent_LwF.png")
plt.show()
