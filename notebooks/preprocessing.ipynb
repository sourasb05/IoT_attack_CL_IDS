# %% [markdown]
# # Automated CSV File Aggregation and Renaming from Subfolders
#
# This code automates the process of aggregating CSV files from multiple subfolders and renaming them with a consistent naming pattern. It is particularly useful when data files are stored in a structured directory (e.g., from different runs or scenarios) and need to be consolidated into a single destination folder with sequential and descriptive file names.
#
# ## Purpose
#
# The primary objectives of this code are to:
#
# 1. **Define Source and Destination Paths:**
#    The code sets a `source_path` (the directory containing multiple subfolders) and a `dest_path` (the directory where the renamed CSV files will be saved). It also defines a base string (`new_file_string`) used as part of the new filenames.
#
# 2. **Ensure Destination Directory Exists:**
#    The code makes sure that the destination directory is available by creating it if it does not already exist.
#
# 3. **List and Sort Subfolders:**
#    It scans the source directory for subfolders (ignoring any files) and sorts them. The assumption is that these subfolders are organized in a predictable naming pattern such as `base-5-1`, `base-5-2`, etc.
#
# 4. **Extract and Rename CSV Files:**
#    For each subfolder, the script:
#    - Constructs the path to the CSV file (specifically named `features_timeseries_60_sec.csv`).
#    - Checks if the CSV file exists.
#    - Reads the CSV file into a pandas DataFrame.
#    - Constructs a new filename by appending an incremental number to the base string.
#    - Saves the DataFrame as a new CSV file in the destination directory.
#    - Provides console feedback about the operation.

# %%
import os
import pandas as pd

# %%
# 1) Define source and destination paths
# source_path = "/Users/souba636/Documents/vinnova_project_python/data-traces3-NOMS-2025/worst_parent/5/oo"
source_path = "/Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc"

dest_path = "/Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec"

new_file_string = "blackhole_var5_dec"

# Make sure the destination folder exists
os.makedirs(dest_path, exist_ok=True)

# 2) List all subfolders (assuming each subfolder is named, for example, base-5-1, base-5-2, etc.)
#    If they're named differently, you'll need to adapt this logic.
subfolders = sorted(
    [folder for folder in os.listdir(source_path) 
     if os.path.isdir(os.path.join(source_path, folder))]
)

# 3) Iterate over subfolders, read the CSV, and save to new location
for i, folder in enumerate(subfolders, start=1):
    folder_path = os.path.join(source_path, folder)
    csv_file = os.path.join(folder_path, "features_timeseries_60_sec.csv")
    
    if os.path.exists(csv_file):
        # Read CSV
        df = pd.read_csv(csv_file)
        
        # Create new file name
        new_name = f"{new_file_string}_{i}_features_timeseries_60_sec.csv"
        dest_file = os.path.join(dest_path, new_name)
        
        # Save renamed CSV
        df.to_csv(dest_file, index=False)
        
        print(f"Copied and renamed {csv_file} to {dest_file}")
    else:
        print(f"No features_timeseries_60_sec.csv found in {folder_path}")
# Out:
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/1/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_1_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/10/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_2_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/11/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_3_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/12/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_4_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/13/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_5_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/14/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_6_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/15/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_7_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/16/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_8_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/17/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_9_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/18/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_10_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/19/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_11_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/2/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_12_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/20/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_13_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/3/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_14_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/4/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_15_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/5/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_16_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/6/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_17_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/7/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_18_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/8/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_19_features_timeseries_60_sec.csv
# Copied and renamed /Users/souba636/Documents/vinnova_project_python/data/blackhole_new/5/gc/9/features_timeseries_60_sec.csv to /Users/souba636/Documents/vinnova_project_python/data/scenario/blackhole_var5_dec/blackhole_var5_dec_20_features_timeseries_60_sec.csv

# %% [markdown]
# # CSV Leave-One-Out Merge Script
#
# This Python script merges multiple CSV files in a folder into training and validation datasets using a leave-one-out cross-validation strategy. It repeats the process 10 times, each time keeping a different file as the validation set.

# %% [markdown]
# ---
#
# ## Features
#
# - **Automatic label column detection**
#   Supports `"label"`, `"class"`, `"target"`, `"y"`, or any binary column.
# - **Leave-One-Out Cross-Validation**
#   Each round selects one CSV as **validation** and merges the remaining CSVs into **training**.
# - **Class Ordering**
#   - Training data: All **class 0 samples** first, followed by **class 1 samples**.
#   - Validation data: Ordered in the same way.
# - **Configurable Parameters**
#   Folder path, number of rounds, file pattern, and label column name.
# - **Output**
#   For each round, saves:
#   - `run_XX_train.csv`
#   - `run_XX_val.csv`
#
# ---
#
# ## Configuration
#
# Update the following section in the script:
#
# ```python
# FOLDER = Path("/path/to/your/folder")   # Path containing your CSV files
# OUTDIR = FOLDER / "merged_runs"         # Output folder for merged files
# N_ROUNDS = 10                           # Number of leave-one-out rounds
# LABEL_COL = None                        # Set manually if known (e.g. "label"), else auto-detected
# CSV_GLOB = "*.csv"                      # Pattern to match CSV files

# %% [markdown]
# ## Remove duplicate rows from train and test set

# %%
from pathlib import Path
import pandas as pd

BASE = Path("/Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario")

# Get subfolders as Path objects
folders = [f for f in BASE.iterdir() if f.is_dir()]
print("Scenario folders:", [f.name for f in folders])

for folder in folders:
    train_files = sorted(folder.glob("run_*_train.csv"))
    val_files   = sorted(folder.glob("run_*_val.csv"))

    if not train_files or not val_files:
        print(f"[WARN] Skipping {folder.name} — no run CSVs found.")
        continue

    print(f"Processing scenario: {folder.name}")

    for tr_file, va_file in zip(train_files, val_files):
        # Read CSVs
        df_train = pd.read_csv(tr_file).drop(columns=["Unnamed: 0"], errors="ignore")
        df_val   = pd.read_csv(va_file).drop(columns=["Unnamed: 0"], errors="ignore")

        # Remove duplicate rows within each set
        df_train = df_train.drop_duplicates(ignore_index=True)
        df_val   = df_val.drop_duplicates(ignore_index=True)

        # Optional: Remove rows that appear in both train and val (cross-leakage)
        common_rows = df_val.merge(df_train, how="inner")
        if not common_rows.empty:
            df_val = df_val[~df_val.apply(tuple, axis=1).isin(common_rows.apply(tuple, axis=1))]
            print(f"  Removed {len(common_rows)} overlapping rows from validation set in {va_file.name}")

        # Save cleaned CSVs
        df_train.to_csv(tr_file, index=False)
        df_val.to_csv(va_file, index=False)

        print(f"  Cleaned: {tr_file.name} ({len(df_train)} rows), {va_file.name} ({len(df_val)} rows)")

print("Duplicate removal completed for all scenarios.")
# Out:
# Scenario folders: ['localrepair_var20_dec', 'worstparent_var10_dec', 'disflooding_var5_base', 'disflooding_var5_dec', 'worstparent_var5_dec', 'worstparent_var15_dec', 'blackhole_var20_dec', 'worstparent_var20_base', 'localrepair_var15_base', 'localrepair_var5_base', 'disflooding_var20_dec', 'blackhole_var15_base', 'localrepair_var5_dec', 'worstparent_var10_base', 'blackhole_var5_dec', 'disflooding_var5_oo', 'blackhole_var5_base', 'disflooding_var15_base', 'worstparent_var20_oo', 'disflooding_var20_oo', 'worstparent_var10_oo', 'disflooding_var20_base', 'disflooding_var10_oo', 'disflooding_var15_dec', 'localrepair_var10_base', 'localrepair_var5_oo', 'worstparent_var5_base', 'disflooding_var10_dec', 'blackhole_var20_base', 'disflooding_var15_oo', 'worstparent_var15_oo', 'blackhole_var5_oo', 'worstparent_var15_base', 'localrepair_var20_oo', 'blackhole_var20_oo', 'localrepair_var20_base', 'worstparent_var5_oo', 'localrepair_var15_dec', 'localrepair_var10_oo', 'disflooding_var10_base', 'blackhole_var10_oo', 'blackhole_var10_dec', 'localrepair_var10_dec', 'worstparent_var20_dec', 'blackhole_var15_dec', 'localrepair_var15_oo', 'blackhole_var10_base', 'blackhole_var15_oo']
# Processing scenario: localrepair_var20_dec
#   Removed 3 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (16335 rows), run_01_val.csv (848 rows)
#   Cleaned: run_02_train.csv (16324 rows), run_02_val.csv (859 rows)
#   Removed 2 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (16323 rows), run_03_val.csv (860 rows)
#   Cleaned: run_04_train.csv (16343 rows), run_04_val.csv (840 rows)
#   Cleaned: run_05_train.csv (16368 rows), run_05_val.csv (815 rows)
#   Removed 4 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (16328 rows), run_06_val.csv (855 rows)
#   Removed 1 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (16314 rows), run_07_val.csv (869 rows)
#   Cleaned: run_08_train.csv (16328 rows), run_08_val.csv (855 rows)
#   Removed 5 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (16323 rows), run_09_val.csv (860 rows)
#   Removed 1 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (16297 rows), run_10_val.csv (886 rows)
# Processing scenario: worstparent_var10_dec
#   Removed 23 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (14192 rows), run_01_val.csv (761 rows)
#   Removed 2 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (14112 rows), run_02_val.csv (841 rows)
#   Removed 43 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (14273 rows), run_03_val.csv (680 rows)
#   Cleaned: run_04_train.csv (14195 rows), run_04_val.csv (758 rows)
#   Removed 51 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (14216 rows), run_05_val.csv (737 rows)
#   Removed 2 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (14212 rows), run_06_val.csv (741 rows)
#   Removed 2 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (14373 rows), run_07_val.csv (580 rows)
#   Removed 2 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (14158 rows), run_08_val.csv (795 rows)
#   Removed 23 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (14200 rows), run_09_val.csv (753 rows)
#   Removed 2 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (14149 rows), run_10_val.csv (804 rows)
# Processing scenario: disflooding_var5_base
#   Removed 71 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (9825 rows), run_01_val.csv (437 rows)
#   Removed 43 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (9745 rows), run_02_val.csv (517 rows)
#   Removed 125 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (9711 rows), run_03_val.csv (551 rows)
#   Removed 119 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (9775 rows), run_04_val.csv (487 rows)
#   Removed 85 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (9717 rows), run_05_val.csv (545 rows)
#   Removed 68 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (9735 rows), run_06_val.csv (527 rows)
#   Removed 44 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (9684 rows), run_07_val.csv (578 rows)
#   Removed 117 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (9786 rows), run_08_val.csv (476 rows)
#   Removed 79 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (9762 rows), run_09_val.csv (500 rows)
#   Removed 83 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (9748 rows), run_10_val.csv (514 rows)
# Processing scenario: disflooding_var5_dec
#   Removed 83 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (10028 rows), run_01_val.csv (587 rows)
#   Removed 58 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (10148 rows), run_02_val.csv (467 rows)
#   Removed 95 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (10114 rows), run_03_val.csv (501 rows)
#   Removed 82 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (10033 rows), run_04_val.csv (582 rows)
#   Removed 59 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (10091 rows), run_05_val.csv (524 rows)
#   Removed 73 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (10103 rows), run_06_val.csv (512 rows)
#   Removed 69 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (10082 rows), run_07_val.csv (533 rows)
#   Removed 2 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (10228 rows), run_08_val.csv (387 rows)
#   Removed 88 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (10167 rows), run_09_val.csv (448 rows)
#   Removed 1 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (10114 rows), run_10_val.csv (501 rows)
# Processing scenario: worstparent_var5_dec
#   Removed 112 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (4148 rows), run_01_val.csv (111 rows)
#   Removed 118 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (4130 rows), run_02_val.csv (129 rows)
#   Removed 137 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (4107 rows), run_03_val.csv (152 rows)
#   Removed 125 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (4043 rows), run_04_val.csv (216 rows)
#   Removed 106 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (4086 rows), run_05_val.csv (173 rows)
#   Removed 138 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (4091 rows), run_06_val.csv (168 rows)
#   Removed 112 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (4141 rows), run_07_val.csv (118 rows)
#   Removed 121 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (4093 rows), run_08_val.csv (166 rows)
#   Removed 124 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (4090 rows), run_09_val.csv (169 rows)
#   Removed 117 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (4074 rows), run_10_val.csv (185 rows)
# Processing scenario: worstparent_var15_dec
#   Cleaned: run_01_train.csv (16979 rows), run_01_val.csv (892 rows)
#   Cleaned: run_02_train.csv (16976 rows), run_02_val.csv (895 rows)
#   Cleaned: run_03_train.csv (16979 rows), run_03_val.csv (892 rows)
#   Cleaned: run_04_train.csv (16973 rows), run_04_val.csv (898 rows)
#   Cleaned: run_05_train.csv (16983 rows), run_05_val.csv (888 rows)
#   Cleaned: run_06_train.csv (16983 rows), run_06_val.csv (888 rows)
#   Cleaned: run_07_train.csv (16973 rows), run_07_val.csv (898 rows)
#   Cleaned: run_08_train.csv (16971 rows), run_08_val.csv (900 rows)
#   Cleaned: run_09_train.csv (16972 rows), run_09_val.csv (899 rows)
#   Cleaned: run_10_train.csv (16973 rows), run_10_val.csv (898 rows)
# Processing scenario: blackhole_var20_dec
#   Cleaned: run_01_train.csv (10420 rows), run_01_val.csv (555 rows)
#   Cleaned: run_02_train.csv (10418 rows), run_02_val.csv (557 rows)
#   Cleaned: run_03_train.csv (10418 rows), run_03_val.csv (557 rows)
#   Cleaned: run_04_train.csv (10417 rows), run_04_val.csv (558 rows)
#   Cleaned: run_05_train.csv (10538 rows), run_05_val.csv (437 rows)
#   Cleaned: run_06_train.csv (10417 rows), run_06_val.csv (558 rows)
#   Cleaned: run_07_train.csv (10418 rows), run_07_val.csv (557 rows)
#   Cleaned: run_08_train.csv (10417 rows), run_08_val.csv (558 rows)
#   Cleaned: run_09_train.csv (10420 rows), run_09_val.csv (555 rows)
#   Cleaned: run_10_train.csv (10421 rows), run_10_val.csv (554 rows)
# Processing scenario: worstparent_var20_base
#   Cleaned: run_01_train.csv (17095 rows), run_01_val.csv (900 rows)
#   Cleaned: run_02_train.csv (17095 rows), run_02_val.csv (900 rows)
#   Cleaned: run_03_train.csv (17095 rows), run_03_val.csv (900 rows)
#   Cleaned: run_04_train.csv (17095 rows), run_04_val.csv (900 rows)
#   Cleaned: run_05_train.csv (17095 rows), run_05_val.csv (900 rows)
#   Cleaned: run_06_train.csv (17095 rows), run_06_val.csv (900 rows)
#   Cleaned: run_07_train.csv (17095 rows), run_07_val.csv (900 rows)
#   Cleaned: run_08_train.csv (17095 rows), run_08_val.csv (900 rows)
#   Cleaned: run_09_train.csv (17095 rows), run_09_val.csv (900 rows)
#   Cleaned: run_10_train.csv (17095 rows), run_10_val.csv (900 rows)
# Processing scenario: localrepair_var15_base
#   Removed 1 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (15441 rows), run_01_val.csv (768 rows)
#   Removed 4 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (15396 rows), run_02_val.csv (813 rows)
#   Removed 9 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (15390 rows), run_03_val.csv (819 rows)
#   Cleaned: run_04_train.csv (15361 rows), run_04_val.csv (848 rows)
#   Removed 4 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (15404 rows), run_05_val.csv (805 rows)
#   Removed 42 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (15463 rows), run_06_val.csv (746 rows)
#   Removed 5 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (15363 rows), run_07_val.csv (846 rows)
#   Removed 8 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (15438 rows), run_08_val.csv (771 rows)
#   Cleaned: run_09_train.csv (15363 rows), run_09_val.csv (846 rows)
#   Removed 9 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (15500 rows), run_10_val.csv (709 rows)
# Processing scenario: localrepair_var5_base
#   Removed 81 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (5049 rows), run_01_val.csv (167 rows)
#   Removed 91 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (5031 rows), run_02_val.csv (185 rows)
#   Removed 128 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (4851 rows), run_03_val.csv (365 rows)
#   Removed 87 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (4915 rows), run_04_val.csv (301 rows)
#   Removed 72 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (4815 rows), run_05_val.csv (401 rows)
#   Removed 133 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (4988 rows), run_06_val.csv (228 rows)
#   Removed 86 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (4922 rows), run_07_val.csv (294 rows)
#   Removed 83 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (5046 rows), run_08_val.csv (170 rows)
#   Removed 140 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (5079 rows), run_09_val.csv (137 rows)
#   Removed 104 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (5113 rows), run_10_val.csv (103 rows)
# Processing scenario: disflooding_var20_dec
#   Cleaned: run_01_train.csv (16348 rows), run_01_val.csv (861 rows)
#   Cleaned: run_02_train.csv (16349 rows), run_02_val.csv (860 rows)
#   Cleaned: run_03_train.csv (16348 rows), run_03_val.csv (861 rows)
#   Cleaned: run_04_train.csv (16349 rows), run_04_val.csv (860 rows)
#   Cleaned: run_05_train.csv (16348 rows), run_05_val.csv (861 rows)
#   Cleaned: run_06_train.csv (16348 rows), run_06_val.csv (861 rows)
#   Cleaned: run_07_train.csv (16348 rows), run_07_val.csv (861 rows)
#   Cleaned: run_08_train.csv (16348 rows), run_08_val.csv (861 rows)
#   Cleaned: run_09_train.csv (16348 rows), run_09_val.csv (861 rows)
#   Cleaned: run_10_train.csv (16348 rows), run_10_val.csv (861 rows)
# Processing scenario: blackhole_var15_base
#   Cleaned: run_01_train.csv (10123 rows), run_01_val.csv (513 rows)
#   Cleaned: run_02_train.csv (10088 rows), run_02_val.csv (548 rows)
#   Cleaned: run_03_train.csv (10090 rows), run_03_val.csv (546 rows)
#   Cleaned: run_04_train.csv (10098 rows), run_04_val.csv (538 rows)
#   Cleaned: run_05_train.csv (10094 rows), run_05_val.csv (542 rows)
#   Removed 7 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (10114 rows), run_06_val.csv (522 rows)
#   Cleaned: run_07_train.csv (10103 rows), run_07_val.csv (533 rows)
#   Cleaned: run_08_train.csv (10122 rows), run_08_val.csv (514 rows)
#   Cleaned: run_09_train.csv (10106 rows), run_09_val.csv (530 rows)
#   Removed 7 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (10107 rows), run_10_val.csv (529 rows)
# Processing scenario: localrepair_var5_dec
#   Removed 100 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (6467 rows), run_01_val.csv (345 rows)
#   Removed 71 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (6517 rows), run_02_val.csv (295 rows)
#   Removed 193 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (6553 rows), run_03_val.csv (259 rows)
#   Removed 108 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (6450 rows), run_04_val.csv (362 rows)
#   Removed 184 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (6571 rows), run_05_val.csv (241 rows)
#   Removed 176 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (6532 rows), run_06_val.csv (280 rows)
#   Removed 106 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (6690 rows), run_07_val.csv (122 rows)
#   Removed 100 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (6507 rows), run_08_val.csv (305 rows)
#   Removed 140 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (6529 rows), run_09_val.csv (283 rows)
#   Removed 109 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (6511 rows), run_10_val.csv (301 rows)
# Processing scenario: worstparent_var10_base
#   Removed 34 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (13609 rows), run_01_val.csv (731 rows)
#   Removed 3 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (13538 rows), run_02_val.csv (802 rows)
#   Removed 44 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (13635 rows), run_03_val.csv (705 rows)
#   Removed 1 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (13620 rows), run_04_val.csv (720 rows)
#   Removed 49 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (13840 rows), run_05_val.csv (500 rows)
#   Removed 3 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (13566 rows), run_06_val.csv (774 rows)
#   Removed 4 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (13739 rows), run_07_val.csv (601 rows)
#   Removed 7 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (13522 rows), run_08_val.csv (818 rows)
#   Removed 25 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (13661 rows), run_09_val.csv (679 rows)
#   Removed 3 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (13529 rows), run_10_val.csv (811 rows)
# Processing scenario: blackhole_var5_dec
#   Removed 136 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (2382 rows), run_01_val.csv (59 rows)
#   Removed 96 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (2321 rows), run_02_val.csv (120 rows)
#   Removed 99 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (2349 rows), run_03_val.csv (92 rows)
#   Removed 1 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (2227 rows), run_04_val.csv (214 rows)
#   Removed 82 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (2345 rows), run_05_val.csv (96 rows)
#   Removed 98 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (2375 rows), run_06_val.csv (66 rows)
#   Removed 115 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (2353 rows), run_07_val.csv (88 rows)
#   Removed 105 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (2329 rows), run_08_val.csv (112 rows)
#   Removed 111 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (2365 rows), run_09_val.csv (76 rows)
#   Removed 97 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (2303 rows), run_10_val.csv (138 rows)
# Processing scenario: disflooding_var5_oo
#   Removed 70 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (9356 rows), run_01_val.csv (531 rows)
#   Removed 2 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (9359 rows), run_02_val.csv (528 rows)
#   Removed 114 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (9402 rows), run_03_val.csv (485 rows)
#   Removed 81 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (9326 rows), run_04_val.csv (561 rows)
#   Removed 631 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (9887 rows), run_05_val.csv (0 rows)
#   Removed 631 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (9887 rows), run_06_val.csv (0 rows)
#   Removed 52 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (9263 rows), run_07_val.csv (624 rows)
#   Removed 536 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (9887 rows), run_08_val.csv (0 rows)
#   Removed 59 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (9325 rows), run_09_val.csv (562 rows)
#   Removed 536 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (9887 rows), run_10_val.csv (0 rows)
# Processing scenario: blackhole_var5_base
#   Removed 142 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (2319 rows), run_01_val.csv (46 rows)
#   Removed 98 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (2254 rows), run_02_val.csv (111 rows)
#   Removed 99 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (2277 rows), run_03_val.csv (88 rows)
#   Removed 15 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (2161 rows), run_04_val.csv (204 rows)
#   Removed 81 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (2270 rows), run_05_val.csv (95 rows)
#   Removed 93 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (2298 rows), run_06_val.csv (67 rows)
#   Removed 103 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (2258 rows), run_07_val.csv (107 rows)
#   Removed 114 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (2279 rows), run_08_val.csv (86 rows)
#   Removed 109 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (2290 rows), run_09_val.csv (75 rows)
#   Removed 102 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (2239 rows), run_10_val.csv (126 rows)
# Processing scenario: disflooding_var15_base
#   Cleaned: run_01_train.csv (14602 rows), run_01_val.csv (859 rows)
#   Removed 862 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (15461 rows), run_02_val.csv (0 rows)
#   Removed 9 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (14611 rows), run_03_val.csv (850 rows)
#   Cleaned: run_04_train.csv (14607 rows), run_04_val.csv (854 rows)
#   Cleaned: run_05_train.csv (14598 rows), run_05_val.csv (863 rows)
#   Cleaned: run_06_train.csv (14598 rows), run_06_val.csv (863 rows)
#   Removed 9 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (14607 rows), run_07_val.csv (854 rows)
#   Cleaned: run_08_train.csv (14603 rows), run_08_val.csv (858 rows)
#   Cleaned: run_09_train.csv (14596 rows), run_09_val.csv (865 rows)
#   Cleaned: run_10_train.csv (14606 rows), run_10_val.csv (855 rows)
# Processing scenario: worstparent_var20_oo
#   Cleaned: run_01_train.csv (17095 rows), run_01_val.csv (900 rows)
#   Cleaned: run_02_train.csv (17095 rows), run_02_val.csv (900 rows)
#   Cleaned: run_03_train.csv (17095 rows), run_03_val.csv (900 rows)
#   Cleaned: run_04_train.csv (17095 rows), run_04_val.csv (900 rows)
#   Cleaned: run_05_train.csv (17095 rows), run_05_val.csv (900 rows)
#   Cleaned: run_06_train.csv (17095 rows), run_06_val.csv (900 rows)
#   Cleaned: run_07_train.csv (17095 rows), run_07_val.csv (900 rows)
#   Cleaned: run_08_train.csv (17095 rows), run_08_val.csv (900 rows)
#   Cleaned: run_09_train.csv (17095 rows), run_09_val.csv (900 rows)
#   Cleaned: run_10_train.csv (17095 rows), run_10_val.csv (900 rows)
# Processing scenario: disflooding_var20_oo
#   Cleaned: run_01_train.csv (16490 rows), run_01_val.csv (868 rows)
#   Cleaned: run_02_train.csv (16490 rows), run_02_val.csv (868 rows)
#   Cleaned: run_03_train.csv (16490 rows), run_03_val.csv (868 rows)
#   Cleaned: run_04_train.csv (16490 rows), run_04_val.csv (868 rows)
#   Cleaned: run_05_train.csv (16490 rows), run_05_val.csv (868 rows)
#   Cleaned: run_06_train.csv (16490 rows), run_06_val.csv (868 rows)
#   Cleaned: run_07_train.csv (16490 rows), run_07_val.csv (868 rows)
#   Cleaned: run_08_train.csv (16490 rows), run_08_val.csv (868 rows)
#   Cleaned: run_09_train.csv (16490 rows), run_09_val.csv (868 rows)
#   Cleaned: run_10_train.csv (16490 rows), run_10_val.csv (868 rows)
# Processing scenario: worstparent_var10_oo
#   Removed 50 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (14384 rows), run_01_val.csv (712 rows)
#   Removed 2 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (14285 rows), run_02_val.csv (811 rows)
#   Removed 49 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (14357 rows), run_03_val.csv (739 rows)
#   Removed 3 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (14298 rows), run_04_val.csv (798 rows)
#   Removed 60 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (14364 rows), run_05_val.csv (732 rows)
#   Removed 5 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (14298 rows), run_06_val.csv (798 rows)
#   Removed 3 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (14397 rows), run_07_val.csv (699 rows)
#   Removed 8 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (14326 rows), run_08_val.csv (770 rows)
#   Removed 30 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (14364 rows), run_09_val.csv (732 rows)
#   Removed 5 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (14289 rows), run_10_val.csv (807 rows)
# Processing scenario: disflooding_var20_base
#   Cleaned: run_01_train.csv (15585 rows), run_01_val.csv (866 rows)
#   Cleaned: run_02_train.csv (15585 rows), run_02_val.csv (866 rows)
#   Removed 866 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (16451 rows), run_03_val.csv (0 rows)
#   Cleaned: run_04_train.csv (15585 rows), run_04_val.csv (866 rows)
#   Cleaned: run_05_train.csv (15585 rows), run_05_val.csv (866 rows)
#   Removed 1 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (15586 rows), run_06_val.csv (865 rows)
#   Cleaned: run_07_train.csv (15585 rows), run_07_val.csv (866 rows)
#   Cleaned: run_08_train.csv (15587 rows), run_08_val.csv (864 rows)
#   Cleaned: run_09_train.csv (15585 rows), run_09_val.csv (866 rows)
#   Cleaned: run_10_train.csv (15585 rows), run_10_val.csv (866 rows)
# Processing scenario: disflooding_var10_oo
#   Removed 4 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (14860 rows), run_01_val.csv (730 rows)
#   Cleaned: run_02_train.csv (14819 rows), run_02_val.csv (771 rows)
#   Removed 46 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (14865 rows), run_03_val.csv (725 rows)
#   Removed 2 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (14894 rows), run_04_val.csv (696 rows)
#   Removed 44 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (14843 rows), run_05_val.csv (747 rows)
#   Removed 4 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (14824 rows), run_06_val.csv (766 rows)
#   Cleaned: run_07_train.csv (14757 rows), run_07_val.csv (833 rows)
#   Removed 46 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (14812 rows), run_08_val.csv (778 rows)
#   Removed 5 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (14824 rows), run_09_val.csv (766 rows)
#   Removed 4 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (14844 rows), run_10_val.csv (746 rows)
# Processing scenario: disflooding_var15_dec
#   Cleaned: run_01_train.csv (16296 rows), run_01_val.csv (849 rows)
#   Cleaned: run_02_train.csv (16285 rows), run_02_val.csv (860 rows)
#   Cleaned: run_03_train.csv (16284 rows), run_03_val.csv (861 rows)
#   Cleaned: run_04_train.csv (16285 rows), run_04_val.csv (860 rows)
#   Cleaned: run_05_train.csv (16286 rows), run_05_val.csv (859 rows)
#   Cleaned: run_06_train.csv (16294 rows), run_06_val.csv (851 rows)
#   Cleaned: run_07_train.csv (16286 rows), run_07_val.csv (859 rows)
#   Cleaned: run_08_train.csv (16287 rows), run_08_val.csv (858 rows)
#   Cleaned: run_09_train.csv (16288 rows), run_09_val.csv (857 rows)
#   Cleaned: run_10_train.csv (16291 rows), run_10_val.csv (854 rows)
# Processing scenario: localrepair_var10_base
#   Cleaned: run_01_train.csv (10599 rows), run_01_val.csv (549 rows)
#   Removed 112 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (10677 rows), run_02_val.csv (471 rows)
#   Removed 11 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (10461 rows), run_03_val.csv (687 rows)
#   Removed 77 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (10708 rows), run_04_val.csv (440 rows)
#   Removed 64 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (10553 rows), run_05_val.csv (595 rows)
#   Removed 5 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (10731 rows), run_06_val.csv (417 rows)
#   Removed 3 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (10538 rows), run_07_val.csv (610 rows)
#   Removed 8 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (10664 rows), run_08_val.csv (484 rows)
#   Cleaned: run_09_train.csv (10668 rows), run_09_val.csv (480 rows)
#   Removed 18 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (10545 rows), run_10_val.csv (603 rows)
# Processing scenario: localrepair_var5_oo
#   Removed 83 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (4520 rows), run_01_val.csv (193 rows)
#   Removed 61 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (4574 rows), run_02_val.csv (139 rows)
#   Removed 155 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (4531 rows), run_03_val.csv (182 rows)
#   Removed 116 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (4502 rows), run_04_val.csv (211 rows)
#   Removed 152 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (4560 rows), run_05_val.csv (153 rows)
#   Removed 119 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (4400 rows), run_06_val.csv (313 rows)
#   Removed 103 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (4606 rows), run_07_val.csv (107 rows)
#   Removed 84 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (4513 rows), run_08_val.csv (200 rows)
#   Removed 152 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (4538 rows), run_09_val.csv (175 rows)
#   Removed 99 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (4583 rows), run_10_val.csv (130 rows)
# Processing scenario: worstparent_var5_base
#   Removed 133 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (4413 rows), run_01_val.csv (118 rows)
#   Removed 111 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (4415 rows), run_02_val.csv (116 rows)
#   Removed 156 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (4383 rows), run_03_val.csv (148 rows)
#   Removed 104 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (4309 rows), run_04_val.csv (222 rows)
#   Removed 93 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (4263 rows), run_05_val.csv (268 rows)
#   Removed 132 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (4340 rows), run_06_val.csv (191 rows)
#   Removed 68 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (4359 rows), run_07_val.csv (172 rows)
#   Removed 71 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (4327 rows), run_08_val.csv (204 rows)
#   Removed 124 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (4367 rows), run_09_val.csv (164 rows)
#   Removed 86 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (4193 rows), run_10_val.csv (338 rows)
# Processing scenario: disflooding_var10_dec
#   Cleaned: run_01_train.csv (15053 rows), run_01_val.csv (823 rows)
#   Cleaned: run_02_train.csv (15050 rows), run_02_val.csv (826 rows)
#   Removed 61 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (15130 rows), run_03_val.csv (746 rows)
#   Cleaned: run_04_train.csv (15170 rows), run_04_val.csv (706 rows)
#   Cleaned: run_05_train.csv (15094 rows), run_05_val.csv (782 rows)
#   Cleaned: run_06_train.csv (15058 rows), run_06_val.csv (818 rows)
#   Removed 2 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (15093 rows), run_07_val.csv (783 rows)
#   Removed 1 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (15070 rows), run_08_val.csv (806 rows)
#   Removed 36 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (15132 rows), run_09_val.csv (744 rows)
#   Cleaned: run_10_train.csv (15050 rows), run_10_val.csv (826 rows)
# Processing scenario: blackhole_var20_base
#   Cleaned: run_01_train.csv (10222 rows), run_01_val.csv (550 rows)
#   Cleaned: run_02_train.csv (10222 rows), run_02_val.csv (550 rows)
#   Cleaned: run_03_train.csv (10223 rows), run_03_val.csv (549 rows)
#   Cleaned: run_04_train.csv (10222 rows), run_04_val.csv (550 rows)
#   Cleaned: run_05_train.csv (10259 rows), run_05_val.csv (513 rows)
#   Cleaned: run_06_train.csv (10222 rows), run_06_val.csv (550 rows)
#   Cleaned: run_07_train.csv (10222 rows), run_07_val.csv (550 rows)
#   Cleaned: run_08_train.csv (10224 rows), run_08_val.csv (548 rows)
#   Cleaned: run_09_train.csv (10222 rows), run_09_val.csv (550 rows)
#   Cleaned: run_10_train.csv (10223 rows), run_10_val.csv (549 rows)
# Processing scenario: disflooding_var15_oo
#   Cleaned: run_01_train.csv (16421 rows), run_01_val.csv (860 rows)
#   Cleaned: run_02_train.csv (16419 rows), run_02_val.csv (862 rows)
#   Cleaned: run_03_train.csv (16414 rows), run_03_val.csv (867 rows)
#   Cleaned: run_04_train.csv (16418 rows), run_04_val.csv (863 rows)
#   Cleaned: run_05_train.csv (16419 rows), run_05_val.csv (862 rows)
#   Cleaned: run_06_train.csv (16413 rows), run_06_val.csv (868 rows)
#   Cleaned: run_07_train.csv (16416 rows), run_07_val.csv (865 rows)
#   Cleaned: run_08_train.csv (16416 rows), run_08_val.csv (865 rows)
#   Cleaned: run_09_train.csv (16421 rows), run_09_val.csv (860 rows)
#   Cleaned: run_10_train.csv (16418 rows), run_10_val.csv (863 rows)
# Processing scenario: worstparent_var15_oo
#   Cleaned: run_01_train.csv (17040 rows), run_01_val.csv (897 rows)
#   Cleaned: run_02_train.csv (17042 rows), run_02_val.csv (895 rows)
#   Cleaned: run_03_train.csv (17042 rows), run_03_val.csv (895 rows)
#   Cleaned: run_04_train.csv (17039 rows), run_04_val.csv (898 rows)
#   Cleaned: run_05_train.csv (17044 rows), run_05_val.csv (893 rows)
#   Removed 1 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (17043 rows), run_06_val.csv (894 rows)
#   Removed 1 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (17040 rows), run_07_val.csv (897 rows)
#   Cleaned: run_08_train.csv (17037 rows), run_08_val.csv (900 rows)
#   Cleaned: run_09_train.csv (17042 rows), run_09_val.csv (895 rows)
#   Cleaned: run_10_train.csv (17038 rows), run_10_val.csv (899 rows)
# Processing scenario: blackhole_var5_oo
#   Removed 120 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (1916 rows), run_01_val.csv (32 rows)
#   Removed 75 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (1856 rows), run_02_val.csv (92 rows)
#   Removed 81 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (1874 rows), run_03_val.csv (74 rows)
#   Removed 1 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (1789 rows), run_04_val.csv (159 rows)
#   Removed 68 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (1887 rows), run_05_val.csv (61 rows)
#   Removed 76 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (1905 rows), run_06_val.csv (43 rows)
#   Removed 83 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (1859 rows), run_07_val.csv (89 rows)
#   Removed 87 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (1855 rows), run_08_val.csv (93 rows)
#   Removed 71 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (1881 rows), run_09_val.csv (67 rows)
#   Removed 83 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (1842 rows), run_10_val.csv (106 rows)
# Processing scenario: worstparent_var15_base
#   Cleaned: run_01_train.csv (17040 rows), run_01_val.csv (898 rows)
#   Cleaned: run_02_train.csv (17041 rows), run_02_val.csv (897 rows)
#   Cleaned: run_03_train.csv (17042 rows), run_03_val.csv (896 rows)
#   Cleaned: run_04_train.csv (17039 rows), run_04_val.csv (899 rows)
#   Cleaned: run_05_train.csv (17045 rows), run_05_val.csv (893 rows)
#   Cleaned: run_06_train.csv (17043 rows), run_06_val.csv (895 rows)
#   Cleaned: run_07_train.csv (17039 rows), run_07_val.csv (899 rows)
#   Cleaned: run_08_train.csv (17040 rows), run_08_val.csv (898 rows)
#   Cleaned: run_09_train.csv (17040 rows), run_09_val.csv (898 rows)
#   Cleaned: run_10_train.csv (17041 rows), run_10_val.csv (897 rows)
# Processing scenario: localrepair_var20_oo
#   Removed 3 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (16146 rows), run_01_val.csv (840 rows)
#   Cleaned: run_02_train.csv (16155 rows), run_02_val.csv (831 rows)
#   Removed 2 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (16133 rows), run_03_val.csv (853 rows)
#   Cleaned: run_04_train.csv (16159 rows), run_04_val.csv (827 rows)
#   Cleaned: run_05_train.csv (16184 rows), run_05_val.csv (802 rows)
#   Removed 4 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (16135 rows), run_06_val.csv (851 rows)
#   Removed 1 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (16126 rows), run_07_val.csv (860 rows)
#   Cleaned: run_08_train.csv (16143 rows), run_08_val.csv (843 rows)
#   Removed 5 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (16147 rows), run_09_val.csv (839 rows)
#   Removed 1 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (16102 rows), run_10_val.csv (884 rows)
# Processing scenario: blackhole_var20_oo
#   Cleaned: run_01_train.csv (7481 rows), run_01_val.csv (394 rows)
#   Cleaned: run_02_train.csv (7481 rows), run_02_val.csv (394 rows)
#   Cleaned: run_03_train.csv (7482 rows), run_03_val.csv (393 rows)
#   Cleaned: run_04_train.csv (7481 rows), run_04_val.csv (394 rows)
#   Cleaned: run_05_train.csv (7481 rows), run_05_val.csv (394 rows)
#   Cleaned: run_06_train.csv (7481 rows), run_06_val.csv (394 rows)
#   Cleaned: run_07_train.csv (7481 rows), run_07_val.csv (394 rows)
#   Cleaned: run_08_train.csv (7481 rows), run_08_val.csv (394 rows)
#   Cleaned: run_09_train.csv (7481 rows), run_09_val.csv (394 rows)
#   Cleaned: run_10_train.csv (7482 rows), run_10_val.csv (393 rows)
# Processing scenario: localrepair_var20_base
#   Removed 3 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (16222 rows), run_01_val.csv (841 rows)
#   Cleaned: run_02_train.csv (16205 rows), run_02_val.csv (858 rows)
#   Removed 2 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (16204 rows), run_03_val.csv (859 rows)
#   Cleaned: run_04_train.csv (16226 rows), run_04_val.csv (837 rows)
#   Cleaned: run_05_train.csv (16253 rows), run_05_val.csv (810 rows)
#   Removed 5 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (16218 rows), run_06_val.csv (845 rows)
#   Removed 1 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (16200 rows), run_07_val.csv (863 rows)
#   Cleaned: run_08_train.csv (16233 rows), run_08_val.csv (830 rows)
#   Removed 6 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (16230 rows), run_09_val.csv (833 rows)
#   Removed 1 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (16178 rows), run_10_val.csv (885 rows)
# Processing scenario: worstparent_var5_oo
#   Removed 112 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (4365 rows), run_01_val.csv (175 rows)
#   Removed 143 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (4462 rows), run_02_val.csv (78 rows)
#   Removed 178 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (4345 rows), run_03_val.csv (195 rows)
#   Removed 192 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (4362 rows), run_04_val.csv (178 rows)
#   Removed 73 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (4295 rows), run_05_val.csv (245 rows)
#   Removed 124 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (4349 rows), run_06_val.csv (191 rows)
#   Removed 107 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (4392 rows), run_07_val.csv (148 rows)
#   Removed 155 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (4395 rows), run_08_val.csv (145 rows)
#   Removed 144 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (4406 rows), run_09_val.csv (134 rows)
#   Removed 88 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (4256 rows), run_10_val.csv (284 rows)
# Processing scenario: localrepair_var15_dec
#   Removed 1 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (15730 rows), run_01_val.csv (807 rows)
#   Removed 3 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (15705 rows), run_02_val.csv (832 rows)
#   Removed 9 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (15701 rows), run_03_val.csv (836 rows)
#   Cleaned: run_04_train.csv (15691 rows), run_04_val.csv (846 rows)
#   Removed 3 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (15711 rows), run_05_val.csv (826 rows)
#   Removed 42 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (15758 rows), run_06_val.csv (779 rows)
#   Removed 5 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (15681 rows), run_07_val.csv (856 rows)
#   Removed 8 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (15727 rows), run_08_val.csv (810 rows)
#   Cleaned: run_09_train.csv (15686 rows), run_09_val.csv (851 rows)
#   Removed 9 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (15743 rows), run_10_val.csv (794 rows)
# Processing scenario: localrepair_var10_oo
#   Cleaned: run_01_train.csv (9839 rows), run_01_val.csv (550 rows)
#   Removed 64 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (9854 rows), run_02_val.csv (535 rows)
#   Removed 22 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (9823 rows), run_03_val.csv (566 rows)
#   Removed 120 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (9971 rows), run_04_val.csv (418 rows)
#   Removed 64 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (9850 rows), run_05_val.csv (539 rows)
#   Removed 6 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (10010 rows), run_06_val.csv (379 rows)
#   Removed 3 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (9770 rows), run_07_val.csv (619 rows)
#   Removed 10 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (9906 rows), run_08_val.csv (483 rows)
#   Cleaned: run_09_train.csv (9929 rows), run_09_val.csv (460 rows)
#   Removed 25 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (9839 rows), run_10_val.csv (550 rows)
# Processing scenario: disflooding_var10_base
#   Cleaned: run_01_train.csv (14380 rows), run_01_val.csv (841 rows)
#   Cleaned: run_02_train.csv (14386 rows), run_02_val.csv (835 rows)
#   Removed 815 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (15221 rows), run_03_val.csv (0 rows)
#   Cleaned: run_04_train.csv (14402 rows), run_04_val.csv (819 rows)
#   Cleaned: run_05_train.csv (14395 rows), run_05_val.csv (826 rows)
#   Cleaned: run_06_train.csv (14434 rows), run_06_val.csv (787 rows)
#   Removed 45 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (14448 rows), run_07_val.csv (773 rows)
#   Removed 24 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (14420 rows), run_08_val.csv (801 rows)
#   Cleaned: run_09_train.csv (14460 rows), run_09_val.csv (761 rows)
#   Cleaned: run_10_train.csv (14409 rows), run_10_val.csv (812 rows)
# Processing scenario: blackhole_var10_oo
#   Removed 15 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (6161 rows), run_01_val.csv (335 rows)
#   Removed 4 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (6158 rows), run_02_val.csv (338 rows)
#   Removed 1 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (6209 rows), run_03_val.csv (287 rows)
#   Removed 2 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (6165 rows), run_04_val.csv (331 rows)
#   Removed 5 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (6207 rows), run_05_val.csv (289 rows)
#   Removed 1 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (6189 rows), run_06_val.csv (307 rows)
#   Removed 9 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (6170 rows), run_07_val.csv (326 rows)
#   Removed 12 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (6235 rows), run_08_val.csv (261 rows)
#   Removed 16 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (6139 rows), run_09_val.csv (357 rows)
#   Removed 4 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (6162 rows), run_10_val.csv (334 rows)
# Processing scenario: blackhole_var10_dec
#   Removed 38 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (8157 rows), run_01_val.csv (446 rows)
#   Removed 11 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (8164 rows), run_02_val.csv (439 rows)
#   Removed 1 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (8185 rows), run_03_val.csv (418 rows)
#   Removed 43 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (8220 rows), run_04_val.csv (383 rows)
#   Removed 1 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (8181 rows), run_05_val.csv (422 rows)
#   Removed 5 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (8189 rows), run_06_val.csv (414 rows)
#   Removed 2 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (8154 rows), run_07_val.csv (449 rows)
#   Cleaned: run_08_train.csv (8242 rows), run_08_val.csv (361 rows)
#   Removed 11 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (8130 rows), run_09_val.csv (473 rows)
#   Removed 6 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (8187 rows), run_10_val.csv (416 rows)
# Processing scenario: localrepair_var10_dec
#   Cleaned: run_01_train.csv (11835 rows), run_01_val.csv (633 rows)
#   Removed 54 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (11837 rows), run_02_val.csv (631 rows)
#   Removed 11 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (11789 rows), run_03_val.csv (679 rows)
#   Removed 84 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (11891 rows), run_04_val.csv (577 rows)
#   Removed 65 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (11836 rows), run_05_val.csv (632 rows)
#   Removed 4 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (11965 rows), run_06_val.csv (503 rows)
#   Removed 3 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (11755 rows), run_07_val.csv (713 rows)
#   Removed 7 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (11848 rows), run_08_val.csv (620 rows)
#   Cleaned: run_09_train.csv (11828 rows), run_09_val.csv (640 rows)
#   Removed 15 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (11818 rows), run_10_val.csv (650 rows)
# Processing scenario: worstparent_var20_dec
#   Cleaned: run_01_train.csv (17082 rows), run_01_val.csv (900 rows)
#   Cleaned: run_02_train.csv (17082 rows), run_02_val.csv (900 rows)
#   Cleaned: run_03_train.csv (17082 rows), run_03_val.csv (900 rows)
#   Cleaned: run_04_train.csv (17083 rows), run_04_val.csv (899 rows)
#   Cleaned: run_05_train.csv (17083 rows), run_05_val.csv (899 rows)
#   Cleaned: run_06_train.csv (17082 rows), run_06_val.csv (900 rows)
#   Cleaned: run_07_train.csv (17083 rows), run_07_val.csv (899 rows)
#   Cleaned: run_08_train.csv (17082 rows), run_08_val.csv (900 rows)
#   Cleaned: run_09_train.csv (17082 rows), run_09_val.csv (900 rows)
#   Cleaned: run_10_train.csv (17082 rows), run_10_val.csv (900 rows)
# Processing scenario: blackhole_var15_dec
#   Cleaned: run_01_train.csv (9972 rows), run_01_val.csv (543 rows)
#   Removed 31 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (10108 rows), run_02_val.csv (407 rows)
#   Cleaned: run_03_train.csv (9961 rows), run_03_val.csv (554 rows)
#   Cleaned: run_04_train.csv (9969 rows), run_04_val.csv (546 rows)
#   Cleaned: run_05_train.csv (9965 rows), run_05_val.csv (550 rows)
#   Removed 7 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (9991 rows), run_06_val.csv (524 rows)
#   Cleaned: run_07_train.csv (10070 rows), run_07_val.csv (445 rows)
#   Cleaned: run_08_train.csv (9963 rows), run_08_val.csv (552 rows)
#   Cleaned: run_09_train.csv (9971 rows), run_09_val.csv (544 rows)
#   Removed 7 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (9979 rows), run_10_val.csv (536 rows)
# Processing scenario: localrepair_var15_oo
#   Removed 1 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (15193 rows), run_01_val.csv (787 rows)
#   Removed 5 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (15163 rows), run_02_val.csv (817 rows)
#   Removed 10 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (15170 rows), run_03_val.csv (810 rows)
#   Cleaned: run_04_train.csv (15169 rows), run_04_val.csv (811 rows)
#   Removed 4 overlapping rows from validation set in run_05_val.csv
#   Cleaned: run_05_train.csv (15175 rows), run_05_val.csv (805 rows)
#   Removed 63 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (15271 rows), run_06_val.csv (709 rows)
#   Removed 6 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (15137 rows), run_07_val.csv (843 rows)
#   Removed 10 overlapping rows from validation set in run_08_val.csv
#   Cleaned: run_08_train.csv (15222 rows), run_08_val.csv (758 rows)
#   Cleaned: run_09_train.csv (15145 rows), run_09_val.csv (835 rows)
#   Removed 13 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (15222 rows), run_10_val.csv (758 rows)
# Processing scenario: blackhole_var10_base
#   Removed 15 overlapping rows from validation set in run_01_val.csv
#   Cleaned: run_01_train.csv (8087 rows), run_01_val.csv (404 rows)
#   Removed 2 overlapping rows from validation set in run_02_val.csv
#   Cleaned: run_02_train.csv (8044 rows), run_02_val.csv (447 rows)
#   Removed 2 overlapping rows from validation set in run_03_val.csv
#   Cleaned: run_03_train.csv (8097 rows), run_03_val.csv (394 rows)
#   Removed 4 overlapping rows from validation set in run_04_val.csv
#   Cleaned: run_04_train.csv (8038 rows), run_04_val.csv (453 rows)
#   Cleaned: run_05_train.csv (8088 rows), run_05_val.csv (403 rows)
#   Removed 1 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (8093 rows), run_06_val.csv (398 rows)
#   Removed 2 overlapping rows from validation set in run_07_val.csv
#   Cleaned: run_07_train.csv (8046 rows), run_07_val.csv (445 rows)
#   Cleaned: run_08_train.csv (8119 rows), run_08_val.csv (372 rows)
#   Removed 39 overlapping rows from validation set in run_09_val.csv
#   Cleaned: run_09_train.csv (8144 rows), run_09_val.csv (347 rows)
#   Removed 1 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (8048 rows), run_10_val.csv (443 rows)
# Processing scenario: blackhole_var15_oo
#   Cleaned: run_01_train.csv (7362 rows), run_01_val.csv (384 rows)
#   Cleaned: run_02_train.csv (7353 rows), run_02_val.csv (393 rows)
#   Cleaned: run_03_train.csv (7356 rows), run_03_val.csv (390 rows)
#   Cleaned: run_04_train.csv (7354 rows), run_04_val.csv (392 rows)
#   Cleaned: run_05_train.csv (7353 rows), run_05_val.csv (393 rows)
#   Removed 7 overlapping rows from validation set in run_06_val.csv
#   Cleaned: run_06_train.csv (7377 rows), run_06_val.csv (369 rows)
#   Cleaned: run_07_train.csv (7354 rows), run_07_val.csv (392 rows)
#   Cleaned: run_08_train.csv (7356 rows), run_08_val.csv (390 rows)
#   Cleaned: run_09_train.csv (7367 rows), run_09_val.csv (379 rows)
#   Removed 7 overlapping rows from validation set in run_10_val.csv
#   Cleaned: run_10_train.csv (7367 rows), run_10_val.csv (379 rows)
# Duplicate removal completed for all scenarios.

# %% [markdown]
# ## Drop Missing cells

# %%
from pathlib import Path
import pandas as pd

BASE = Path("/Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario")

# Get subfolders as Path objects
folders = [f for f in BASE.iterdir() if f.is_dir()]
print("Scenario folders:", [f.name for f in folders])

for folder in folders:
    train_files = sorted(folder.glob("run_*_train.csv"))
    val_files   = sorted(folder.glob("run_*_val.csv"))

    if not train_files or not val_files:
        print(f"[WARN] Skipping {folder.name} — no run CSVs found.")
        continue

    print(f"Processing scenario: {folder.name}")

    for tr_file, va_file in zip(train_files, val_files):
        # Read CSVs and remove Unnamed: 0 if exists
        df_train = pd.read_csv(tr_file).drop(columns=["Unnamed: 0"], errors="ignore")
        df_val   = pd.read_csv(va_file).drop(columns=["Unnamed: 0"], errors="ignore")

        # Remove rows with missing values
        before_train = len(df_train)
        before_val = len(df_val)
        df_train = df_train.dropna()
        df_val = df_val.dropna()


        # Save cleaned CSVs
        df_train.to_csv(tr_file, index=False)
        df_val.to_csv(va_file, index=False)

        print(
            f"  Cleaned {tr_file.name}: "
            f"{before_train - len(df_train)} rows removed (missing/duplicates)"
        )
        print(
            f"  Cleaned {va_file.name}: "
            f"{before_val - len(df_val)} rows removed (missing/duplicates)"
        )

print(" Cleaning completed for all scenarios.")
# Out:
# Scenario folders: ['localrepair_var20_dec', 'worstparent_var10_dec', 'disflooding_var5_base', 'disflooding_var5_dec', 'worstparent_var5_dec', 'worstparent_var15_dec', 'blackhole_var20_dec', 'worstparent_var20_base', 'localrepair_var15_base', 'localrepair_var5_base', 'disflooding_var20_dec', 'blackhole_var15_base', 'localrepair_var5_dec', 'worstparent_var10_base', 'blackhole_var5_dec', 'disflooding_var5_oo', 'blackhole_var5_base', 'disflooding_var15_base', 'worstparent_var20_oo', 'disflooding_var20_oo', 'worstparent_var10_oo', 'disflooding_var20_base', 'disflooding_var10_oo', 'disflooding_var15_dec', 'localrepair_var10_base', 'localrepair_var5_oo', 'worstparent_var5_base', 'disflooding_var10_dec', 'blackhole_var20_base', 'disflooding_var15_oo', 'worstparent_var15_oo', 'blackhole_var5_oo', 'worstparent_var15_base', 'localrepair_var20_oo', 'blackhole_var20_oo', 'localrepair_var20_base', 'worstparent_var5_oo', 'localrepair_var15_dec', 'localrepair_var10_oo', 'disflooding_var10_base', 'blackhole_var10_oo', 'blackhole_var10_dec', 'localrepair_var10_dec', 'worstparent_var20_dec', 'blackhole_var15_dec', 'localrepair_var15_oo', 'blackhole_var10_base', 'blackhole_var15_oo']
# Processing scenario: localrepair_var20_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var10_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var5_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var5_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var5_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var15_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var20_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var20_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var15_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var5_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var20_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var15_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var5_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var10_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var5_dec
#   Cleaned run_01_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var5_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var5_base
#   Cleaned run_01_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 21 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var15_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var20_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var20_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var10_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var20_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var10_oo
#   Cleaned run_01_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 1 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var15_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var10_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var5_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var5_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var10_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var20_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var15_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var15_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var5_oo
#   Cleaned run_01_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 3 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var15_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var20_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var20_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var20_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var5_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var15_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var10_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: disflooding_var10_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var10_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var10_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var10_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: worstparent_var20_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var15_dec
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: localrepair_var15_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var10_base
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
# Processing scenario: blackhole_var15_oo
#   Cleaned run_01_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_01_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_02_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_03_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_04_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_05_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_06_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_07_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_08_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_09_val.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_train.csv: 0 rows removed (missing/duplicates)
#   Cleaned run_10_val.csv: 0 rows removed (missing/duplicates)
#  Cleaning completed for all scenarios.

# %% [markdown]
# ## Files those have number of rows in validation file = 0

# %%
from pathlib import Path
import pandas as pd

BASE = Path("/Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario")

# Get subfolders as Path objects
folders = [f for f in BASE.iterdir() if f.is_dir()]
print("Scenario folders:", [f.name for f in folders])

empty_val_files = []

for folder in folders:
    val_files = sorted(folder.glob("run_*_val.csv"))

    if not val_files:
        print(f"[WARN] Skipping {folder.name} — no validation CSVs found.")
        continue

    for va_file in val_files:
        df_val = pd.read_csv(va_file).drop(columns=["Unnamed: 0"], errors="ignore")

        if len(df_val) == 0:
            empty_val_files.append(str(va_file))

# Final report
if empty_val_files:
    print("\n Validation files with 0 rows:")
    for f in empty_val_files:
        print(" -", f)
else:
    print("\n No validation files with 0 rows found.")
# Out:
# Scenario folders: ['localrepair_var20_dec', 'worstparent_var10_dec', 'disflooding_var5_base', 'disflooding_var5_dec', 'worstparent_var5_dec', 'worstparent_var15_dec', 'blackhole_var20_dec', 'worstparent_var20_base', 'localrepair_var15_base', 'localrepair_var5_base', 'disflooding_var20_dec', 'blackhole_var15_base', 'localrepair_var5_dec', 'worstparent_var10_base', 'blackhole_var5_dec', 'disflooding_var5_oo', 'blackhole_var5_base', 'disflooding_var15_base', 'worstparent_var20_oo', 'disflooding_var20_oo', 'worstparent_var10_oo', 'disflooding_var20_base', 'disflooding_var10_oo', 'disflooding_var15_dec', 'localrepair_var10_base', 'localrepair_var5_oo', 'worstparent_var5_base', 'disflooding_var10_dec', 'blackhole_var20_base', 'disflooding_var15_oo', 'worstparent_var15_oo', 'blackhole_var5_oo', 'worstparent_var15_base', 'localrepair_var20_oo', 'blackhole_var20_oo', 'localrepair_var20_base', 'worstparent_var5_oo', 'localrepair_var15_dec', 'localrepair_var10_oo', 'disflooding_var10_base', 'blackhole_var10_oo', 'blackhole_var10_dec', 'localrepair_var10_dec', 'worstparent_var20_dec', 'blackhole_var15_dec', 'localrepair_var15_oo', 'blackhole_var10_base', 'blackhole_var15_oo']
#
#  No validation files with 0 rows found.

# %% [markdown]
# ### Create 10 cross_validation files for each attacks

# %%
import pandas as pd
from pathlib import Path

# ==== CONFIG ====
BASE = Path("/Users/souba636/Documents/vinnova_project_python/data/scenario/disflooding_var10_base")  # path with CSV files
OUTDIR = Path("/Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var10_base")
TARGET_RUNS = 10                        # how many valid runs we want
LABEL_COL = None                        # set manually if known
CSV_GLOB = "*.csv"                      # match all CSV files in BASE

# List all CSV files
files = sorted(BASE.glob(CSV_GLOB))
total_files = len(files)
print(f"Found {total_files} CSV files in {BASE}")
if total_files < TARGET_RUNS:
    raise ValueError(f"Found {total_files} CSVs but TARGET_RUNS={TARGET_RUNS}.")

# Detect label column from first file
def detect_label_col(df: pd.DataFrame):
    for c in ["label", "class", "target", "y"]:
        if c in df.columns and set(df[c].dropna().unique()).issubset({0, 1}):
            return c
    for c in df.columns[::-1]:
        vals = df[c].dropna().unique()
        if len(vals) <= 3 and set(vals).issubset({0, 1}):
            return c
    raise ValueError("Couldn't detect the label column. Set LABEL_COL manually.")

first_df = pd.read_csv(files[0]).drop(columns=["Unnamed: 0"], errors="ignore")
label_col = LABEL_COL or detect_label_col(first_df)
print(f"Using label column: {label_col}")

# Create output directory
OUTDIR.mkdir(parents=True, exist_ok=True)

# Loop until we get TARGET_RUNS valid runs
valid_run_count = 0
skipped_runs = []

for i in range(total_files):
    if valid_run_count >= TARGET_RUNS:
        break  # Stop when we have enough valid runs

    val_file = files[i]
    train_files = [f for f in files if f != val_file]

    # Load and split training data by class
    zeros, ones = [], []
    for f in train_files:
        df = pd.read_csv(f).drop(columns=["Unnamed: 0"], errors="ignore")
        if label_col not in df.columns:
            raise ValueError(f"{f.name} does not have label column '{label_col}'")
        zeros.append(df[df[label_col] == 0])
        ones.append(df[df[label_col] == 1])

    # Combine and clean train data
    train_0 = pd.concat(zeros, ignore_index=True) if zeros else pd.DataFrame(columns=first_df.columns)
    train_1 = pd.concat(ones, ignore_index=True) if ones else pd.DataFrame(columns=first_df.columns)
    train_df = pd.concat([train_0, train_1], ignore_index=True)

    # Load and order validation data
    val_df = pd.read_csv(val_file).drop(columns=["Unnamed: 0"], errors="ignore")
    val_df = pd.concat(
        [val_df[val_df[label_col] == 0], val_df[val_df[label_col] == 1]],
        ignore_index=True
    )

    # === Cleaning ===
    train_df = train_df.dropna().drop_duplicates(ignore_index=True)
    val_df = val_df.dropna().drop_duplicates(ignore_index=True)

    # Remove duplicate rows across train and validation (leakage)
    common_rows = val_df.merge(train_df, how="inner")
    if not common_rows.empty:
        val_df = val_df[~val_df.apply(tuple, axis=1).isin(common_rows.apply(tuple, axis=1))]

    # If validation set becomes empty, skip this run
    if len(val_df) == 0:
        print(f"[SKIP] Run {i+1:02d} skipped — validation empty after cleaning")
        skipped_runs.append(val_file.name)
        continue

    # Save cleaned sets
    run_name = f"run_{valid_run_count+1:02d}"  # valid run numbering
    train_path = OUTDIR / f"{run_name}_train.csv"
    val_path = OUTDIR / f"{run_name}_val.csv"
    train_df.to_csv(train_path, index=False)
    val_df.to_csv(val_path, index=False)

    # Summary
    c0_train, c1_train = (train_df[label_col] == 0).sum(), (train_df[label_col] == 1).sum()
    c0_val, c1_val = (val_df[label_col] == 0).sum(), (val_df[label_col] == 1).sum()
    print(f"[{run_name}] val={val_file.name} | train: 0={c0_train}, 1={c1_train} | val: 0={c0_val}, 1={c1_val}")

    valid_run_count += 1

print(f" Done. Created {valid_run_count} valid runs. Files written to: {OUTDIR}")

if skipped_runs:
    print("\n Skipped runs due to empty validation set after cleaning:")
    for f in skipped_runs:
        print(" -", f)
# Out:
# Found 20 CSV files in /Users/souba636/Documents/vinnova_project_python/data/scenario/disflooding_var10_base
# Using label column: label
# [run_01] val=disflooding_var10_base_10_features_timeseries_60_sec.csv | train: 0=6585, 1=7795 | val: 0=408, 1=433
# [run_02] val=disflooding_var10_base_11_features_timeseries_60_sec.csv | train: 0=6592, 1=7794 | val: 0=401, 1=434
# [SKIP] Run 03 skipped — validation empty after cleaning
# [run_03] val=disflooding_var10_base_13_features_timeseries_60_sec.csv | train: 0=6608, 1=7794 | val: 0=385, 1=434
# [run_04] val=disflooding_var10_base_14_features_timeseries_60_sec.csv | train: 0=6594, 1=7801 | val: 0=399, 1=427
# [run_05] val=disflooding_var10_base_15_features_timeseries_60_sec.csv | train: 0=6640, 1=7794 | val: 0=353, 1=434
# [run_06] val=disflooding_var10_base_16_features_timeseries_60_sec.csv | train: 0=6654, 1=7794 | val: 0=339, 1=434
# [run_07] val=disflooding_var10_base_17_features_timeseries_60_sec.csv | train: 0=6626, 1=7794 | val: 0=367, 1=434
# [run_08] val=disflooding_var10_base_18_features_timeseries_60_sec.csv | train: 0=6663, 1=7797 | val: 0=330, 1=431
# [run_09] val=disflooding_var10_base_19_features_timeseries_60_sec.csv | train: 0=6615, 1=7794 | val: 0=378, 1=434
# [SKIP] Run 11 skipped — validation empty after cleaning
# [run_10] val=disflooding_var10_base_20_features_timeseries_60_sec.csv | train: 0=6583, 1=7794 | val: 0=410, 1=434
#  Done. Created 10 valid runs. Files written to: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var10_base
#
#  Skipped runs due to empty validation set after cleaning:
#  - disflooding_var10_base_12_features_timeseries_60_sec.csv
#  - disflooding_var10_base_1_features_timeseries_60_sec.csv

# %% [markdown]
# ### Check for
#
# 1. missing values
#
# 2. duplicate rows (within each file)
#
# 3. train/val overlap (data leakage) per run
#
# 4. label column validity (binary {0,1}, no NaNs)
#
# 5. schema consistency (same columns across all files)
#
# 6. column count (should be 14 features + 1 label)
#
# 7. non‑numeric feature values
#
# 8. constant (zero-variance) feature columns
#
# 9. class counts and ordering (0s before 1s)

# %%
from pathlib import Path
import pandas as pd
import numpy as np

BASE = Path("/Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario")

# Get subfolders as Path objects
folders = [f for f in BASE.iterdir() if f.is_dir()]
print("Scenario folders:", [f.name for f in folders])

# === PARAMETERS ===
LABEL_COL = None       # set if known, else auto-detect
EXPECTED_FEATURES = 14 # you said 14 features + 1 label = 15 cols

# --- Helper functions ---
def detect_label_col(df: pd.DataFrame):
    for c in ["label", "class", "target", "y"]:
        if c in df.columns and set(df[c].dropna().unique()).issubset({0,1}):
            return c
    for c in df.columns[::-1]:
        vals = df[c].dropna().unique()
        if len(vals) <= 3 and set(vals).issubset({0,1}):
            return c
    raise ValueError("Could not detect label column; set LABEL_COL explicitly.")

def is_ordered_zeros_then_ones(s: pd.Series) -> bool:
    arr = s.to_numpy()
    return not np.any((arr[1:] == 0) & (arr[:-1] == 1))

# Collect all reports
reports = []

for folder in folders:
    train_files = sorted(folder.glob("run_*_train.csv"))
    val_files   = sorted(folder.glob("run_*_val.csv"))
    
    if not train_files or not val_files:
        print(f"[WARN] Skipping {folder.name} — no run CSVs found.")
        continue
    
    # Detect label column
    first_df = pd.read_csv(train_files[0], nrows=1000)
    label_col = LABEL_COL or detect_label_col(first_df)

    for tr, va in zip(train_files, val_files):
        run_id = tr.stem.replace("_train","")

        df_train = pd.read_csv(tr)
        df_val   = pd.read_csv(va)

        # Basic checks
        same_cols = list(df_train.columns) == list(df_val.columns)
        col_count_ok = len(df_train.columns) == (EXPECTED_FEATURES + 1)
        miss_train = int(df_train.isna().sum().sum())
        miss_val   = int(df_val.isna().sum().sum())
        dup_train  = int(df_train.duplicated().sum())
        dup_val    = int(df_val.duplicated().sum())
        # leakage    = int(len(df_val.merge(df_train, on=list(df_train.columns), how="inner")))
        duplicates = df_val.merge(df_train, on=list(df_train.columns), how="inner")
        leakage = len(duplicates)
        leakage_label0 = int((duplicates[label_col] == 0).sum())
        leakage_label1 = int((duplicates[label_col] == 1).sum())
        ordered_train = is_ordered_zeros_then_ones(df_train[label_col])
        ordered_val   = is_ordered_zeros_then_ones(df_val[label_col])

        reports.append({
            "scenario": folder.name,
            "run": run_id,
            "total_rows_train": len(df_train),
            "total_rows_val": len(df_val),
            "missing_cells_train": miss_train,
            "missing_cells_val": miss_val,
            "dup_rows_train": dup_train,
            "dup_rows_val": dup_val,
            "leakage_rows_train∩val": leakage,
            "leakage_label0_count": leakage_label0,
            "leakage_label1_count": leakage_label1,
            "same_schema": same_cols,
            "col_count_ok": col_count_ok,
            "ordered_train_0_then_1": ordered_train,
            "ordered_val_0_then_1": ordered_val
        })

# Save report
report_df = pd.DataFrame(reports)
report_path = BASE / "cross_val_validation_report.csv"
report_df.to_csv(report_path, index=False)
print(f"\nValidation report saved: {report_path}")

# Quick summary
print("\nSummary of issues:")
print(report_df[
    (~report_df["same_schema"]) |
    (~report_df["col_count_ok"]) |
    (report_df["missing_cells_train"] > 0) |
    (report_df["missing_cells_val"] > 0) |
    (report_df["dup_rows_train"] > 0) |
    (report_df["dup_rows_val"] > 0) |
    (report_df["leakage_rows_train∩val"] > 0) |
    (~report_df["ordered_train_0_then_1"]) |
    (~report_df["ordered_val_0_then_1"])
])

# %%
from pathlib import Path
import pandas as pd
import numpy as np

BASE = Path("/Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario")

# Get subfolders as Path objects
folders = [f for f in BASE.iterdir() if f.is_dir()]
print("Scenario folders:", [f.name for f in folders])

# === PARAMETERS ===
LABEL_COL = "label"       # set if known, else auto-detect
EXPECTED_FEATURES = 14 # you said 14 features + 1 label = 15 cols

# Collect all reports
results = []

for folder in folders:
    train_files = sorted(folder.glob("run_*_train.csv"))
    val_files   = sorted(folder.glob("run_*_val.csv"))
    if not train_files or not val_files:
        print(f"[WARN] Skipping {folder.name} — no train/val CSVs found.")
        continue

    for tr_file, va_file in zip(train_files, val_files):
        # Load data
        print(f"Processing scenario: {folder.name}")
        print(f"Train_file: {tr_file}")
        print(f"Processing: {tr_file.name} and {va_file.name}")
        df_train = pd.read_csv(tr_file)
        df_val   = pd.read_csv(va_file)

        print(f"df_train columns: {df_train.columns.tolist()}")
        print(f"df_val columns: {df_val.columns.tolist()}")
        

        # if LABEL_COL not in df_train.columns or LABEL_COL not in df_val.columns:
        #    raise ValueError(f"Label column '{LABEL_COL}' not found in {tr_file.name} or {va_file.name}")

        # Count labels
        train_label0 = (df_train[LABEL_COL] == 0).sum()
        train_label1 = (df_train[LABEL_COL] == 1).sum()
        val_label0   = (df_val[LABEL_COL] == 0).sum()
        val_label1   = (df_val[LABEL_COL] == 1).sum()

        # Append results
        results.append({
            "scenario": folder.name,
            "run": tr_file.stem.replace("_train", ""),
            "train_label0": train_label0,
            "train_label1": train_label1,
            "val_label0": val_label0,
            "val_label1": val_label1
        })

# Save summary CSV
summary_df = pd.DataFrame(results)
summary_path = BASE / "label_counts_summary.csv"
summary_df.to_csv(summary_path, index=False)

print(f"\n Summary saved to {summary_path}")
# Out:
# Scenario folders: ['localrepair_var20_dec', 'worstparent_var10_dec', 'disflooding_var5_base', 'disflooding_var5_dec', 'worstparent_var5_dec', 'worstparent_var15_dec', 'blackhole_var20_dec', 'worstparent_var20_base', 'localrepair_var15_base', 'localrepair_var5_base', 'disflooding_var20_dec', 'blackhole_var15_base', 'localrepair_var5_dec', 'worstparent_var10_base', 'blackhole_var5_dec', 'disflooding_var5_oo', 'blackhole_var5_base', 'disflooding_var15_base', 'worstparent_var20_oo', 'disflooding_var20_oo', 'worstparent_var10_oo', 'disflooding_var20_base', 'disflooding_var10_oo', 'disflooding_var15_dec', 'localrepair_var10_base', 'localrepair_var5_oo', 'worstparent_var5_base', 'disflooding_var10_dec', 'blackhole_var20_base', 'disflooding_var15_oo', 'worstparent_var15_oo', 'blackhole_var5_oo', 'worstparent_var15_base', 'localrepair_var20_oo', 'blackhole_var20_oo', 'localrepair_var20_base', 'worstparent_var5_oo', 'localrepair_var15_dec', 'localrepair_var10_oo', 'disflooding_var10_base', 'blackhole_var10_oo', 'blackhole_var10_dec', 'localrepair_var10_dec', 'worstparent_var20_dec', 'blackhole_var15_dec', 'localrepair_var15_oo', 'blackhole_var10_base', 'blackhole_var15_oo']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var20_dec/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var10_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var10_dec/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_base/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: disflooding_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/disflooding_var5_dec/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var5_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var5_dec/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var15_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var15_dec/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var20_dec
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var20_dec/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: worstparent_var20_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/worstparent_var20_base/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_base/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# ...
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: localrepair_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/localrepair_var15_oo/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var10_base
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var10_base/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_01_train.csv
# Processing: run_01_train.csv and run_01_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_02_train.csv
# Processing: run_02_train.csv and run_02_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_03_train.csv
# Processing: run_03_train.csv and run_03_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_04_train.csv
# Processing: run_04_train.csv and run_04_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_05_train.csv
# Processing: run_05_train.csv and run_05_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_06_train.csv
# Processing: run_06_train.csv and run_06_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_07_train.csv
# Processing: run_07_train.csv and run_07_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_08_train.csv
# Processing: run_08_train.csv and run_08_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_09_train.csv
# Processing: run_09_train.csv and run_09_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# Processing scenario: blackhole_var15_oo
# Train_file: /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/blackhole_var15_oo/run_10_train.csv
# Processing: run_10_train.csv and run_10_val.csv
# df_train columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
# df_val columns: ['rank', 'disr', 'diss', 'dior', 'dios', 'diar', 'tots', 'rank.1', 'disr.1', 'diss.1', 'dior.1', 'dios.1', 'diar.1', 'tots.1', 'label']
#
#  Summary saved to /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/label_counts_summary.csv

# %% [markdown]
# ## MMD Between the domains

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# ==== CONFIG ====
BASE = Path("/Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario")
LABEL_COL = "label"     # Change if needed
CSV_TYPE = "train"      # "train" or "val"
SIGMA = 1.0             # RBF kernel width
RUNS = range(1, 2)      # run_01 ... run_10

# ==== MMD FUNCTIONS ====
def rbf_kernel(X, Y, sigma):
    XX = np.sum(X**2, axis=1)[:, None]
    YY = np.sum(Y**2, axis=1)[None, :]
    d2 = XX + YY - 2 * (X @ Y.T)
    return np.exp(-d2 / (2 * sigma**2 + 1e-12))

def mmd_rbf(X, Y, sigma):
    Kxx = rbf_kernel(X, X, sigma)
    Kyy = rbf_kernel(Y, Y, sigma)
    Kxy = rbf_kernel(X, Y, sigma)
    return float(Kxx.mean() + Kyy.mean() - 2 * Kxy.mean())

# ==== FOLDERS ====
folders = sorted([f for f in BASE.iterdir() if f.is_dir()])
folder_names = [f.name for f in folders]
print(f"Found {len(folders)} folders.")

# ==== RESULTS ====
all_results = []

for run_id in RUNS:
    print(f"\n=== Processing run_{run_id:02d} ===")
    
    # Step 1: Pre-load all datasets for this run
    datasets = []
    valid_names = []
    for folder in folders:
        fpath = folder / f"run_{run_id:02d}_{CSV_TYPE}.csv"
        if not fpath.exists():
            continue
        df = pd.read_csv(fpath).drop(columns=["Unnamed: 0"], errors="ignore")
        if LABEL_COL in df.columns:
            df = df.drop(columns=[LABEL_COL])
        df = df.apply(pd.to_numeric, errors="coerce").dropna()
        if df.shape[0] > 0 and df.shape[1] > 0:
            datasets.append(df.to_numpy())
            valid_names.append(folder.name)
    
    n = len(datasets)
    print(f"Found {n} valid datasets for run_{run_id:02d}: {valid_names}")
    if n < 2:
        print(f"[SKIP] Not enough datasets for run_{run_id:02d}")
        continue
    
    # Step 2: Compute lower-triangular MMD matrix
    M = np.zeros((n, n))
    for i in range(n):
        for j in range(i):
            val = mmd_rbf(datasets[i], datasets[j], SIGMA)
            print(f"MMD({valid_names[i]}, {valid_names[j]}) = {val:.4f}")
            M[i, j] = val
            M[j, i] = val  # fill symmetric position
    
    # Step 3: Store results in a long-form table
    for i in range(n):
        for j in range(i):
            all_results.append({
                "run": run_id,
                "folder_a": valid_names[i],
                "folder_b": valid_names[j],
                "mmd": M[i, j]
            })
    
    # Step 4: Save CSV + heatmap for this run
    mat_df = pd.DataFrame(M, index=valid_names, columns=valid_names)
    mat_df.to_csv(BASE / f"mmd_matrix_run_{run_id:02d}_{CSV_TYPE}.csv")
    
    plt.figure(figsize=(10, 8))
    plt.imshow(M, interpolation="nearest", aspect="auto")
    plt.xticks(range(n), valid_names, rotation=90)
    plt.yticks(range(n), valid_names)
    plt.colorbar(label="MMD")
    plt.title(f"MMD Heatmap — run_{run_id:02d} ({CSV_TYPE})")
    plt.tight_layout()
    plt.savefig(BASE / f"mmd_heatmap_run_{run_id:02d}_{CSV_TYPE}.png", dpi=200)
    plt.close()

# ==== Save long-form results ====
results_df = pd.DataFrame(all_results)
results_df.to_csv(BASE / f"mmd_results_{CSV_TYPE}.csv", index=False)
print(f"All results saved to {BASE}/mmd_results_{CSV_TYPE}.csv")
# Out:
# Found 48 folders.
#
# === Processing run_01 ===
# Found 48 valid datasets for run_01: ['blackhole_var10_base', 'blackhole_var10_dec', 'blackhole_var10_oo', 'blackhole_var15_base', 'blackhole_var15_dec', 'blackhole_var15_oo', 'blackhole_var20_base', 'blackhole_var20_dec', 'blackhole_var20_oo', 'blackhole_var5_base', 'blackhole_var5_dec', 'blackhole_var5_oo', 'disflooding_var10_base', 'disflooding_var10_dec', 'disflooding_var10_oo', 'disflooding_var15_base', 'disflooding_var15_dec', 'disflooding_var15_oo', 'disflooding_var20_base', 'disflooding_var20_dec', 'disflooding_var20_oo', 'disflooding_var5_base', 'disflooding_var5_dec', 'disflooding_var5_oo', 'localrepair_var10_base', 'localrepair_var10_dec', 'localrepair_var10_oo', 'localrepair_var15_base', 'localrepair_var15_dec', 'localrepair_var15_oo', 'localrepair_var20_base', 'localrepair_var20_dec', 'localrepair_var20_oo', 'localrepair_var5_base', 'localrepair_var5_dec', 'localrepair_var5_oo', 'worstparent_var10_base', 'worstparent_var10_dec', 'worstparent_var10_oo', 'worstparent_var15_base', 'worstparent_var15_dec', 'worstparent_var15_oo', 'worstparent_var20_base', 'worstparent_var20_dec', 'worstparent_var20_oo', 'worstparent_var5_base', 'worstparent_var5_dec', 'worstparent_var5_oo']
# MMD(blackhole_var10_dec, blackhole_var10_base) = 0.0035
# MMD(blackhole_var10_oo, blackhole_var10_base) = 0.0024
# MMD(blackhole_var10_oo, blackhole_var10_dec) = 0.0024
# MMD(blackhole_var15_base, blackhole_var10_base) = 0.0165
# MMD(blackhole_var15_base, blackhole_var10_dec) = 0.0150
# MMD(blackhole_var15_base, blackhole_var10_oo) = 0.0160
# MMD(blackhole_var15_dec, blackhole_var10_base) = 0.0157
# MMD(blackhole_var15_dec, blackhole_var10_dec) = 0.0142
# MMD(blackhole_var15_dec, blackhole_var10_oo) = 0.0151
# MMD(blackhole_var15_dec, blackhole_var15_base) = 0.0041
# MMD(blackhole_var15_oo, blackhole_var10_base) = 0.0169
# MMD(blackhole_var15_oo, blackhole_var10_dec) = 0.0154
# MMD(blackhole_var15_oo, blackhole_var10_oo) = 0.0163
# MMD(blackhole_var15_oo, blackhole_var15_base) = 0.0027
# MMD(blackhole_var15_oo, blackhole_var15_dec) = 0.0031
# MMD(blackhole_var20_base, blackhole_var10_base) = 0.0132
# MMD(blackhole_var20_base, blackhole_var10_dec) = 0.0116
# MMD(blackhole_var20_base, blackhole_var10_oo) = 0.0124
# MMD(blackhole_var20_base, blackhole_var15_base) = 0.0115
# MMD(blackhole_var20_base, blackhole_var15_dec) = 0.0104
# MMD(blackhole_var20_base, blackhole_var15_oo) = 0.0121
# MMD(blackhole_var20_dec, blackhole_var10_base) = 0.0135
# MMD(blackhole_var20_dec, blackhole_var10_dec) = 0.0119
# MMD(blackhole_var20_dec, blackhole_var10_oo) = 0.0128
# MMD(blackhole_var20_dec, blackhole_var15_base) = 0.0119
# MMD(blackhole_var20_dec, blackhole_var15_dec) = 0.0104
# MMD(blackhole_var20_dec, blackhole_var15_oo) = 0.0124
# MMD(blackhole_var20_dec, blackhole_var20_base) = 0.0021
# MMD(blackhole_var20_oo, blackhole_var10_base) = 0.0135
# MMD(blackhole_var20_oo, blackhole_var10_dec) = 0.0119
# MMD(blackhole_var20_oo, blackhole_var10_oo) = 0.0128
# MMD(blackhole_var20_oo, blackhole_var15_base) = 0.0119
# MMD(blackhole_var20_oo, blackhole_var15_dec) = 0.0106
# MMD(blackhole_var20_oo, blackhole_var15_oo) = 0.0122
# MMD(blackhole_var20_oo, blackhole_var20_base) = 0.0016
# MMD(blackhole_var20_oo, blackhole_var20_dec) = 0.0011
# MMD(blackhole_var5_base, blackhole_var10_base) = 0.0610
# MMD(blackhole_var5_base, blackhole_var10_dec) = 0.0575
# MMD(blackhole_var5_base, blackhole_var10_oo) = 0.0615
# MMD(blackhole_var5_base, blackhole_var15_base) = 0.0607
# MMD(blackhole_var5_base, blackhole_var15_dec) = 0.0590
# MMD(blackhole_var5_base, blackhole_var15_oo) = 0.0614
# MMD(blackhole_var5_base, blackhole_var20_base) = 0.0559
# MMD(blackhole_var5_base, blackhole_var20_dec) = 0.0560
# MMD(blackhole_var5_base, blackhole_var20_oo) = 0.0563
# MMD(blackhole_var5_dec, blackhole_var10_base) = 0.0608
# MMD(blackhole_var5_dec, blackhole_var10_dec) = 0.0575
# MMD(blackhole_var5_dec, blackhole_var10_oo) = 0.0614
# MMD(blackhole_var5_dec, blackhole_var15_base) = 0.0606
# MMD(blackhole_var5_dec, blackhole_var15_dec) = 0.0590
# MMD(blackhole_var5_dec, blackhole_var15_oo) = 0.0613
# MMD(blackhole_var5_dec, blackhole_var20_base) = 0.0558
# MMD(blackhole_var5_dec, blackhole_var20_dec) = 0.0559
# MMD(blackhole_var5_dec, blackhole_var20_oo) = 0.0563
# MMD(blackhole_var5_dec, blackhole_var5_base) = 0.0017
# MMD(blackhole_var5_oo, blackhole_var10_base) = 0.0671
# MMD(blackhole_var5_oo, blackhole_var10_dec) = 0.0628
# MMD(blackhole_var5_oo, blackhole_var10_oo) = 0.0670
# MMD(blackhole_var5_oo, blackhole_var15_base) = 0.0663
# MMD(blackhole_var5_oo, blackhole_var15_dec) = 0.0648
# MMD(blackhole_var5_oo, blackhole_var15_oo) = 0.0669
# MMD(blackhole_var5_oo, blackhole_var20_base) = 0.0616
# MMD(blackhole_var5_oo, blackhole_var20_dec) = 0.0616
# MMD(blackhole_var5_oo, blackhole_var20_oo) = 0.0619
# MMD(blackhole_var5_oo, blackhole_var5_base) = 0.0027
# MMD(blackhole_var5_oo, blackhole_var5_dec) = 0.0023
# MMD(disflooding_var10_base, blackhole_var10_base) = 0.0150
# MMD(disflooding_var10_base, blackhole_var10_dec) = 0.0138
# MMD(disflooding_var10_base, blackhole_var10_oo) = 0.0143
# MMD(disflooding_var10_base, blackhole_var15_base) = 0.0148
# MMD(disflooding_var10_base, blackhole_var15_dec) = 0.0136
# MMD(disflooding_var10_base, blackhole_var15_oo) = 0.0153
# MMD(disflooding_var10_base, blackhole_var20_base) = 0.0100
# MMD(disflooding_var10_base, blackhole_var20_dec) = 0.0104
# MMD(disflooding_var10_base, blackhole_var20_oo) = 0.0103
# MMD(disflooding_var10_base, blackhole_var5_base) = 0.0592
# MMD(disflooding_var10_base, blackhole_var5_dec) = 0.0591
# MMD(disflooding_var10_base, blackhole_var5_oo) = 0.0647
# MMD(disflooding_var10_dec, blackhole_var10_base) = 0.0155
# MMD(disflooding_var10_dec, blackhole_var10_dec) = 0.0147
# MMD(disflooding_var10_dec, blackhole_var10_oo) = 0.0152
# MMD(disflooding_var10_dec, blackhole_var15_base) = 0.0156
# MMD(disflooding_var10_dec, blackhole_var15_dec) = 0.0145
# MMD(disflooding_var10_dec, blackhole_var15_oo) = 0.0165
# MMD(disflooding_var10_dec, blackhole_var20_base) = 0.0112
# MMD(disflooding_var10_dec, blackhole_var20_dec) = 0.0117
# MMD(disflooding_var10_dec, blackhole_var20_oo) = 0.0116
# MMD(disflooding_var10_dec, blackhole_var5_base) = 0.0604
# MMD(disflooding_var10_dec, blackhole_var5_dec) = 0.0604
# MMD(disflooding_var10_dec, blackhole_var5_oo) = 0.0659
# MMD(disflooding_var10_dec, disflooding_var10_base) = 0.0124
# MMD(disflooding_var10_oo, blackhole_var10_base) = 0.0141
# MMD(disflooding_var10_oo, blackhole_var10_dec) = 0.0128
# MMD(disflooding_var10_oo, blackhole_var10_oo) = 0.0136
# MMD(disflooding_var10_oo, blackhole_var15_base) = 0.0133
# MMD(disflooding_var10_oo, blackhole_var15_dec) = 0.0120
# MMD(disflooding_var10_oo, blackhole_var15_oo) = 0.0138
# MMD(disflooding_var10_oo, blackhole_var20_base) = 0.0087
# MMD(disflooding_var10_oo, blackhole_var20_dec) = 0.0088
# MMD(disflooding_var10_oo, blackhole_var20_oo) = 0.0088
# MMD(disflooding_var10_oo, blackhole_var5_base) = 0.0576
# MMD(disflooding_var10_oo, blackhole_var5_dec) = 0.0576
# MMD(disflooding_var10_oo, blackhole_var5_oo) = 0.0631
# MMD(disflooding_var10_oo, disflooding_var10_base) = 0.0102
# MMD(disflooding_var10_oo, disflooding_var10_dec) = 0.0085
# MMD(disflooding_var15_base, blackhole_var10_base) = 0.0156
# MMD(disflooding_var15_base, blackhole_var10_dec) = 0.0141
# MMD(disflooding_var15_base, blackhole_var10_oo) = 0.0150
# MMD(disflooding_var15_base, blackhole_var15_base) = 0.0143
# MMD(disflooding_var15_base, blackhole_var15_dec) = 0.0126
# MMD(disflooding_var15_base, blackhole_var15_oo) = 0.0147
# MMD(disflooding_var15_base, blackhole_var20_base) = 0.0096
# MMD(disflooding_var15_base, blackhole_var20_dec) = 0.0098
# MMD(disflooding_var15_base, blackhole_var20_oo) = 0.0097
# MMD(disflooding_var15_base, blackhole_var5_base) = 0.0585
# MMD(disflooding_var15_base, blackhole_var5_dec) = 0.0585
# MMD(disflooding_var15_base, blackhole_var5_oo) = 0.0641
# MMD(disflooding_var15_base, disflooding_var10_base) = 0.0125
# MMD(disflooding_var15_base, disflooding_var10_dec) = 0.0132
# MMD(disflooding_var15_base, disflooding_var10_oo) = 0.0105
# MMD(disflooding_var15_dec, blackhole_var10_base) = 0.0132
# MMD(disflooding_var15_dec, blackhole_var10_dec) = 0.0115
# MMD(disflooding_var15_dec, blackhole_var10_oo) = 0.0125
# MMD(disflooding_var15_dec, blackhole_var15_base) = 0.0117
# MMD(disflooding_var15_dec, blackhole_var15_dec) = 0.0105
# MMD(disflooding_var15_dec, blackhole_var15_oo) = 0.0122
# MMD(disflooding_var15_dec, blackhole_var20_base) = 0.0071
# MMD(disflooding_var15_dec, blackhole_var20_dec) = 0.0072
# MMD(disflooding_var15_dec, blackhole_var20_oo) = 0.0071
# MMD(disflooding_var15_dec, blackhole_var5_base) = 0.0560
# MMD(disflooding_var15_dec, blackhole_var5_dec) = 0.0560
# MMD(disflooding_var15_dec, blackhole_var5_oo) = 0.0616
# MMD(disflooding_var15_dec, disflooding_var10_base) = 0.0098
# MMD(disflooding_var15_dec, disflooding_var10_dec) = 0.0113
# MMD(disflooding_var15_dec, disflooding_var10_oo) = 0.0085
# MMD(disflooding_var15_dec, disflooding_var15_base) = 0.0085
# MMD(disflooding_var15_oo, blackhole_var10_base) = 0.0135
# MMD(disflooding_var15_oo, blackhole_var10_dec) = 0.0117
# MMD(disflooding_var15_oo, blackhole_var10_oo) = 0.0128
# MMD(disflooding_var15_oo, blackhole_var15_base) = 0.0111
# MMD(disflooding_var15_oo, blackhole_var15_dec) = 0.0102
# MMD(disflooding_var15_oo, blackhole_var15_oo) = 0.0116
# MMD(disflooding_var15_oo, blackhole_var20_base) = 0.0073
# MMD(disflooding_var15_oo, blackhole_var20_dec) = 0.0076
# MMD(disflooding_var15_oo, blackhole_var20_oo) = 0.0075
# MMD(disflooding_var15_oo, blackhole_var5_base) = 0.0564
# MMD(disflooding_var15_oo, blackhole_var5_dec) = 0.0563
# MMD(disflooding_var15_oo, blackhole_var5_oo) = 0.0620
# MMD(disflooding_var15_oo, disflooding_var10_base) = 0.0102
# MMD(disflooding_var15_oo, disflooding_var10_dec) = 0.0115
# MMD(disflooding_var15_oo, disflooding_var10_oo) = 0.0088
# MMD(disflooding_var15_oo, disflooding_var15_base) = 0.0097
# MMD(disflooding_var15_oo, disflooding_var15_dec) = 0.0067
# MMD(disflooding_var20_base, blackhole_var10_base) = 0.0126
# MMD(disflooding_var20_base, blackhole_var10_dec) = 0.0110
# MMD(disflooding_var20_base, blackhole_var10_oo) = 0.0119
# MMD(disflooding_var20_base, blackhole_var15_base) = 0.0112
# MMD(disflooding_var20_base, blackhole_var15_dec) = 0.0100
# MMD(disflooding_var20_base, blackhole_var15_oo) = 0.0117
# MMD(disflooding_var20_base, blackhole_var20_base) = 0.0066
# MMD(disflooding_var20_base, blackhole_var20_dec) = 0.0067
# MMD(disflooding_var20_base, blackhole_var20_oo) = 0.0067
# MMD(disflooding_var20_base, blackhole_var5_base) = 0.0556
# MMD(disflooding_var20_base, blackhole_var5_dec) = 0.0555
# MMD(disflooding_var20_base, blackhole_var5_oo) = 0.0612
# MMD(disflooding_var20_base, disflooding_var10_base) = 0.0094
# MMD(disflooding_var20_base, disflooding_var10_dec) = 0.0107
# MMD(disflooding_var20_base, disflooding_var10_oo) = 0.0079
# MMD(disflooding_var20_base, disflooding_var15_base) = 0.0088
# MMD(disflooding_var20_base, disflooding_var15_dec) = 0.0063
# MMD(disflooding_var20_base, disflooding_var15_oo) = 0.0067
# MMD(disflooding_var20_dec, blackhole_var10_base) = 0.0120
# MMD(disflooding_var20_dec, blackhole_var10_dec) = 0.0104
# MMD(disflooding_var20_dec, blackhole_var10_oo) = 0.0112
# MMD(disflooding_var20_dec, blackhole_var15_base) = 0.0107
# MMD(disflooding_var20_dec, blackhole_var15_dec) = 0.0094
# MMD(disflooding_var20_dec, blackhole_var15_oo) = 0.0111
# MMD(disflooding_var20_dec, blackhole_var20_base) = 0.0060
# MMD(disflooding_var20_dec, blackhole_var20_dec) = 0.0062
# MMD(disflooding_var20_dec, blackhole_var20_oo) = 0.0061
# MMD(disflooding_var20_dec, blackhole_var5_base) = 0.0550
# MMD(disflooding_var20_dec, blackhole_var5_dec) = 0.0550
# MMD(disflooding_var20_dec, blackhole_var5_oo) = 0.0606
# MMD(disflooding_var20_dec, disflooding_var10_base) = 0.0090
# MMD(disflooding_var20_dec, disflooding_var10_dec) = 0.0102
# MMD(disflooding_var20_dec, disflooding_var10_oo) = 0.0074
# MMD(disflooding_var20_dec, disflooding_var15_base) = 0.0084
# MMD(disflooding_var20_dec, disflooding_var15_dec) = 0.0058
# MMD(disflooding_var20_dec, disflooding_var15_oo) = 0.0059
# MMD(disflooding_var20_dec, disflooding_var20_base) = 0.0053
# MMD(disflooding_var20_oo, blackhole_var10_base) = 0.0116
# MMD(disflooding_var20_oo, blackhole_var10_dec) = 0.0099
# MMD(disflooding_var20_oo, blackhole_var10_oo) = 0.0109
# MMD(disflooding_var20_oo, blackhole_var15_base) = 0.0102
# MMD(disflooding_var20_oo, blackhole_var15_dec) = 0.0090
# MMD(disflooding_var20_oo, blackhole_var15_oo) = 0.0106
# MMD(disflooding_var20_oo, blackhole_var20_base) = 0.0056
# MMD(disflooding_var20_oo, blackhole_var20_dec) = 0.0057
# MMD(disflooding_var20_oo, blackhole_var20_oo) = 0.0056
# MMD(disflooding_var20_oo, blackhole_var5_base) = 0.0545
# MMD(disflooding_var20_oo, blackhole_var5_dec) = 0.0544
# MMD(disflooding_var20_oo, blackhole_var5_oo) = 0.0601
# MMD(disflooding_var20_oo, disflooding_var10_base) = 0.0083
# MMD(disflooding_var20_oo, disflooding_var10_dec) = 0.0097
# MMD(disflooding_var20_oo, disflooding_var10_oo) = 0.0069
# MMD(disflooding_var20_oo, disflooding_var15_base) = 0.0078
# MMD(disflooding_var20_oo, disflooding_var15_dec) = 0.0053
# MMD(disflooding_var20_oo, disflooding_var15_oo) = 0.0056
# MMD(disflooding_var20_oo, disflooding_var20_base) = 0.0046
# MMD(disflooding_var20_oo, disflooding_var20_dec) = 0.0043
# MMD(disflooding_var5_base, blackhole_var10_base) = 0.0248
# MMD(disflooding_var5_base, blackhole_var10_dec) = 0.0229
# MMD(disflooding_var5_base, blackhole_var10_oo) = 0.0243
# MMD(disflooding_var5_base, blackhole_var15_base) = 0.0228
# MMD(disflooding_var5_base, blackhole_var15_dec) = 0.0221
# MMD(disflooding_var5_base, blackhole_var15_oo) = 0.0239
# MMD(disflooding_var5_base, blackhole_var20_base) = 0.0181
# MMD(disflooding_var5_base, blackhole_var20_dec) = 0.0189
# MMD(disflooding_var5_base, blackhole_var20_oo) = 0.0189
# MMD(disflooding_var5_base, blackhole_var5_base) = 0.0580
# MMD(disflooding_var5_base, blackhole_var5_dec) = 0.0570
# MMD(disflooding_var5_base, blackhole_var5_oo) = 0.0617
# MMD(disflooding_var5_base, disflooding_var10_base) = 0.0217
# MMD(disflooding_var5_base, disflooding_var10_dec) = 0.0230
# MMD(disflooding_var5_base, disflooding_var10_oo) = 0.0202
# MMD(disflooding_var5_base, disflooding_var15_base) = 0.0211
# MMD(disflooding_var5_base, disflooding_var15_dec) = 0.0186
# MMD(disflooding_var5_base, disflooding_var15_oo) = 0.0189
# MMD(disflooding_var5_base, disflooding_var20_base) = 0.0181
# MMD(disflooding_var5_base, disflooding_var20_dec) = 0.0176
# MMD(disflooding_var5_base, disflooding_var20_oo) = 0.0168
# MMD(disflooding_var5_dec, blackhole_var10_base) = 0.0206
# MMD(disflooding_var5_dec, blackhole_var10_dec) = 0.0186
# MMD(disflooding_var5_dec, blackhole_var10_oo) = 0.0200
# MMD(disflooding_var5_dec, blackhole_var15_base) = 0.0189
# MMD(disflooding_var5_dec, blackhole_var15_dec) = 0.0179
# MMD(disflooding_var5_dec, blackhole_var15_oo) = 0.0197
# MMD(disflooding_var5_dec, blackhole_var20_base) = 0.0143
# MMD(disflooding_var5_dec, blackhole_var20_dec) = 0.0146
# MMD(disflooding_var5_dec, blackhole_var20_oo) = 0.0146
# MMD(disflooding_var5_dec, blackhole_var5_base) = 0.0476
# MMD(disflooding_var5_dec, blackhole_var5_dec) = 0.0471
# MMD(disflooding_var5_dec, blackhole_var5_oo) = 0.0515
# MMD(disflooding_var5_dec, disflooding_var10_base) = 0.0175
# MMD(disflooding_var5_dec, disflooding_var10_dec) = 0.0187
# MMD(disflooding_var5_dec, disflooding_var10_oo) = 0.0159
# MMD(disflooding_var5_dec, disflooding_var15_base) = 0.0169
# MMD(disflooding_var5_dec, disflooding_var15_dec) = 0.0143
# MMD(disflooding_var5_dec, disflooding_var15_oo) = 0.0147
# MMD(disflooding_var5_dec, disflooding_var20_base) = 0.0139
# MMD(disflooding_var5_dec, disflooding_var20_dec) = 0.0133
# MMD(disflooding_var5_dec, disflooding_var20_oo) = 0.0128
# MMD(disflooding_var5_dec, disflooding_var5_base) = 0.0218
# MMD(disflooding_var5_oo, blackhole_var10_base) = 0.0172
# MMD(disflooding_var5_oo, blackhole_var10_dec) = 0.0152
# MMD(disflooding_var5_oo, blackhole_var10_oo) = 0.0166
# MMD(disflooding_var5_oo, blackhole_var15_base) = 0.0154
# MMD(disflooding_var5_oo, blackhole_var15_dec) = 0.0145
# MMD(disflooding_var5_oo, blackhole_var15_oo) = 0.0163
# MMD(disflooding_var5_oo, blackhole_var20_base) = 0.0107
# MMD(disflooding_var5_oo, blackhole_var20_dec) = 0.0113
# MMD(disflooding_var5_oo, blackhole_var20_oo) = 0.0113
# MMD(disflooding_var5_oo, blackhole_var5_base) = 0.0442
# MMD(disflooding_var5_oo, blackhole_var5_dec) = 0.0438
# MMD(disflooding_var5_oo, blackhole_var5_oo) = 0.0485
# MMD(disflooding_var5_oo, disflooding_var10_base) = 0.0141
# MMD(disflooding_var5_oo, disflooding_var10_dec) = 0.0153
# MMD(disflooding_var5_oo, disflooding_var10_oo) = 0.0126
# MMD(disflooding_var5_oo, disflooding_var15_base) = 0.0135
# MMD(disflooding_var5_oo, disflooding_var15_dec) = 0.0110
# MMD(disflooding_var5_oo, disflooding_var15_oo) = 0.0113
# MMD(disflooding_var5_oo, disflooding_var20_base) = 0.0105
# MMD(disflooding_var5_oo, disflooding_var20_dec) = 0.0099
# MMD(disflooding_var5_oo, disflooding_var20_oo) = 0.0094
# MMD(disflooding_var5_oo, disflooding_var5_base) = 0.0180
# MMD(disflooding_var5_oo, disflooding_var5_dec) = 0.0139
# MMD(localrepair_var10_base, blackhole_var10_base) = 0.0158
# MMD(localrepair_var10_base, blackhole_var10_dec) = 0.0147
# MMD(localrepair_var10_base, blackhole_var10_oo) = 0.0153
# MMD(localrepair_var10_base, blackhole_var15_base) = 0.0191
# MMD(localrepair_var10_base, blackhole_var15_dec) = 0.0179
# MMD(localrepair_var10_base, blackhole_var15_oo) = 0.0195
# MMD(localrepair_var10_base, blackhole_var20_base) = 0.0144
# MMD(localrepair_var10_base, blackhole_var20_dec) = 0.0147
# MMD(localrepair_var10_base, blackhole_var20_oo) = 0.0147
# MMD(localrepair_var10_base, blackhole_var5_base) = 0.0635
# MMD(localrepair_var10_base, blackhole_var5_dec) = 0.0635
# MMD(localrepair_var10_base, blackhole_var5_oo) = 0.0691
# MMD(localrepair_var10_base, disflooding_var10_base) = 0.0171
# MMD(localrepair_var10_base, disflooding_var10_dec) = 0.0176
# MMD(localrepair_var10_base, disflooding_var10_oo) = 0.0155
# MMD(localrepair_var10_base, disflooding_var15_base) = 0.0169
# MMD(localrepair_var10_base, disflooding_var15_dec) = 0.0144
# MMD(localrepair_var10_base, disflooding_var15_oo) = 0.0147
# MMD(localrepair_var10_base, disflooding_var20_base) = 0.0139
# MMD(localrepair_var10_base, disflooding_var20_dec) = 0.0133
# MMD(localrepair_var10_base, disflooding_var20_oo) = 0.0128
# MMD(localrepair_var10_base, disflooding_var5_base) = 0.0261
# MMD(localrepair_var10_base, disflooding_var5_dec) = 0.0218
# MMD(localrepair_var10_base, disflooding_var5_oo) = 0.0184
# MMD(localrepair_var10_dec, blackhole_var10_base) = 0.0144
# MMD(localrepair_var10_dec, blackhole_var10_dec) = 0.0136
# MMD(localrepair_var10_dec, blackhole_var10_oo) = 0.0140
# MMD(localrepair_var10_dec, blackhole_var15_base) = 0.0196
# MMD(localrepair_var10_dec, blackhole_var15_dec) = 0.0184
# MMD(localrepair_var10_dec, blackhole_var15_oo) = 0.0200
# MMD(localrepair_var10_dec, blackhole_var20_base) = 0.0149
# MMD(localrepair_var10_dec, blackhole_var20_dec) = 0.0154
# MMD(localrepair_var10_dec, blackhole_var20_oo) = 0.0153
# MMD(localrepair_var10_dec, blackhole_var5_base) = 0.0642
# MMD(localrepair_var10_dec, blackhole_var5_dec) = 0.0641
# MMD(localrepair_var10_dec, blackhole_var5_oo) = 0.0697
# MMD(localrepair_var10_dec, disflooding_var10_base) = 0.0175
# MMD(localrepair_var10_dec, disflooding_var10_dec) = 0.0176
# MMD(localrepair_var10_dec, disflooding_var10_oo) = 0.0159
# MMD(localrepair_var10_dec, disflooding_var15_base) = 0.0175
# MMD(localrepair_var10_dec, disflooding_var15_dec) = 0.0150
# MMD(localrepair_var10_dec, disflooding_var15_oo) = 0.0153
# MMD(localrepair_var10_dec, disflooding_var20_base) = 0.0145
# MMD(localrepair_var10_dec, disflooding_var20_dec) = 0.0140
# MMD(localrepair_var10_dec, disflooding_var20_oo) = 0.0134
# MMD(localrepair_var10_dec, disflooding_var5_base) = 0.0267
# MMD(localrepair_var10_dec, disflooding_var5_dec) = 0.0224
# MMD(localrepair_var10_dec, disflooding_var5_oo) = 0.0191
# MMD(localrepair_var10_dec, localrepair_var10_base) = 0.0111
# MMD(localrepair_var10_oo, blackhole_var10_base) = 0.0147
# MMD(localrepair_var10_oo, blackhole_var10_dec) = 0.0136
# MMD(localrepair_var10_oo, blackhole_var10_oo) = 0.0142
# MMD(localrepair_var10_oo, blackhole_var15_base) = 0.0208
# MMD(localrepair_var10_oo, blackhole_var15_dec) = 0.0196
# MMD(localrepair_var10_oo, blackhole_var15_oo) = 0.0211
# MMD(localrepair_var10_oo, blackhole_var20_base) = 0.0161
# MMD(localrepair_var10_oo, blackhole_var20_dec) = 0.0166
# MMD(localrepair_var10_oo, blackhole_var20_oo) = 0.0165
# MMD(localrepair_var10_oo, blackhole_var5_base) = 0.0653
# MMD(localrepair_var10_oo, blackhole_var5_dec) = 0.0652
# MMD(localrepair_var10_oo, blackhole_var5_oo) = 0.0708
# MMD(localrepair_var10_oo, disflooding_var10_base) = 0.0186
# MMD(localrepair_var10_oo, disflooding_var10_dec) = 0.0186
# MMD(localrepair_var10_oo, disflooding_var10_oo) = 0.0172
# MMD(localrepair_var10_oo, disflooding_var15_base) = 0.0187
# MMD(localrepair_var10_oo, disflooding_var15_dec) = 0.0162
# MMD(localrepair_var10_oo, disflooding_var15_oo) = 0.0165
# MMD(localrepair_var10_oo, disflooding_var20_base) = 0.0157
# MMD(localrepair_var10_oo, disflooding_var20_dec) = 0.0152
# MMD(localrepair_var10_oo, disflooding_var20_oo) = 0.0146
# MMD(localrepair_var10_oo, disflooding_var5_base) = 0.0279
# MMD(localrepair_var10_oo, disflooding_var5_dec) = 0.0236
# MMD(localrepair_var10_oo, disflooding_var5_oo) = 0.0203
# MMD(localrepair_var10_oo, localrepair_var10_base) = 0.0066
# MMD(localrepair_var10_oo, localrepair_var10_dec) = 0.0061
# MMD(localrepair_var15_base, blackhole_var10_base) = 0.0167
# MMD(localrepair_var15_base, blackhole_var10_dec) = 0.0151
# MMD(localrepair_var15_base, blackhole_var10_oo) = 0.0160
# MMD(localrepair_var15_base, blackhole_var15_base) = 0.0147
# MMD(localrepair_var15_base, blackhole_var15_dec) = 0.0134
# MMD(localrepair_var15_base, blackhole_var15_oo) = 0.0151
# MMD(localrepair_var15_base, blackhole_var20_base) = 0.0106
# MMD(localrepair_var15_base, blackhole_var20_dec) = 0.0107
# MMD(localrepair_var15_base, blackhole_var20_oo) = 0.0107
# MMD(localrepair_var15_base, blackhole_var5_base) = 0.0597
# MMD(localrepair_var15_base, blackhole_var5_dec) = 0.0596
# MMD(localrepair_var15_base, blackhole_var5_oo) = 0.0652
# MMD(localrepair_var15_base, disflooding_var10_base) = 0.0136
# MMD(localrepair_var15_base, disflooding_var10_dec) = 0.0149
# MMD(localrepair_var15_base, disflooding_var10_oo) = 0.0121
# MMD(localrepair_var15_base, disflooding_var15_base) = 0.0130
# MMD(localrepair_var15_base, disflooding_var15_dec) = 0.0102
# MMD(localrepair_var15_base, disflooding_var15_oo) = 0.0108
# MMD(localrepair_var15_base, disflooding_var20_base) = 0.0100
# MMD(localrepair_var15_base, disflooding_var20_dec) = 0.0094
# MMD(localrepair_var15_base, disflooding_var20_oo) = 0.0089
# MMD(localrepair_var15_base, disflooding_var5_base) = 0.0222
# MMD(localrepair_var15_base, disflooding_var5_dec) = 0.0179
# MMD(localrepair_var15_base, disflooding_var5_oo) = 0.0146
# MMD(localrepair_var15_base, localrepair_var10_base) = 0.0179
# MMD(localrepair_var15_base, localrepair_var10_dec) = 0.0185
# MMD(localrepair_var15_base, localrepair_var10_oo) = 0.0197
# MMD(localrepair_var15_dec, blackhole_var10_base) = 0.0183
# MMD(localrepair_var15_dec, blackhole_var10_dec) = 0.0167
# MMD(localrepair_var15_dec, blackhole_var10_oo) = 0.0176
# MMD(localrepair_var15_dec, blackhole_var15_base) = 0.0161
# MMD(localrepair_var15_dec, blackhole_var15_dec) = 0.0147
# MMD(localrepair_var15_dec, blackhole_var15_oo) = 0.0164
# MMD(localrepair_var15_dec, blackhole_var20_base) = 0.0122
# MMD(localrepair_var15_dec, blackhole_var20_dec) = 0.0123
# MMD(localrepair_var15_dec, blackhole_var20_oo) = 0.0124
# MMD(localrepair_var15_dec, blackhole_var5_base) = 0.0613
# MMD(localrepair_var15_dec, blackhole_var5_dec) = 0.0612
# MMD(localrepair_var15_dec, blackhole_var5_oo) = 0.0669
# MMD(localrepair_var15_dec, disflooding_var10_base) = 0.0153
# MMD(localrepair_var15_dec, disflooding_var10_dec) = 0.0165
# MMD(localrepair_var15_dec, disflooding_var10_oo) = 0.0137
# MMD(localrepair_var15_dec, disflooding_var15_base) = 0.0147
# MMD(localrepair_var15_dec, disflooding_var15_dec) = 0.0116
# MMD(localrepair_var15_dec, disflooding_var15_oo) = 0.0124
# MMD(localrepair_var15_dec, disflooding_var20_base) = 0.0116
# MMD(localrepair_var15_dec, disflooding_var20_dec) = 0.0110
# MMD(localrepair_var15_dec, disflooding_var20_oo) = 0.0106
# MMD(localrepair_var15_dec, disflooding_var5_base) = 0.0238
# MMD(localrepair_var15_dec, disflooding_var5_dec) = 0.0196
# MMD(localrepair_var15_dec, disflooding_var5_oo) = 0.0162
# MMD(localrepair_var15_dec, localrepair_var10_base) = 0.0195
# MMD(localrepair_var15_dec, localrepair_var10_dec) = 0.0201
# MMD(localrepair_var15_dec, localrepair_var10_oo) = 0.0213
# MMD(localrepair_var15_dec, localrepair_var15_base) = 0.0054
# MMD(localrepair_var15_oo, blackhole_var10_base) = 0.0194
# MMD(localrepair_var15_oo, blackhole_var10_dec) = 0.0178
# MMD(localrepair_var15_oo, blackhole_var10_oo) = 0.0187
# MMD(localrepair_var15_oo, blackhole_var15_base) = 0.0172
# MMD(localrepair_var15_oo, blackhole_var15_dec) = 0.0157
# MMD(localrepair_var15_oo, blackhole_var15_oo) = 0.0174
# MMD(localrepair_var15_oo, blackhole_var20_base) = 0.0133
# MMD(localrepair_var15_oo, blackhole_var20_dec) = 0.0135
# MMD(localrepair_var15_oo, blackhole_var20_oo) = 0.0135
# MMD(localrepair_var15_oo, blackhole_var5_base) = 0.0625
# MMD(localrepair_var15_oo, blackhole_var5_dec) = 0.0624
# MMD(localrepair_var15_oo, blackhole_var5_oo) = 0.0680
# MMD(localrepair_var15_oo, disflooding_var10_base) = 0.0164
# MMD(localrepair_var15_oo, disflooding_var10_dec) = 0.0177
# MMD(localrepair_var15_oo, disflooding_var10_oo) = 0.0149
# MMD(localrepair_var15_oo, disflooding_var15_base) = 0.0158
# MMD(localrepair_var15_oo, disflooding_var15_dec) = 0.0128
# MMD(localrepair_var15_oo, disflooding_var15_oo) = 0.0136
# MMD(localrepair_var15_oo, disflooding_var20_base) = 0.0128
# MMD(localrepair_var15_oo, disflooding_var20_dec) = 0.0122
# MMD(localrepair_var15_oo, disflooding_var20_oo) = 0.0117
# MMD(localrepair_var15_oo, disflooding_var5_base) = 0.0250
# MMD(localrepair_var15_oo, disflooding_var5_dec) = 0.0208
# MMD(localrepair_var15_oo, disflooding_var5_oo) = 0.0174
# MMD(localrepair_var15_oo, localrepair_var10_base) = 0.0207
# MMD(localrepair_var15_oo, localrepair_var10_dec) = 0.0213
# MMD(localrepair_var15_oo, localrepair_var10_oo) = 0.0225
# MMD(localrepair_var15_oo, localrepair_var15_base) = 0.0038
# MMD(localrepair_var15_oo, localrepair_var15_dec) = 0.0027
# MMD(localrepair_var20_base, blackhole_var10_base) = 0.0137
# MMD(localrepair_var20_base, blackhole_var10_dec) = 0.0120
# MMD(localrepair_var20_base, blackhole_var10_oo) = 0.0130
# MMD(localrepair_var20_base, blackhole_var15_base) = 0.0121
# MMD(localrepair_var20_base, blackhole_var15_dec) = 0.0109
# MMD(localrepair_var20_base, blackhole_var15_oo) = 0.0126
# MMD(localrepair_var20_base, blackhole_var20_base) = 0.0074
# MMD(localrepair_var20_base, blackhole_var20_dec) = 0.0075
# MMD(localrepair_var20_base, blackhole_var20_oo) = 0.0074
# MMD(localrepair_var20_base, blackhole_var5_base) = 0.0565
# MMD(localrepair_var20_base, blackhole_var5_dec) = 0.0564
# MMD(localrepair_var20_base, blackhole_var5_oo) = 0.0621
# MMD(localrepair_var20_base, disflooding_var10_base) = 0.0105
# MMD(localrepair_var20_base, disflooding_var10_dec) = 0.0118
# MMD(localrepair_var20_base, disflooding_var10_oo) = 0.0089
# MMD(localrepair_var20_base, disflooding_var15_base) = 0.0099
# MMD(localrepair_var20_base, disflooding_var15_dec) = 0.0073
# MMD(localrepair_var20_base, disflooding_var15_oo) = 0.0077
# MMD(localrepair_var20_base, disflooding_var20_base) = 0.0068
# MMD(localrepair_var20_base, disflooding_var20_dec) = 0.0063
# MMD(localrepair_var20_base, disflooding_var20_oo) = 0.0058
# MMD(localrepair_var20_base, disflooding_var5_base) = 0.0191
# MMD(localrepair_var20_base, disflooding_var5_dec) = 0.0148
# MMD(localrepair_var20_base, disflooding_var5_oo) = 0.0114
# MMD(localrepair_var20_base, localrepair_var10_base) = 0.0148
# MMD(localrepair_var20_base, localrepair_var10_dec) = 0.0155
# MMD(localrepair_var20_base, localrepair_var10_oo) = 0.0167
# MMD(localrepair_var20_base, localrepair_var15_base) = 0.0109
# MMD(localrepair_var20_base, localrepair_var15_dec) = 0.0126
# MMD(localrepair_var20_base, localrepair_var15_oo) = 0.0137
# MMD(localrepair_var20_dec, blackhole_var10_base) = 0.0141
# MMD(localrepair_var20_dec, blackhole_var10_dec) = 0.0124
# MMD(localrepair_var20_dec, blackhole_var10_oo) = 0.0134
# MMD(localrepair_var20_dec, blackhole_var15_base) = 0.0125
# MMD(localrepair_var20_dec, blackhole_var15_dec) = 0.0113
# MMD(localrepair_var20_dec, blackhole_var15_oo) = 0.0129
# MMD(localrepair_var20_dec, blackhole_var20_base) = 0.0078
# MMD(localrepair_var20_dec, blackhole_var20_dec) = 0.0079
# MMD(localrepair_var20_dec, blackhole_var20_oo) = 0.0078
# MMD(localrepair_var20_dec, blackhole_var5_base) = 0.0569
# MMD(localrepair_var20_dec, blackhole_var5_dec) = 0.0569
# MMD(localrepair_var20_dec, blackhole_var5_oo) = 0.0625
# MMD(localrepair_var20_dec, disflooding_var10_base) = 0.0109
# MMD(localrepair_var20_dec, disflooding_var10_dec) = 0.0122
# MMD(localrepair_var20_dec, disflooding_var10_oo) = 0.0094
# MMD(localrepair_var20_dec, disflooding_var15_base) = 0.0103
# MMD(localrepair_var20_dec, disflooding_var15_dec) = 0.0077
# MMD(localrepair_var20_dec, disflooding_var15_oo) = 0.0081
# MMD(localrepair_var20_dec, disflooding_var20_base) = 0.0071
# MMD(localrepair_var20_dec, disflooding_var20_dec) = 0.0067
# MMD(localrepair_var20_dec, disflooding_var20_oo) = 0.0062
# MMD(localrepair_var20_dec, disflooding_var5_base) = 0.0195
# MMD(localrepair_var20_dec, disflooding_var5_dec) = 0.0152
# MMD(localrepair_var20_dec, disflooding_var5_oo) = 0.0118
# MMD(localrepair_var20_dec, localrepair_var10_base) = 0.0152
# MMD(localrepair_var20_dec, localrepair_var10_dec) = 0.0159
# MMD(localrepair_var20_dec, localrepair_var10_oo) = 0.0171
# MMD(localrepair_var20_dec, localrepair_var15_base) = 0.0113
# MMD(localrepair_var20_dec, localrepair_var15_dec) = 0.0129
# MMD(localrepair_var20_dec, localrepair_var15_oo) = 0.0141
# MMD(localrepair_var20_dec, localrepair_var20_base) = 0.0032
# MMD(localrepair_var20_oo, blackhole_var10_base) = 0.0140
# MMD(localrepair_var20_oo, blackhole_var10_dec) = 0.0123
# MMD(localrepair_var20_oo, blackhole_var10_oo) = 0.0133
# MMD(localrepair_var20_oo, blackhole_var15_base) = 0.0124
# MMD(localrepair_var20_oo, blackhole_var15_dec) = 0.0112
# MMD(localrepair_var20_oo, blackhole_var15_oo) = 0.0128
# MMD(localrepair_var20_oo, blackhole_var20_base) = 0.0076
# MMD(localrepair_var20_oo, blackhole_var20_dec) = 0.0077
# MMD(localrepair_var20_oo, blackhole_var20_oo) = 0.0077
# MMD(localrepair_var20_oo, blackhole_var5_base) = 0.0568
# MMD(localrepair_var20_oo, blackhole_var5_dec) = 0.0568
# MMD(localrepair_var20_oo, blackhole_var5_oo) = 0.0624
# MMD(localrepair_var20_oo, disflooding_var10_base) = 0.0107
# MMD(localrepair_var20_oo, disflooding_var10_dec) = 0.0120
# MMD(localrepair_var20_oo, disflooding_var10_oo) = 0.0093
# MMD(localrepair_var20_oo, disflooding_var15_base) = 0.0102
# MMD(localrepair_var20_oo, disflooding_var15_dec) = 0.0076
# MMD(localrepair_var20_oo, disflooding_var15_oo) = 0.0080
# MMD(localrepair_var20_oo, disflooding_var20_base) = 0.0070
# MMD(localrepair_var20_oo, disflooding_var20_dec) = 0.0066
# MMD(localrepair_var20_oo, disflooding_var20_oo) = 0.0061
# MMD(localrepair_var20_oo, disflooding_var5_base) = 0.0194
# MMD(localrepair_var20_oo, disflooding_var5_dec) = 0.0151
# MMD(localrepair_var20_oo, disflooding_var5_oo) = 0.0117
# MMD(localrepair_var20_oo, localrepair_var10_base) = 0.0151
# MMD(localrepair_var20_oo, localrepair_var10_dec) = 0.0158
# MMD(localrepair_var20_oo, localrepair_var10_oo) = 0.0170
# MMD(localrepair_var20_oo, localrepair_var15_base) = 0.0112
# MMD(localrepair_var20_oo, localrepair_var15_dec) = 0.0129
# MMD(localrepair_var20_oo, localrepair_var15_oo) = 0.0140
# MMD(localrepair_var20_oo, localrepair_var20_base) = 0.0022
# MMD(localrepair_var20_oo, localrepair_var20_dec) = 0.0015
# MMD(localrepair_var5_base, blackhole_var10_base) = 0.0500
# MMD(localrepair_var5_base, blackhole_var10_dec) = 0.0475
# MMD(localrepair_var5_base, blackhole_var10_oo) = 0.0494
# MMD(localrepair_var5_base, blackhole_var15_base) = 0.0486
# MMD(localrepair_var5_base, blackhole_var15_dec) = 0.0473
# MMD(localrepair_var5_base, blackhole_var15_oo) = 0.0491
# MMD(localrepair_var5_base, blackhole_var20_base) = 0.0440
# MMD(localrepair_var5_base, blackhole_var20_dec) = 0.0441
# MMD(localrepair_var5_base, blackhole_var20_oo) = 0.0441
# MMD(localrepair_var5_base, blackhole_var5_base) = 0.0625
# MMD(localrepair_var5_base, blackhole_var5_dec) = 0.0628
# MMD(localrepair_var5_base, blackhole_var5_oo) = 0.0657
# MMD(localrepair_var5_base, disflooding_var10_base) = 0.0469
# MMD(localrepair_var5_base, disflooding_var10_dec) = 0.0482
# MMD(localrepair_var5_base, disflooding_var10_oo) = 0.0454
# MMD(localrepair_var5_base, disflooding_var15_base) = 0.0463
# MMD(localrepair_var5_base, disflooding_var15_dec) = 0.0438
# MMD(localrepair_var5_base, disflooding_var15_oo) = 0.0441
# MMD(localrepair_var5_base, disflooding_var20_base) = 0.0433
# MMD(localrepair_var5_base, disflooding_var20_dec) = 0.0427
# MMD(localrepair_var5_base, disflooding_var20_oo) = 0.0422
# MMD(localrepair_var5_base, disflooding_var5_base) = 0.0518
# MMD(localrepair_var5_base, disflooding_var5_dec) = 0.0452
# MMD(localrepair_var5_base, disflooding_var5_oo) = 0.0423
# MMD(localrepair_var5_base, localrepair_var10_base) = 0.0505
# MMD(localrepair_var5_base, localrepair_var10_dec) = 0.0519
# MMD(localrepair_var5_base, localrepair_var10_oo) = 0.0530
# MMD(localrepair_var5_base, localrepair_var15_base) = 0.0474
# MMD(localrepair_var5_base, localrepair_var15_dec) = 0.0490
# MMD(localrepair_var5_base, localrepair_var15_oo) = 0.0502
# MMD(localrepair_var5_base, localrepair_var20_base) = 0.0442
# MMD(localrepair_var5_base, localrepair_var20_dec) = 0.0446
# MMD(localrepair_var5_base, localrepair_var20_oo) = 0.0445
# MMD(localrepair_var5_dec, blackhole_var10_base) = 0.0439
# MMD(localrepair_var5_dec, blackhole_var10_dec) = 0.0412
# MMD(localrepair_var5_dec, blackhole_var10_oo) = 0.0435
# MMD(localrepair_var5_dec, blackhole_var15_base) = 0.0427
# MMD(localrepair_var5_dec, blackhole_var15_dec) = 0.0413
# MMD(localrepair_var5_dec, blackhole_var15_oo) = 0.0432
# MMD(localrepair_var5_dec, blackhole_var20_base) = 0.0381
# MMD(localrepair_var5_dec, blackhole_var20_dec) = 0.0382
# MMD(localrepair_var5_dec, blackhole_var20_oo) = 0.0382
# MMD(localrepair_var5_dec, blackhole_var5_base) = 0.0412
# MMD(localrepair_var5_dec, blackhole_var5_dec) = 0.0418
# MMD(localrepair_var5_dec, blackhole_var5_oo) = 0.0432
# MMD(localrepair_var5_dec, disflooding_var10_base) = 0.0410
# MMD(localrepair_var5_dec, disflooding_var10_dec) = 0.0423
# MMD(localrepair_var5_dec, disflooding_var10_oo) = 0.0395
# MMD(localrepair_var5_dec, disflooding_var15_base) = 0.0404
# MMD(localrepair_var5_dec, disflooding_var15_dec) = 0.0379
# MMD(localrepair_var5_dec, disflooding_var15_oo) = 0.0382
# MMD(localrepair_var5_dec, disflooding_var20_base) = 0.0374
# MMD(localrepair_var5_dec, disflooding_var20_dec) = 0.0368
# MMD(localrepair_var5_dec, disflooding_var20_oo) = 0.0363
# MMD(localrepair_var5_dec, disflooding_var5_base) = 0.0435
# MMD(localrepair_var5_dec, disflooding_var5_dec) = 0.0360
# MMD(localrepair_var5_dec, disflooding_var5_oo) = 0.0335
# MMD(localrepair_var5_dec, localrepair_var10_base) = 0.0452
# MMD(localrepair_var5_dec, localrepair_var10_dec) = 0.0459
# MMD(localrepair_var5_dec, localrepair_var10_oo) = 0.0471
# MMD(localrepair_var5_dec, localrepair_var15_base) = 0.0415
# MMD(localrepair_var5_dec, localrepair_var15_dec) = 0.0431
# MMD(localrepair_var5_dec, localrepair_var15_oo) = 0.0443
# MMD(localrepair_var5_dec, localrepair_var20_base) = 0.0383
# MMD(localrepair_var5_dec, localrepair_var20_dec) = 0.0387
# MMD(localrepair_var5_dec, localrepair_var20_oo) = 0.0386
# MMD(localrepair_var5_dec, localrepair_var5_base) = 0.0539
# MMD(localrepair_var5_oo, blackhole_var10_base) = 0.0421
# MMD(localrepair_var5_oo, blackhole_var10_dec) = 0.0389
# MMD(localrepair_var5_oo, blackhole_var10_oo) = 0.0415
# MMD(localrepair_var5_oo, blackhole_var15_base) = 0.0408
# MMD(localrepair_var5_oo, blackhole_var15_dec) = 0.0393
# MMD(localrepair_var5_oo, blackhole_var15_oo) = 0.0413
# MMD(localrepair_var5_oo, blackhole_var20_base) = 0.0361
# MMD(localrepair_var5_oo, blackhole_var20_dec) = 0.0363
# MMD(localrepair_var5_oo, blackhole_var20_oo) = 0.0362
# MMD(localrepair_var5_oo, blackhole_var5_base) = 0.0279
# MMD(localrepair_var5_oo, blackhole_var5_dec) = 0.0287
# MMD(localrepair_var5_oo, blackhole_var5_oo) = 0.0290
# MMD(localrepair_var5_oo, disflooding_var10_base) = 0.0391
# MMD(localrepair_var5_oo, disflooding_var10_dec) = 0.0403
# MMD(localrepair_var5_oo, disflooding_var10_oo) = 0.0375
# MMD(localrepair_var5_oo, disflooding_var15_base) = 0.0385
# MMD(localrepair_var5_oo, disflooding_var15_dec) = 0.0359
# MMD(localrepair_var5_oo, disflooding_var15_oo) = 0.0363
# MMD(localrepair_var5_oo, disflooding_var20_base) = 0.0355
# MMD(localrepair_var5_oo, disflooding_var20_dec) = 0.0349
# MMD(localrepair_var5_oo, disflooding_var20_oo) = 0.0344
# MMD(localrepair_var5_oo, disflooding_var5_base) = 0.0409
# MMD(localrepair_var5_oo, disflooding_var5_dec) = 0.0322
# MMD(localrepair_var5_oo, disflooding_var5_oo) = 0.0296
# MMD(localrepair_var5_oo, localrepair_var10_base) = 0.0431
# MMD(localrepair_var5_oo, localrepair_var10_dec) = 0.0440
# MMD(localrepair_var5_oo, localrepair_var10_oo) = 0.0452
# MMD(localrepair_var5_oo, localrepair_var15_base) = 0.0395
# MMD(localrepair_var5_oo, localrepair_var15_dec) = 0.0412
# MMD(localrepair_var5_oo, localrepair_var15_oo) = 0.0424
# MMD(localrepair_var5_oo, localrepair_var20_base) = 0.0364
# MMD(localrepair_var5_oo, localrepair_var20_dec) = 0.0368
# MMD(localrepair_var5_oo, localrepair_var20_oo) = 0.0367
# MMD(localrepair_var5_oo, localrepair_var5_base) = 0.0191
# MMD(localrepair_var5_oo, localrepair_var5_dec) = 0.0285
# MMD(worstparent_var10_base, blackhole_var10_base) = 0.0083
# MMD(worstparent_var10_base, blackhole_var10_dec) = 0.0082
# MMD(worstparent_var10_base, blackhole_var10_oo) = 0.0087
# MMD(worstparent_var10_base, blackhole_var15_base) = 0.0138
# MMD(worstparent_var10_base, blackhole_var15_dec) = 0.0126
# MMD(worstparent_var10_base, blackhole_var15_oo) = 0.0143
# MMD(worstparent_var10_base, blackhole_var20_base) = 0.0097
# MMD(worstparent_var10_base, blackhole_var20_dec) = 0.0098
# MMD(worstparent_var10_base, blackhole_var20_oo) = 0.0098
# MMD(worstparent_var10_base, blackhole_var5_base) = 0.0583
# MMD(worstparent_var10_base, blackhole_var5_dec) = 0.0582
# MMD(worstparent_var10_base, blackhole_var5_oo) = 0.0638
# MMD(worstparent_var10_base, disflooding_var10_base) = 0.0117
# MMD(worstparent_var10_base, disflooding_var10_dec) = 0.0118
# MMD(worstparent_var10_base, disflooding_var10_oo) = 0.0092
# MMD(worstparent_var10_base, disflooding_var15_base) = 0.0120
# MMD(worstparent_var10_base, disflooding_var15_dec) = 0.0095
# MMD(worstparent_var10_base, disflooding_var15_oo) = 0.0098
# MMD(worstparent_var10_base, disflooding_var20_base) = 0.0090
# MMD(worstparent_var10_base, disflooding_var20_dec) = 0.0084
# MMD(worstparent_var10_base, disflooding_var20_oo) = 0.0080
# MMD(worstparent_var10_base, disflooding_var5_base) = 0.0212
# MMD(worstparent_var10_base, disflooding_var5_dec) = 0.0169
# MMD(worstparent_var10_base, disflooding_var5_oo) = 0.0135
# MMD(worstparent_var10_base, localrepair_var10_base) = 0.0136
# MMD(worstparent_var10_base, localrepair_var10_dec) = 0.0130
# MMD(worstparent_var10_base, localrepair_var10_oo) = 0.0132
# MMD(worstparent_var10_base, localrepair_var15_base) = 0.0130
# MMD(worstparent_var10_base, localrepair_var15_dec) = 0.0147
# MMD(worstparent_var10_base, localrepair_var15_oo) = 0.0158
# MMD(worstparent_var10_base, localrepair_var20_base) = 0.0100
# MMD(worstparent_var10_base, localrepair_var20_dec) = 0.0104
# MMD(worstparent_var10_base, localrepair_var20_oo) = 0.0103
# MMD(worstparent_var10_base, localrepair_var5_base) = 0.0463
# MMD(worstparent_var10_base, localrepair_var5_dec) = 0.0403
# MMD(worstparent_var10_base, localrepair_var5_oo) = 0.0384
# MMD(worstparent_var10_dec, blackhole_var10_base) = 0.0076
# MMD(worstparent_var10_dec, blackhole_var10_dec) = 0.0079
# MMD(worstparent_var10_dec, blackhole_var10_oo) = 0.0083
# MMD(worstparent_var10_dec, blackhole_var15_base) = 0.0138
# MMD(worstparent_var10_dec, blackhole_var15_dec) = 0.0126
# MMD(worstparent_var10_dec, blackhole_var15_oo) = 0.0144
# MMD(worstparent_var10_dec, blackhole_var20_base) = 0.0099
# MMD(worstparent_var10_dec, blackhole_var20_dec) = 0.0100
# MMD(worstparent_var10_dec, blackhole_var20_oo) = 0.0100
# MMD(worstparent_var10_dec, blackhole_var5_base) = 0.0588
# MMD(worstparent_var10_dec, blackhole_var5_dec) = 0.0587
# MMD(worstparent_var10_dec, blackhole_var5_oo) = 0.0643
# MMD(worstparent_var10_dec, disflooding_var10_base) = 0.0119
# MMD(worstparent_var10_dec, disflooding_var10_dec) = 0.0126
# MMD(worstparent_var10_dec, disflooding_var10_oo) = 0.0102
# MMD(worstparent_var10_dec, disflooding_var15_base) = 0.0122
# MMD(worstparent_var10_dec, disflooding_var15_dec) = 0.0096
# MMD(worstparent_var10_dec, disflooding_var15_oo) = 0.0099
# MMD(worstparent_var10_dec, disflooding_var20_base) = 0.0091
# MMD(worstparent_var10_dec, disflooding_var20_dec) = 0.0086
# MMD(worstparent_var10_dec, disflooding_var20_oo) = 0.0081
# MMD(worstparent_var10_dec, disflooding_var5_base) = 0.0214
# MMD(worstparent_var10_dec, disflooding_var5_dec) = 0.0171
# MMD(worstparent_var10_dec, disflooding_var5_oo) = 0.0138
# MMD(worstparent_var10_dec, localrepair_var10_base) = 0.0136
# MMD(worstparent_var10_dec, localrepair_var10_dec) = 0.0128
# MMD(worstparent_var10_dec, localrepair_var10_oo) = 0.0132
# MMD(worstparent_var10_dec, localrepair_var15_base) = 0.0132
# MMD(worstparent_var10_dec, localrepair_var15_dec) = 0.0148
# MMD(worstparent_var10_dec, localrepair_var15_oo) = 0.0160
# MMD(worstparent_var10_dec, localrepair_var20_base) = 0.0101
# MMD(worstparent_var10_dec, localrepair_var20_dec) = 0.0105
# MMD(worstparent_var10_dec, localrepair_var20_oo) = 0.0104
# MMD(worstparent_var10_dec, localrepair_var5_base) = 0.0465
# MMD(worstparent_var10_dec, localrepair_var5_dec) = 0.0406
# MMD(worstparent_var10_dec, localrepair_var5_oo) = 0.0387
# MMD(worstparent_var10_dec, worstparent_var10_base) = 0.0037
# MMD(worstparent_var10_oo, blackhole_var10_base) = 0.0070
# MMD(worstparent_var10_oo, blackhole_var10_dec) = 0.0077
# MMD(worstparent_var10_oo, blackhole_var10_oo) = 0.0080
# MMD(worstparent_var10_oo, blackhole_var15_base) = 0.0136
# MMD(worstparent_var10_oo, blackhole_var15_dec) = 0.0124
# MMD(worstparent_var10_oo, blackhole_var15_oo) = 0.0141
# MMD(worstparent_var10_oo, blackhole_var20_base) = 0.0096
# MMD(worstparent_var10_oo, blackhole_var20_dec) = 0.0097
# MMD(worstparent_var10_oo, blackhole_var20_oo) = 0.0097
# MMD(worstparent_var10_oo, blackhole_var5_base) = 0.0585
# MMD(worstparent_var10_oo, blackhole_var5_dec) = 0.0584
# MMD(worstparent_var10_oo, blackhole_var5_oo) = 0.0641
# MMD(worstparent_var10_oo, disflooding_var10_base) = 0.0118
# MMD(worstparent_var10_oo, disflooding_var10_dec) = 0.0124
# MMD(worstparent_var10_oo, disflooding_var10_oo) = 0.0102
# MMD(worstparent_var10_oo, disflooding_var15_base) = 0.0119
# MMD(worstparent_var10_oo, disflooding_var15_dec) = 0.0094
# MMD(worstparent_var10_oo, disflooding_var15_oo) = 0.0097
# MMD(worstparent_var10_oo, disflooding_var20_base) = 0.0089
# MMD(worstparent_var10_oo, disflooding_var20_dec) = 0.0084
# MMD(worstparent_var10_oo, disflooding_var20_oo) = 0.0079
# MMD(worstparent_var10_oo, disflooding_var5_base) = 0.0212
# MMD(worstparent_var10_oo, disflooding_var5_dec) = 0.0169
# MMD(worstparent_var10_oo, disflooding_var5_oo) = 0.0135
# MMD(worstparent_var10_oo, localrepair_var10_base) = 0.0130
# MMD(worstparent_var10_oo, localrepair_var10_dec) = 0.0121
# MMD(worstparent_var10_oo, localrepair_var10_oo) = 0.0123
# MMD(worstparent_var10_oo, localrepair_var15_base) = 0.0129
# MMD(worstparent_var10_oo, localrepair_var15_dec) = 0.0145
# MMD(worstparent_var10_oo, localrepair_var15_oo) = 0.0157
# MMD(worstparent_var10_oo, localrepair_var20_base) = 0.0099
# MMD(worstparent_var10_oo, localrepair_var20_dec) = 0.0103
# MMD(worstparent_var10_oo, localrepair_var20_oo) = 0.0102
# MMD(worstparent_var10_oo, localrepair_var5_base) = 0.0463
# MMD(worstparent_var10_oo, localrepair_var5_dec) = 0.0404
# MMD(worstparent_var10_oo, localrepair_var5_oo) = 0.0385
# MMD(worstparent_var10_oo, worstparent_var10_base) = 0.0035
# MMD(worstparent_var10_oo, worstparent_var10_dec) = 0.0024
# MMD(worstparent_var15_base, blackhole_var10_base) = 0.0117
# MMD(worstparent_var15_base, blackhole_var10_dec) = 0.0100
# MMD(worstparent_var15_base, blackhole_var10_oo) = 0.0110
# MMD(worstparent_var15_base, blackhole_var15_base) = 0.0091
# MMD(worstparent_var15_base, blackhole_var15_dec) = 0.0081
# MMD(worstparent_var15_base, blackhole_var15_oo) = 0.0095
# MMD(worstparent_var15_base, blackhole_var20_base) = 0.0056
# MMD(worstparent_var15_base, blackhole_var20_dec) = 0.0057
# MMD(worstparent_var15_base, blackhole_var20_oo) = 0.0057
# MMD(worstparent_var15_base, blackhole_var5_base) = 0.0547
# MMD(worstparent_var15_base, blackhole_var5_dec) = 0.0547
# MMD(worstparent_var15_base, blackhole_var5_oo) = 0.0603
# MMD(worstparent_var15_base, disflooding_var10_base) = 0.0087
# MMD(worstparent_var15_base, disflooding_var10_dec) = 0.0100
# MMD(worstparent_var15_base, disflooding_var10_oo) = 0.0072
# MMD(worstparent_var15_base, disflooding_var15_base) = 0.0079
# MMD(worstparent_var15_base, disflooding_var15_dec) = 0.0055
# MMD(worstparent_var15_base, disflooding_var15_oo) = 0.0057
# MMD(worstparent_var15_base, disflooding_var20_base) = 0.0051
# MMD(worstparent_var15_base, disflooding_var20_dec) = 0.0044
# MMD(worstparent_var15_base, disflooding_var20_oo) = 0.0039
# MMD(worstparent_var15_base, disflooding_var5_base) = 0.0173
# MMD(worstparent_var15_base, disflooding_var5_dec) = 0.0130
# MMD(worstparent_var15_base, disflooding_var5_oo) = 0.0097
# MMD(worstparent_var15_base, localrepair_var10_base) = 0.0129
# MMD(worstparent_var15_base, localrepair_var10_dec) = 0.0135
# MMD(worstparent_var15_base, localrepair_var10_oo) = 0.0146
# MMD(worstparent_var15_base, localrepair_var15_base) = 0.0088
# MMD(worstparent_var15_base, localrepair_var15_dec) = 0.0103
# MMD(worstparent_var15_base, localrepair_var15_oo) = 0.0114
# MMD(worstparent_var15_base, localrepair_var20_base) = 0.0060
# MMD(worstparent_var15_base, localrepair_var20_dec) = 0.0063
# MMD(worstparent_var15_base, localrepair_var20_oo) = 0.0062
# MMD(worstparent_var15_base, localrepair_var5_base) = 0.0424
# MMD(worstparent_var15_base, localrepair_var5_dec) = 0.0365
# MMD(worstparent_var15_base, localrepair_var5_oo) = 0.0346
# MMD(worstparent_var15_base, worstparent_var10_base) = 0.0080
# MMD(worstparent_var15_base, worstparent_var10_dec) = 0.0082
# MMD(worstparent_var15_base, worstparent_var10_oo) = 0.0079
# MMD(worstparent_var15_dec, blackhole_var10_base) = 0.0129
# MMD(worstparent_var15_dec, blackhole_var10_dec) = 0.0112
# MMD(worstparent_var15_dec, blackhole_var10_oo) = 0.0122
# MMD(worstparent_var15_dec, blackhole_var15_base) = 0.0096
# MMD(worstparent_var15_dec, blackhole_var15_dec) = 0.0088
# MMD(worstparent_var15_dec, blackhole_var15_oo) = 0.0101
# MMD(worstparent_var15_dec, blackhole_var20_base) = 0.0068
# MMD(worstparent_var15_dec, blackhole_var20_dec) = 0.0068
# MMD(worstparent_var15_dec, blackhole_var20_oo) = 0.0068
# MMD(worstparent_var15_dec, blackhole_var5_base) = 0.0559
# MMD(worstparent_var15_dec, blackhole_var5_dec) = 0.0558
# MMD(worstparent_var15_dec, blackhole_var5_oo) = 0.0615
# MMD(worstparent_var15_dec, disflooding_var10_base) = 0.0098
# MMD(worstparent_var15_dec, disflooding_var10_dec) = 0.0110
# MMD(worstparent_var15_dec, disflooding_var10_oo) = 0.0081
# MMD(worstparent_var15_dec, disflooding_var15_base) = 0.0093
# MMD(worstparent_var15_dec, disflooding_var15_dec) = 0.0067
# MMD(worstparent_var15_dec, disflooding_var15_oo) = 0.0067
# MMD(worstparent_var15_dec, disflooding_var20_base) = 0.0062
# MMD(worstparent_var15_dec, disflooding_var20_dec) = 0.0056
# MMD(worstparent_var15_dec, disflooding_var20_oo) = 0.0050
# MMD(worstparent_var15_dec, disflooding_var5_base) = 0.0184
# MMD(worstparent_var15_dec, disflooding_var5_dec) = 0.0142
# MMD(worstparent_var15_dec, disflooding_var5_oo) = 0.0108
# MMD(worstparent_var15_dec, localrepair_var10_base) = 0.0140
# MMD(worstparent_var15_dec, localrepair_var10_dec) = 0.0146
# MMD(worstparent_var15_dec, localrepair_var10_oo) = 0.0157
# MMD(worstparent_var15_dec, localrepair_var15_base) = 0.0101
# MMD(worstparent_var15_dec, localrepair_var15_dec) = 0.0116
# MMD(worstparent_var15_dec, localrepair_var15_oo) = 0.0128
# MMD(worstparent_var15_dec, localrepair_var20_base) = 0.0072
# MMD(worstparent_var15_dec, localrepair_var20_dec) = 0.0075
# MMD(worstparent_var15_dec, localrepair_var20_oo) = 0.0074
# MMD(worstparent_var15_dec, localrepair_var5_base) = 0.0436
# ...
# MMD(worstparent_var15_oo, localrepair_var5_base) = 0.0426
# MMD(worstparent_var15_oo, localrepair_var5_dec) = 0.0367
# MMD(worstparent_var15_oo, localrepair_var5_oo) = 0.0347
# MMD(worstparent_var15_oo, worstparent_var10_base) = 0.0081
# MMD(worstparent_var15_oo, worstparent_var10_dec) = 0.0082
# MMD(worstparent_var15_oo, worstparent_var10_oo) = 0.0078
# MMD(worstparent_var15_oo, worstparent_var15_base) = 0.0012
# MMD(worstparent_var15_oo, worstparent_var15_dec) = 0.0016
# MMD(worstparent_var20_base, blackhole_var10_base) = 0.0105
# MMD(worstparent_var20_base, blackhole_var10_dec) = 0.0089
# MMD(worstparent_var20_base, blackhole_var10_oo) = 0.0098
# MMD(worstparent_var20_base, blackhole_var15_base) = 0.0089
# MMD(worstparent_var20_base, blackhole_var15_dec) = 0.0077
# MMD(worstparent_var20_base, blackhole_var15_oo) = 0.0094
# MMD(worstparent_var20_base, blackhole_var20_base) = 0.0042
# MMD(worstparent_var20_base, blackhole_var20_dec) = 0.0043
# MMD(worstparent_var20_base, blackhole_var20_oo) = 0.0042
# MMD(worstparent_var20_base, blackhole_var5_base) = 0.0534
# MMD(worstparent_var20_base, blackhole_var5_dec) = 0.0533
# MMD(worstparent_var20_base, blackhole_var5_oo) = 0.0589
# MMD(worstparent_var20_base, disflooding_var10_base) = 0.0073
# MMD(worstparent_var20_base, disflooding_var10_dec) = 0.0086
# MMD(worstparent_var20_base, disflooding_var10_oo) = 0.0058
# MMD(worstparent_var20_base, disflooding_var15_base) = 0.0067
# MMD(worstparent_var20_base, disflooding_var15_dec) = 0.0042
# MMD(worstparent_var20_base, disflooding_var15_oo) = 0.0045
# MMD(worstparent_var20_base, disflooding_var20_base) = 0.0037
# MMD(worstparent_var20_base, disflooding_var20_dec) = 0.0031
# MMD(worstparent_var20_base, disflooding_var20_oo) = 0.0026
# MMD(worstparent_var20_base, disflooding_var5_base) = 0.0159
# MMD(worstparent_var20_base, disflooding_var5_dec) = 0.0116
# MMD(worstparent_var20_base, disflooding_var5_oo) = 0.0083
# MMD(worstparent_var20_base, localrepair_var10_base) = 0.0116
# MMD(worstparent_var20_base, localrepair_var10_dec) = 0.0123
# MMD(worstparent_var20_base, localrepair_var10_oo) = 0.0135
# MMD(worstparent_var20_base, localrepair_var15_base) = 0.0077
# MMD(worstparent_var20_base, localrepair_var15_dec) = 0.0093
# MMD(worstparent_var20_base, localrepair_var15_oo) = 0.0105
# MMD(worstparent_var20_base, localrepair_var20_base) = 0.0046
# MMD(worstparent_var20_base, localrepair_var20_dec) = 0.0049
# MMD(worstparent_var20_base, localrepair_var20_oo) = 0.0048
# MMD(worstparent_var20_base, localrepair_var5_base) = 0.0411
# MMD(worstparent_var20_base, localrepair_var5_dec) = 0.0352
# MMD(worstparent_var20_base, localrepair_var5_oo) = 0.0332
# MMD(worstparent_var20_base, worstparent_var10_base) = 0.0068
# MMD(worstparent_var20_base, worstparent_var10_dec) = 0.0069
# MMD(worstparent_var20_base, worstparent_var10_oo) = 0.0067
# MMD(worstparent_var20_base, worstparent_var15_base) = 0.0026
# MMD(worstparent_var20_base, worstparent_var15_dec) = 0.0038
# MMD(worstparent_var20_base, worstparent_var15_oo) = 0.0027
# MMD(worstparent_var20_dec, blackhole_var10_base) = 0.0115
# MMD(worstparent_var20_dec, blackhole_var10_dec) = 0.0098
# MMD(worstparent_var20_dec, blackhole_var10_oo) = 0.0109
# MMD(worstparent_var20_dec, blackhole_var15_base) = 0.0103
# MMD(worstparent_var20_dec, blackhole_var15_dec) = 0.0091
# MMD(worstparent_var20_dec, blackhole_var15_oo) = 0.0108
# MMD(worstparent_var20_dec, blackhole_var20_base) = 0.0055
# MMD(worstparent_var20_dec, blackhole_var20_dec) = 0.0055
# MMD(worstparent_var20_dec, blackhole_var20_oo) = 0.0055
# MMD(worstparent_var20_dec, blackhole_var5_base) = 0.0547
# MMD(worstparent_var20_dec, blackhole_var5_dec) = 0.0546
# MMD(worstparent_var20_dec, blackhole_var5_oo) = 0.0603
# MMD(worstparent_var20_dec, disflooding_var10_base) = 0.0086
# MMD(worstparent_var20_dec, disflooding_var10_dec) = 0.0099
# MMD(worstparent_var20_dec, disflooding_var10_oo) = 0.0071
# MMD(worstparent_var20_dec, disflooding_var15_base) = 0.0081
# MMD(worstparent_var20_dec, disflooding_var15_dec) = 0.0054
# MMD(worstparent_var20_dec, disflooding_var15_oo) = 0.0057
# MMD(worstparent_var20_dec, disflooding_var20_base) = 0.0050
# MMD(worstparent_var20_dec, disflooding_var20_dec) = 0.0044
# MMD(worstparent_var20_dec, disflooding_var20_oo) = 0.0039
# MMD(worstparent_var20_dec, disflooding_var5_base) = 0.0172
# MMD(worstparent_var20_dec, disflooding_var5_dec) = 0.0130
# MMD(worstparent_var20_dec, disflooding_var5_oo) = 0.0096
# MMD(worstparent_var20_dec, localrepair_var10_base) = 0.0126
# MMD(worstparent_var20_dec, localrepair_var10_dec) = 0.0132
# MMD(worstparent_var20_dec, localrepair_var10_oo) = 0.0142
# MMD(worstparent_var20_dec, localrepair_var15_base) = 0.0089
# MMD(worstparent_var20_dec, localrepair_var15_dec) = 0.0105
# MMD(worstparent_var20_dec, localrepair_var15_oo) = 0.0116
# MMD(worstparent_var20_dec, localrepair_var20_base) = 0.0059
# MMD(worstparent_var20_dec, localrepair_var20_dec) = 0.0062
# MMD(worstparent_var20_dec, localrepair_var20_oo) = 0.0061
# MMD(worstparent_var20_dec, localrepair_var5_base) = 0.0424
# MMD(worstparent_var20_dec, localrepair_var5_dec) = 0.0365
# MMD(worstparent_var20_dec, localrepair_var5_oo) = 0.0346
# MMD(worstparent_var20_dec, worstparent_var10_base) = 0.0077
# MMD(worstparent_var20_dec, worstparent_var10_dec) = 0.0078
# MMD(worstparent_var20_dec, worstparent_var10_oo) = 0.0076
# MMD(worstparent_var20_dec, worstparent_var15_base) = 0.0039
# MMD(worstparent_var20_dec, worstparent_var15_dec) = 0.0052
# MMD(worstparent_var20_dec, worstparent_var15_oo) = 0.0041
# MMD(worstparent_var20_dec, worstparent_var20_base) = 0.0013
# MMD(worstparent_var20_oo, blackhole_var10_base) = 0.0107
# MMD(worstparent_var20_oo, blackhole_var10_dec) = 0.0091
# MMD(worstparent_var20_oo, blackhole_var10_oo) = 0.0100
# MMD(worstparent_var20_oo, blackhole_var15_base) = 0.0089
# MMD(worstparent_var20_oo, blackhole_var15_dec) = 0.0078
# MMD(worstparent_var20_oo, blackhole_var15_oo) = 0.0094
# MMD(worstparent_var20_oo, blackhole_var20_base) = 0.0044
# MMD(worstparent_var20_oo, blackhole_var20_dec) = 0.0044
# MMD(worstparent_var20_oo, blackhole_var20_oo) = 0.0044
# MMD(worstparent_var20_oo, blackhole_var5_base) = 0.0536
# MMD(worstparent_var20_oo, blackhole_var5_dec) = 0.0535
# MMD(worstparent_var20_oo, blackhole_var5_oo) = 0.0592
# MMD(worstparent_var20_oo, disflooding_var10_base) = 0.0075
# MMD(worstparent_var20_oo, disflooding_var10_dec) = 0.0089
# MMD(worstparent_var20_oo, disflooding_var10_oo) = 0.0060
# MMD(worstparent_var20_oo, disflooding_var15_base) = 0.0070
# MMD(worstparent_var20_oo, disflooding_var15_dec) = 0.0044
# MMD(worstparent_var20_oo, disflooding_var15_oo) = 0.0047
# MMD(worstparent_var20_oo, disflooding_var20_base) = 0.0039
# MMD(worstparent_var20_oo, disflooding_var20_dec) = 0.0033
# MMD(worstparent_var20_oo, disflooding_var20_oo) = 0.0029
# MMD(worstparent_var20_oo, disflooding_var5_base) = 0.0161
# MMD(worstparent_var20_oo, disflooding_var5_dec) = 0.0119
# MMD(worstparent_var20_oo, disflooding_var5_oo) = 0.0085
# MMD(worstparent_var20_oo, localrepair_var10_base) = 0.0119
# MMD(worstparent_var20_oo, localrepair_var10_dec) = 0.0125
# MMD(worstparent_var20_oo, localrepair_var10_oo) = 0.0137
# MMD(worstparent_var20_oo, localrepair_var15_base) = 0.0079
# MMD(worstparent_var20_oo, localrepair_var15_dec) = 0.0095
# MMD(worstparent_var20_oo, localrepair_var15_oo) = 0.0107
# MMD(worstparent_var20_oo, localrepair_var20_base) = 0.0047
# MMD(worstparent_var20_oo, localrepair_var20_dec) = 0.0051
# MMD(worstparent_var20_oo, localrepair_var20_oo) = 0.0050
# MMD(worstparent_var20_oo, localrepair_var5_base) = 0.0413
# MMD(worstparent_var20_oo, localrepair_var5_dec) = 0.0354
# MMD(worstparent_var20_oo, localrepair_var5_oo) = 0.0335
# MMD(worstparent_var20_oo, worstparent_var10_base) = 0.0070
# MMD(worstparent_var20_oo, worstparent_var10_dec) = 0.0072
# MMD(worstparent_var20_oo, worstparent_var10_oo) = 0.0069
# MMD(worstparent_var20_oo, worstparent_var15_base) = 0.0028
# MMD(worstparent_var20_oo, worstparent_var15_dec) = 0.0040
# MMD(worstparent_var20_oo, worstparent_var15_oo) = 0.0029
# MMD(worstparent_var20_oo, worstparent_var20_base) = 0.0006
# MMD(worstparent_var20_oo, worstparent_var20_dec) = 0.0013
# MMD(worstparent_var5_base, blackhole_var10_base) = 0.0427
# MMD(worstparent_var5_base, blackhole_var10_dec) = 0.0398
# MMD(worstparent_var5_base, blackhole_var10_oo) = 0.0421
# MMD(worstparent_var5_base, blackhole_var15_base) = 0.0403
# MMD(worstparent_var5_base, blackhole_var15_dec) = 0.0380
# MMD(worstparent_var5_base, blackhole_var15_oo) = 0.0418
# MMD(worstparent_var5_base, blackhole_var20_base) = 0.0355
# MMD(worstparent_var5_base, blackhole_var20_dec) = 0.0368
# MMD(worstparent_var5_base, blackhole_var20_oo) = 0.0369
# MMD(worstparent_var5_base, blackhole_var5_base) = 0.0242
# MMD(worstparent_var5_base, blackhole_var5_dec) = 0.0242
# MMD(worstparent_var5_base, blackhole_var5_oo) = 0.0267
# MMD(worstparent_var5_base, disflooding_var10_base) = 0.0397
# MMD(worstparent_var5_base, disflooding_var10_dec) = 0.0408
# MMD(worstparent_var5_base, disflooding_var10_oo) = 0.0382
# MMD(worstparent_var5_base, disflooding_var15_base) = 0.0373
# MMD(worstparent_var5_base, disflooding_var15_dec) = 0.0366
# MMD(worstparent_var5_base, disflooding_var15_oo) = 0.0369
# MMD(worstparent_var5_base, disflooding_var20_base) = 0.0361
# MMD(worstparent_var5_base, disflooding_var20_dec) = 0.0356
# MMD(worstparent_var5_base, disflooding_var20_oo) = 0.0350
# MMD(worstparent_var5_base, disflooding_var5_base) = 0.0378
# MMD(worstparent_var5_base, disflooding_var5_dec) = 0.0301
# MMD(worstparent_var5_base, disflooding_var5_oo) = 0.0260
# MMD(worstparent_var5_base, localrepair_var10_base) = 0.0439
# MMD(worstparent_var5_base, localrepair_var10_dec) = 0.0444
# MMD(worstparent_var5_base, localrepair_var10_oo) = 0.0455
# MMD(worstparent_var5_base, localrepair_var15_base) = 0.0402
# MMD(worstparent_var5_base, localrepair_var15_dec) = 0.0419
# MMD(worstparent_var5_base, localrepair_var15_oo) = 0.0430
# MMD(worstparent_var5_base, localrepair_var20_base) = 0.0371
# MMD(worstparent_var5_base, localrepair_var20_dec) = 0.0375
# MMD(worstparent_var5_base, localrepair_var20_oo) = 0.0374
# MMD(worstparent_var5_base, localrepair_var5_base) = 0.0534
# MMD(worstparent_var5_base, localrepair_var5_dec) = 0.0372
# MMD(worstparent_var5_base, localrepair_var5_oo) = 0.0281
# MMD(worstparent_var5_base, worstparent_var10_base) = 0.0390
# MMD(worstparent_var5_base, worstparent_var10_dec) = 0.0393
# MMD(worstparent_var5_base, worstparent_var10_oo) = 0.0392
# MMD(worstparent_var5_base, worstparent_var15_base) = 0.0353
# MMD(worstparent_var5_base, worstparent_var15_dec) = 0.0364
# MMD(worstparent_var5_base, worstparent_var15_oo) = 0.0354
# MMD(worstparent_var5_base, worstparent_var20_base) = 0.0339
# MMD(worstparent_var5_base, worstparent_var20_dec) = 0.0352
# MMD(worstparent_var5_base, worstparent_var20_oo) = 0.0342
# MMD(worstparent_var5_dec, blackhole_var10_base) = 0.0425
# MMD(worstparent_var5_dec, blackhole_var10_dec) = 0.0394
# MMD(worstparent_var5_dec, blackhole_var10_oo) = 0.0419
# MMD(worstparent_var5_dec, blackhole_var15_base) = 0.0402
# MMD(worstparent_var5_dec, blackhole_var15_dec) = 0.0383
# MMD(worstparent_var5_dec, blackhole_var15_oo) = 0.0416
# MMD(worstparent_var5_dec, blackhole_var20_base) = 0.0355
# MMD(worstparent_var5_dec, blackhole_var20_dec) = 0.0368
# MMD(worstparent_var5_dec, blackhole_var20_oo) = 0.0367
# MMD(worstparent_var5_dec, blackhole_var5_base) = 0.0220
# MMD(worstparent_var5_dec, blackhole_var5_dec) = 0.0230
# MMD(worstparent_var5_dec, blackhole_var5_oo) = 0.0244
# MMD(worstparent_var5_dec, disflooding_var10_base) = 0.0395
# MMD(worstparent_var5_dec, disflooding_var10_dec) = 0.0407
# MMD(worstparent_var5_dec, disflooding_var10_oo) = 0.0380
# MMD(worstparent_var5_dec, disflooding_var15_base) = 0.0374
# MMD(worstparent_var5_dec, disflooding_var15_dec) = 0.0364
# MMD(worstparent_var5_dec, disflooding_var15_oo) = 0.0367
# MMD(worstparent_var5_dec, disflooding_var20_base) = 0.0359
# MMD(worstparent_var5_dec, disflooding_var20_dec) = 0.0354
# MMD(worstparent_var5_dec, disflooding_var20_oo) = 0.0344
# MMD(worstparent_var5_dec, disflooding_var5_base) = 0.0376
# MMD(worstparent_var5_dec, disflooding_var5_dec) = 0.0297
# MMD(worstparent_var5_dec, disflooding_var5_oo) = 0.0256
# MMD(worstparent_var5_dec, localrepair_var10_base) = 0.0438
# MMD(worstparent_var5_dec, localrepair_var10_dec) = 0.0443
# MMD(worstparent_var5_dec, localrepair_var10_oo) = 0.0455
# MMD(worstparent_var5_dec, localrepair_var15_base) = 0.0400
# MMD(worstparent_var5_dec, localrepair_var15_dec) = 0.0417
# MMD(worstparent_var5_dec, localrepair_var15_oo) = 0.0428
# MMD(worstparent_var5_dec, localrepair_var20_base) = 0.0369
# MMD(worstparent_var5_dec, localrepair_var20_dec) = 0.0373
# MMD(worstparent_var5_dec, localrepair_var20_oo) = 0.0372
# MMD(worstparent_var5_dec, localrepair_var5_base) = 0.0518
# MMD(worstparent_var5_dec, localrepair_var5_dec) = 0.0344
# MMD(worstparent_var5_dec, localrepair_var5_oo) = 0.0255
# MMD(worstparent_var5_dec, worstparent_var10_base) = 0.0388
# MMD(worstparent_var5_dec, worstparent_var10_dec) = 0.0391
# MMD(worstparent_var5_dec, worstparent_var10_oo) = 0.0390
# MMD(worstparent_var5_dec, worstparent_var15_base) = 0.0351
# MMD(worstparent_var5_dec, worstparent_var15_dec) = 0.0363
# MMD(worstparent_var5_dec, worstparent_var15_oo) = 0.0352
# MMD(worstparent_var5_dec, worstparent_var20_base) = 0.0337
# MMD(worstparent_var5_dec, worstparent_var20_dec) = 0.0350
# MMD(worstparent_var5_dec, worstparent_var20_oo) = 0.0340
# MMD(worstparent_var5_dec, worstparent_var5_base) = 0.0044
# MMD(worstparent_var5_oo, blackhole_var10_base) = 0.0372
# MMD(worstparent_var5_oo, blackhole_var10_dec) = 0.0342
# MMD(worstparent_var5_oo, blackhole_var10_oo) = 0.0365
# MMD(worstparent_var5_oo, blackhole_var15_base) = 0.0358
# MMD(worstparent_var5_oo, blackhole_var15_dec) = 0.0331
# MMD(worstparent_var5_oo, blackhole_var15_oo) = 0.0362
# MMD(worstparent_var5_oo, blackhole_var20_base) = 0.0311
# MMD(worstparent_var5_oo, blackhole_var20_dec) = 0.0313
# MMD(worstparent_var5_oo, blackhole_var20_oo) = 0.0313
# MMD(worstparent_var5_oo, blackhole_var5_base) = 0.0252
# MMD(worstparent_var5_oo, blackhole_var5_dec) = 0.0244
# MMD(worstparent_var5_oo, blackhole_var5_oo) = 0.0263
# MMD(worstparent_var5_oo, disflooding_var10_base) = 0.0341
# MMD(worstparent_var5_oo, disflooding_var10_dec) = 0.0352
# MMD(worstparent_var5_oo, disflooding_var10_oo) = 0.0325
# MMD(worstparent_var5_oo, disflooding_var15_base) = 0.0322
# MMD(worstparent_var5_oo, disflooding_var15_dec) = 0.0309
# MMD(worstparent_var5_oo, disflooding_var15_oo) = 0.0313
# MMD(worstparent_var5_oo, disflooding_var20_base) = 0.0305
# MMD(worstparent_var5_oo, disflooding_var20_dec) = 0.0299
# MMD(worstparent_var5_oo, disflooding_var20_oo) = 0.0291
# MMD(worstparent_var5_oo, disflooding_var5_base) = 0.0335
# MMD(worstparent_var5_oo, disflooding_var5_dec) = 0.0243
# MMD(worstparent_var5_oo, disflooding_var5_oo) = 0.0234
# MMD(worstparent_var5_oo, localrepair_var10_base) = 0.0383
# MMD(worstparent_var5_oo, localrepair_var10_dec) = 0.0387
# MMD(worstparent_var5_oo, localrepair_var10_oo) = 0.0399
# MMD(worstparent_var5_oo, localrepair_var15_base) = 0.0346
# MMD(worstparent_var5_oo, localrepair_var15_dec) = 0.0362
# MMD(worstparent_var5_oo, localrepair_var15_oo) = 0.0374
# MMD(worstparent_var5_oo, localrepair_var20_base) = 0.0314
# MMD(worstparent_var5_oo, localrepair_var20_dec) = 0.0318
# MMD(worstparent_var5_oo, localrepair_var20_oo) = 0.0317
# MMD(worstparent_var5_oo, localrepair_var5_base) = 0.0483
# MMD(worstparent_var5_oo, localrepair_var5_dec) = 0.0324
# MMD(worstparent_var5_oo, localrepair_var5_oo) = 0.0239
# MMD(worstparent_var5_oo, worstparent_var10_base) = 0.0332
# MMD(worstparent_var5_oo, worstparent_var10_dec) = 0.0337
# MMD(worstparent_var5_oo, worstparent_var10_oo) = 0.0335
# MMD(worstparent_var5_oo, worstparent_var15_base) = 0.0296
# MMD(worstparent_var5_oo, worstparent_var15_dec) = 0.0308
# MMD(worstparent_var5_oo, worstparent_var15_oo) = 0.0298
# MMD(worstparent_var5_oo, worstparent_var20_base) = 0.0283
# MMD(worstparent_var5_oo, worstparent_var20_dec) = 0.0296
# MMD(worstparent_var5_oo, worstparent_var20_oo) = 0.0285
# MMD(worstparent_var5_oo, worstparent_var5_base) = 0.0117
# MMD(worstparent_var5_oo, worstparent_var5_dec) = 0.0110
# All results saved to /Users/souba636/Documents/vinnova_project_python/data/cross_val_scenario/mmd_results_train.csv

# %%
import os
import re
from pathlib import Path

folder = Path("/Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/")

for root, dirs, files in os.walk(folder):
    for fname in files:
        # only target files ending with the pattern
        if fname.endswith("_features_timeseries_60_sec.csv"):
            m = re.search(r"(\d+_features_timeseries_60_sec\.csv)$", fname)
            if m:
                new_name = m.group(1)  # keep only from the number onwards
                old_path = os.path.join(root, fname)
                new_path = os.path.join(root, new_name)
                
                # rename only if different
                if old_path != new_path:
                    os.rename(old_path, new_path)
                    print(f"Renamed in {root}: {fname} -> {new_name}")
# Out:
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var20_dec: localrepair_var20_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var10_dec: worstparent_var10_dec_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_base: disflooding_var5_base_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var5_dec: disflooding_var5_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var5_dec: worstparent_var5_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var15_dec: worstparent_var15_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var20_dec: blackhole_var20_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_base: worstparent_var20_base_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_base: localrepair_var15_base_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_base: localrepair_var5_base_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/disflooding_var20_dec: disflooding_var20_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_base: blackhole_var15_base_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var5_dec: localrepair_var5_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# ...
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_dec: worstparent_var20_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_dec: worstparent_var20_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_dec: worstparent_var20_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_dec: worstparent_var20_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_dec: worstparent_var20_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_dec: worstparent_var20_dec_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/worstparent_var20_dec: worstparent_var20_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_dec: blackhole_var15_dec_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/localrepair_var15_oo: localrepair_var15_oo_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var10_base: blackhole_var10_base_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_9_features_timeseries_60_sec.csv -> 9_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_3_features_timeseries_60_sec.csv -> 3_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_20_features_timeseries_60_sec.csv -> 20_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_5_features_timeseries_60_sec.csv -> 5_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_17_features_timeseries_60_sec.csv -> 17_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_11_features_timeseries_60_sec.csv -> 11_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_8_features_timeseries_60_sec.csv -> 8_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_4_features_timeseries_60_sec.csv -> 4_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_2_features_timeseries_60_sec.csv -> 2_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_10_features_timeseries_60_sec.csv -> 10_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_16_features_timeseries_60_sec.csv -> 16_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_1_features_timeseries_60_sec.csv -> 1_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_7_features_timeseries_60_sec.csv -> 7_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_15_features_timeseries_60_sec.csv -> 15_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_13_features_timeseries_60_sec.csv -> 13_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_19_features_timeseries_60_sec.csv -> 19_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_6_features_timeseries_60_sec.csv -> 6_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_12_features_timeseries_60_sec.csv -> 12_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_14_features_timeseries_60_sec.csv -> 14_features_timeseries_60_sec.csv
# Renamed in /Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var15_oo: blackhole_var15_oo_18_features_timeseries_60_sec.csv -> 18_features_timeseries_60_sec.csv

# %%
import os, glob, re, random
import numpy as np
import pandas as pd
import torch
from torch.utils.data import TensorDataset, DataLoader
from pathlib import Path

# -----------------------
# Config
# -----------------------
BASE = Path("/Users/souba636/Documents/IoT_attack_CL_IDS/data/attack_data/blackhole_var5_base")  # folder that directly contains the 20 CSVs
DROP_COLS = ["Unnamed: 0"]
SEQUENCE_LENGTH = 10
BATCH_SIZE = 128
RANDOM_STATE = 42
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# -----------------------
# File discovery (supports both spellings)
# -----------------------

pat1 = os.path.join(BASE, "*_features_timeseries_60_sec.csv")   # common variant
files = glob.glob(pat1) + glob.glob(pat1)
assert len(files) >= 20, f"Expected at least 20 files, found {len(files)} in {BASE}"

def extract_index(path):
    # pull the number between ..._ and _60_sec.csv
    m = re.search(r"_(\d+)_60_sec\.csv$", os.path.basename(path))
    return int(m.group(1)) if m else 10**9  # push unknowns to end

files = sorted(files, key=extract_index)[:20]  # ensure exactly 20, ordered

random.seed(RANDOM_STATE)
random.shuffle(files)
train_files = files[:16]
test_files  = files[16:20]

print("Train files:", [os.path.basename(f) for f in train_files])
print("Test  files:", [os.path.basename(f) for f in test_files])

# -----------------------
# Utilities
# -----------------------
def load_csv(path):
    df = pd.read_csv(path)
    for c in DROP_COLS:
        if c in df.columns:
            df = df.drop(columns=[c])
    assert "label" in df.columns, f"'label' column missing in {os.path.basename(path)}"
    return df

def seq_maker(df, sequence_length=10, label_col="label"):
    df_feat = df.drop(columns=[label_col])
    labels = df[label_col].astype(int).values

    attack_idxs = np.where(labels == 1)[0]
    if len(attack_idxs) == 0:
        start_attack = len(labels) + sequence_length   # all zeros
    else:
        start_attack = max(0, attack_idxs[0] - sequence_length)

    sequences = []
    for i in range(len(df_feat) - sequence_length):
        sequences.append(df_feat.iloc[i:i+sequence_length].values.flatten())

    if not sequences:
        return pd.DataFrame(columns=[*range(df_feat.shape[1]*sequence_length), "label"])

    seq_df = pd.DataFrame(sequences)
    zeros = [0] * min(start_attack, len(seq_df))
    ones  = [1] * (len(seq_df) - len(zeros))
    seq_df["label"] = zeros + ones
    return seq_df

def safe_minmax_normalize(df, global_min, global_max, label_col="label"):
    feat_cols = [c for c in df.columns if c != label_col]
    denom = (global_max - global_min).replace(0, 1)  # avoid div/0
    out = df.copy()
    out[feat_cols] = (out[feat_cols] - global_min) / denom
    out[feat_cols] = out[feat_cols].replace([np.inf, -np.inf], np.nan).fillna(0.0)
    return out

# -----------------------
# Load all, compute train-only global min/max (excluding 'label')
# -----------------------
train_dfs = [load_csv(p) for p in train_files]
test_dfs  = [load_csv(p) for p in test_files]

feat_cols = [c for c in train_dfs[0].columns if c != "label"]
train_feat_mins = [df[feat_cols].min(axis=0) for df in train_dfs]
train_feat_maxs = [df[feat_cols].max(axis=0) for df in train_dfs]
global_min = pd.concat(train_feat_mins, axis=1).min(axis=1)
global_max = pd.concat(train_feat_maxs, axis=1).max(axis=1)

# -----------------------
# Normalize using train stats
# -----------------------
norm_train = [safe_minmax_normalize(df, global_min, global_max, "label") for df in train_dfs]
norm_test  = [safe_minmax_normalize(df, global_min, global_max, "label") for df in test_dfs]

# -----------------------
# Sequence-ify and concat
# -----------------------
seq_train_parts = [seq_maker(df, SEQUENCE_LENGTH, "label") for df in norm_train]
seq_test_parts  = [seq_maker(df, SEQUENCE_LENGTH, "label") for df in norm_test]

seq_train_parts = [df for df in seq_train_parts if not df.empty]
seq_test_parts  = [df for df in seq_test_parts if not df.empty]

seq_train = pd.concat(seq_train_parts, ignore_index=True)
seq_test  = pd.concat(seq_test_parts,  ignore_index=True)

# -----------------------
# Tensors & Dataloaders
# -----------------------
X_train = torch.tensor(seq_train.iloc[:, :-1].values, dtype=torch.float32)
y_train = torch.tensor(seq_train.iloc[:,  -1].values.astype(int), dtype=torch.long)
X_test  = torch.tensor(seq_test.iloc[:,  :-1].values, dtype=torch.float32)
y_test  = torch.tensor(seq_test.iloc[:,   -1].values.astype(int), dtype=torch.long)

X_train = torch.nan_to_num(X_train, nan=0.0)
X_test  = torch.nan_to_num(X_test,  nan=0.0)

feature_dim = X_train.shape[1]  # (#features * SEQUENCE_LENGTH)
X_train = X_train.view(-1, 1, feature_dim)
X_test  = X_test.view(-1, 1, feature_dim)

train_dataset = TensorDataset(X_train, y_train)
test_dataset  = TensorDataset(X_test,  y_test)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False)

print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_test :", X_test.shape,  "y_test :", y_test.shape)
# Out:
# Train files: ['20_features_timeseries_60_sec.csv', '2_features_timeseries_60_sec.csv', '10_features_timeseries_60_sec.csv', '4_features_timeseries_60_sec.csv', '3_features_timeseries_60_sec.csv', '16_features_timeseries_60_sec.csv', '1_features_timeseries_60_sec.csv', '17_features_timeseries_60_sec.csv', '13_features_timeseries_60_sec.csv', '6_features_timeseries_60_sec.csv', '11_features_timeseries_60_sec.csv', '5_features_timeseries_60_sec.csv', '8_features_timeseries_60_sec.csv', '19_features_timeseries_60_sec.csv', '12_features_timeseries_60_sec.csv', '7_features_timeseries_60_sec.csv']
# Test  files: ['9_features_timeseries_60_sec.csv', '15_features_timeseries_60_sec.csv', '14_features_timeseries_60_sec.csv', '18_features_timeseries_60_sec.csv']
# X_train: torch.Size([8640, 1, 140]) y_train: torch.Size([8640])
# X_test : torch.Size([2160, 1, 140]) y_test : torch.Size([2160])
